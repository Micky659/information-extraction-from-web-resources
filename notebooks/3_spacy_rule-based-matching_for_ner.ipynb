# %%
# install and download spaCy related modules
# !pip install --upgrade spacy
# !python -m spacy download en_core_web_lg

# Google Drive
from google.colab import drive

# Firebase/Firestore
import firebase_admin
from firebase_admin import credentials
from firebase_admin import firestore

# BeautifulSoup
from bs4 import BeautifulSoup

# Tweepy
import tweepy

# general Python modules
import re
import json
import spacy
from spacy.language import Language
import requests
import datetime
from dateutil.relativedelta import relativedelta
from pprint import pprint
from spacy.language import Language
from spacy.tokens import Span
from spacy.matcher import PhraseMatcher
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: spacy in /usr/local/lib/python3.8/dist-packages (3.4.4)
# Collecting spacy
#   Downloading spacy-3.5.0-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (6.7 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.7/6.7 MB 33.6 MB/s eta 0:00:00
# Requirement already satisfied: thinc<8.2.0,>=8.1.0 in /usr/local/lib/python3.8/dist-packages (from spacy) (8.1.7)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in /usr/local/lib/python3.8/dist-packages (from spacy) (1.0.4)
# Requirement already satisfied: wasabi<1.2.0,>=0.9.1 in /usr/local/lib/python3.8/dist-packages (from spacy) (0.10.1)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in /usr/local/lib/python3.8/dist-packages (from spacy) (3.0.8)
# Requirement already satisfied: srsly<3.0.0,>=2.4.3 in /usr/local/lib/python3.8/dist-packages (from spacy) (2.4.5)
# Requirement already satisfied: typer<0.8.0,>=0.3.0 in /usr/local/lib/python3.8/dist-packages (from spacy) (0.7.0)
# Requirement already satisfied: pathy>=0.10.0 in /usr/local/lib/python3.8/dist-packages (from spacy) (0.10.1)
# Requirement already satisfied: smart-open<7.0.0,>=5.2.1 in /usr/local/lib/python3.8/dist-packages (from spacy) (6.3.0)
# Requirement already satisfied: numpy>=1.15.0 in /usr/local/lib/python3.8/dist-packages (from spacy) (1.21.6)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.11 in /usr/local/lib/python3.8/dist-packages (from spacy) (3.0.12)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.8/dist-packages (from spacy) (2.11.3)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in /usr/local/lib/python3.8/dist-packages (from spacy) (2.0.8)
# Requirement already satisfied: langcodes<4.0.0,>=3.2.0 in /usr/local/lib/python3.8/dist-packages (from spacy) (3.3.0)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in /usr/local/lib/python3.8/dist-packages (from spacy) (2.0.7)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.8/dist-packages (from spacy) (57.4.0)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in /usr/local/lib/python3.8/dist-packages (from spacy) (1.0.9)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in /usr/local/lib/python3.8/dist-packages (from spacy) (4.64.1)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.8/dist-packages (from spacy) (23.0)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<1.11.0,>=1.7.4 in /usr/local/lib/python3.8/dist-packages (from spacy) (1.10.4)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in /usr/local/lib/python3.8/dist-packages (from spacy) (2.25.1)
# Requirement already satisfied: typing-extensions>=4.2.0 in /usr/local/lib/python3.8/dist-packages (from pydantic!=1.8,!=1.8.1,<1.11.0,>=1.7.4->spacy) (4.4.0)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.8/dist-packages (from requests<3.0.0,>=2.13.0->spacy) (1.24.3)
# Requirement already satisfied: chardet<5,>=3.0.2 in /usr/local/lib/python3.8/dist-packages (from requests<3.0.0,>=2.13.0->spacy) (4.0.0)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.8/dist-packages (from requests<3.0.0,>=2.13.0->spacy) (2.10)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.8/dist-packages (from requests<3.0.0,>=2.13.0->spacy) (2022.12.7)
# Requirement already satisfied: confection<1.0.0,>=0.0.1 in /usr/local/lib/python3.8/dist-packages (from thinc<8.2.0,>=8.1.0->spacy) (0.0.4)
# Requirement already satisfied: blis<0.8.0,>=0.7.8 in /usr/local/lib/python3.8/dist-packages (from thinc<8.2.0,>=8.1.0->spacy) (0.7.9)
# Requirement already satisfied: click<9.0.0,>=7.1.1 in /usr/local/lib/python3.8/dist-packages (from typer<0.8.0,>=0.3.0->spacy) (7.1.2)
# Requirement already satisfied: MarkupSafe>=0.23 in /usr/local/lib/python3.8/dist-packages (from jinja2->spacy) (2.0.1)
# Installing collected packages: spacy
#   Attempting uninstall: spacy
#     Found existing installation: spacy 3.4.4
#     Uninstalling spacy-3.4.4:
#       Successfully uninstalled spacy-3.4.4
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# en-core-web-sm 3.4.1 requires spacy<3.5.0,>=3.4.0, but you have spacy 3.5.0 which is incompatible.
# Successfully installed spacy-3.5.0
# /usr/local/lib/python3.8/dist-packages/torch/cuda/__init__.py:497: UserWarning: Can't initialize NVML
#   warnings.warn("Can't initialize NVML")
# 2023-02-13 15:44:25.814559: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-02-13 15:44:27.778983: W tensorflow/compiler/xla/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer.so.7'; dlerror: libnvinfer.so.7: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/local/nvidia/lib:/usr/local/nvidia/lib64
# 2023-02-13 15:44:27.779118: W tensorflow/compiler/xla/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer_plugin.so.7'; dlerror: libnvinfer_plugin.so.7: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/local/nvidia/lib:/usr/local/nvidia/lib64
# 2023-02-13 15:44:27.779141: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Cannot dlopen some TensorRT libraries. If you would like to use Nvidia GPU with TensorRT, please make sure the missing libraries mentioned above are installed properly.
# 2023-02-13 15:44:29.659779: E tensorflow/compiler/xla/stream_executor/cuda/cuda_driver.cc:267] failed call to cuInit: CUDA_ERROR_NO_DEVICE: no CUDA-capable device is detected
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting en-core-web-lg==3.5.0
#   Downloading https://github.com/explosion/spacy-models/releases/download/en_core_web_lg-3.5.0/en_core_web_lg-3.5.0-py3-none-any.whl (587.7 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 587.7/587.7 MB 2.0 MB/s eta 0:00:00
# Requirement already satisfied: spacy<3.6.0,>=3.5.0 in /usr/local/lib/python3.8/dist-packages (from en-core-web-lg==3.5.0) (3.5.0)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in /usr/local/lib/python3.8/dist-packages (from spacy<3.6.0,>=3.5.0->en-core-web-lg==3.5.0) (1.0.4)
# Requirement already satisfied: pathy>=0.10.0 in /usr/local/lib/python3.8/dist-packages (from spacy<3.6.0,>=3.5.0->en-core-web-lg==3.5.0) (0.10.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.8/dist-packages (from spacy<3.6.0,>=3.5.0->en-core-web-lg==3.5.0) (2.11.3)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in /usr/local/lib/python3.8/dist-packages (from spacy<3.6.0,>=3.5.0->en-core-web-lg==3.5.0) (1.0.9)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<1.11.0,>=1.7.4 in /usr/local/lib/python3.8/dist-packages (from spacy<3.6.0,>=3.5.0->en-core-web-lg==3.5.0) (1.10.4)
# Requirement already satisfied: typer<0.8.0,>=0.3.0 in /usr/local/lib/python3.8/dist-packages (from spacy<3.6.0,>=3.5.0->en-core-web-lg==3.5.0) (0.7.0)
# Requirement already satisfied: srsly<3.0.0,>=2.4.3 in /usr/local/lib/python3.8/dist-packages (from spacy<3.6.0,>=3.5.0->en-core-web-lg==3.5.0) (2.4.5)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in /usr/local/lib/python3.8/dist-packages (from spacy<3.6.0,>=3.5.0->en-core-web-lg==3.5.0) (2.25.1)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.11 in /usr/local/lib/python3.8/dist-packages (from spacy<3.6.0,>=3.5.0->en-core-web-lg==3.5.0) (3.0.12)
# Requirement already satisfied: smart-open<7.0.0,>=5.2.1 in /usr/local/lib/python3.8/dist-packages (from spacy<3.6.0,>=3.5.0->en-core-web-lg==3.5.0) (6.3.0)
# Requirement already satisfied: thinc<8.2.0,>=8.1.0 in /usr/local/lib/python3.8/dist-packages (from spacy<3.6.0,>=3.5.0->en-core-web-lg==3.5.0) (8.1.7)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in /usr/local/lib/python3.8/dist-packages (from spacy<3.6.0,>=3.5.0->en-core-web-lg==3.5.0) (2.0.7)
# Requirement already satisfied: langcodes<4.0.0,>=3.2.0 in /usr/local/lib/python3.8/dist-packages (from spacy<3.6.0,>=3.5.0->en-core-web-lg==3.5.0) (3.3.0)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.8/dist-packages (from spacy<3.6.0,>=3.5.0->en-core-web-lg==3.5.0) (23.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.8/dist-packages (from spacy<3.6.0,>=3.5.0->en-core-web-lg==3.5.0) (57.4.0)
# Requirement already satisfied: numpy>=1.15.0 in /usr/local/lib/python3.8/dist-packages (from spacy<3.6.0,>=3.5.0->en-core-web-lg==3.5.0) (1.21.6)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in /usr/local/lib/python3.8/dist-packages (from spacy<3.6.0,>=3.5.0->en-core-web-lg==3.5.0) (2.0.8)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in /usr/local/lib/python3.8/dist-packages (from spacy<3.6.0,>=3.5.0->en-core-web-lg==3.5.0) (3.0.8)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in /usr/local/lib/python3.8/dist-packages (from spacy<3.6.0,>=3.5.0->en-core-web-lg==3.5.0) (4.64.1)
# Requirement already satisfied: wasabi<1.2.0,>=0.9.1 in /usr/local/lib/python3.8/dist-packages (from spacy<3.6.0,>=3.5.0->en-core-web-lg==3.5.0) (0.10.1)
# Requirement already satisfied: typing-extensions>=4.2.0 in /usr/local/lib/python3.8/dist-packages (from pydantic!=1.8,!=1.8.1,<1.11.0,>=1.7.4->spacy<3.6.0,>=3.5.0->en-core-web-lg==3.5.0) (4.4.0)
# Requirement already satisfied: chardet<5,>=3.0.2 in /usr/local/lib/python3.8/dist-packages (from requests<3.0.0,>=2.13.0->spacy<3.6.0,>=3.5.0->en-core-web-lg==3.5.0) (4.0.0)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.8/dist-packages (from requests<3.0.0,>=2.13.0->spacy<3.6.0,>=3.5.0->en-core-web-lg==3.5.0) (2.10)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.8/dist-packages (from requests<3.0.0,>=2.13.0->spacy<3.6.0,>=3.5.0->en-core-web-lg==3.5.0) (1.24.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.8/dist-packages (from requests<3.0.0,>=2.13.0->spacy<3.6.0,>=3.5.0->en-core-web-lg==3.5.0) (2022.12.7)
# Requirement already satisfied: blis<0.8.0,>=0.7.8 in /usr/local/lib/python3.8/dist-packages (from thinc<8.2.0,>=8.1.0->spacy<3.6.0,>=3.5.0->en-core-web-lg==3.5.0) (0.7.9)
# Requirement already satisfied: confection<1.0.0,>=0.0.1 in /usr/local/lib/python3.8/dist-packages (from thinc<8.2.0,>=8.1.0->spacy<3.6.0,>=3.5.0->en-core-web-lg==3.5.0) (0.0.4)
# Requirement already satisfied: click<9.0.0,>=7.1.1 in /usr/local/lib/python3.8/dist-packages (from typer<0.8.0,>=0.3.0->spacy<3.6.0,>=3.5.0->en-core-web-lg==3.5.0) (7.1.2)
# Requirement already satisfied: MarkupSafe>=0.23 in /usr/local/lib/python3.8/dist-packages (from jinja2->spacy<3.6.0,>=3.5.0->en-core-web-lg==3.5.0) (2.0.1)
# Installing collected packages: en-core-web-lg
# Successfully installed en-core-web-lg-3.5.0
# ✔ Download and installation successful
# You can now load the package via spacy.load('en_core_web_lg')
# /usr/local/lib/python3.8/dist-packages/torch/cuda/__init__.py:497: UserWarning: Can't initialize NVML
#   warnings.warn("Can't initialize NVML")

# %%
from google.colab import drive
drive.mount('/content/drive/')

DRIVE_PATH = "/content/drive/MyDrive"

# # open Firebase credentials
# with open(DRIVE_PATH + "/IE/ie_course_2022_team03/credentials/firebase_credentials.json") as f:
#   credential = json.load(f)
# credential = credentials.Certificate(credential)

# # create Firestore database instance
# firebase_admin.initialize_app(credential)
# db = firestore.client()
# print("Stablished access to Firestore")
# Out:
# Mounted at /content/drive/

# %%
# retrieve list of entities gazetteers
with open(DRIVE_PATH + "/IE/ie_course_2022_team03/assets/entities_gazetteers.json") as f:
  entities_gazetteers_list = json.load(f)
  print(f"Retrieved entities gazetteers list")
  
# retrieve ignore list of entities gazetteers
with open(DRIVE_PATH + "/IE/ie_course_2022_team03/assets/entities_gazetteers_ignore_list.json") as f:
  entities_gazetteers_ignore_list = json.load(f)
  print(f"Retrieved entities gazetteers' ignore list")

# retrieve entities
with open(DRIVE_PATH + "/IE/ie_course_2022_team03/assets/entities.json") as f:
  entities = json.load(f)
  print(f"Retrieved entities")
# Out:
# Retrieved entities gazetteers list
# Retrieved entities gazetteers' ignore list
# Retrieved entities

# %%
""" Custom pipeline Component: entities gazetteer function """

@Language.component("entities_gazetteer")
def entities_gazetteer(doc):
  # set up and extend structure of default span object
  span = Span(doc, 0, 0, "")
  span.set_extension("qid", default=None, force=True)
  span.set_extension("label", default=None, force=True)
  span.set_extension("wd_name", default=None, force=True)

  # identify matches of the gazetteers contained in Doc object (text)
  matches = matcher(doc)
  # convert matches to Span objects
  spans = [doc[start:end] for _, start, end in matches]
  # filter overlaping matches (Span objs) to keep gazetteers uniqueness
  filtered_matches = spacy.util.filter_spans(spans)

  # loop unique matches of gazetteers
  for match in filtered_matches:
    # skip if matched gazetter is in ignore list
    if match.text in entities_gazetteers_ignore_list:
      print(f"-- Skipped '{match}' due it's in ignore list!")
      continue
    # find matched gazetters in issues dictionary to get entities' Wikidata info
    # usually only one entity is found, but some gazetteer finds more than one
    matched_entities = [i for i in entities if match.text == i["name"] or match.text in i["aliases"]]
    if len(matched_entities):
      entity = Span(doc, match.start, match.end, label=matched_entities[0]["label"])

      # set attributes
      if len(matched_entities) == 1:
        entity._.label = matched_entities[0]["label"]
      elif len(matched_entities) > 1:
        entity._.label = [e["label"] for e in matched_entities]

      entity.set_extension("qid", default=None, force=True)
      if len(matched_entities) == 1:
        entity._.qid = matched_entities[0]["qid"]
      elif len(matched_entities) > 1:
        entity._.qid = [e["qid"] for e in matched_entities]

      entity.set_extension("wd_name", default=None, force=True)
      if len(matched_entities) == 1:
        entity._.wd_name = matched_entities[0]["name"]
      elif len(matched_entities) > 1:
        entity._.wd_name = [e["name"] for e in matched_entities]

      # modify the provided entity spans, leaving the rest unmodified
      doc.set_ents([entity], default="unmodified")

  return doc

# create pipeline loaded with a pretrained statistical model (English/lg)
nlp = spacy.load("en_core_web_lg", exclude=["tok2vec", "tagger", "parser", "attribute_ruler", "lemmatizer"])
nlp.add_pipe("sentencizer")

# add custom component to pipeline
nlp.add_pipe("entities_gazetteer", last=True)

# initialize spaCY phrase matcher (rule-based)
matcher = PhraseMatcher(nlp.vocab, None)

# load gazetteers (issues) as matcher patterns
patterns = [nlp.make_doc(gazetteer) for gazetteer in entities_gazetteers_list]
matcher.add("gazetteers", patterns)

# see pipeline components
print(nlp.pipe_names)

# analize pipeline
pprint(nlp.analyze_pipes(pretty=True))
# Out:
# ['ner', 'sentencizer', 'entities_gazetteer']
#
# ============================= Pipeline Overview =============================
#
# #   Component            Assigns               Requires   Scores          Retokenizes
# -   ------------------   -------------------   --------   -------------   -----------
# 0   ner                  doc.ents                         ents_f          False
#                          token.ent_iob                    ents_p
#                          token.ent_type                   ents_r
#                                                           ents_per_type
#
# 1   sentencizer          token.is_sent_start              sents_f         False
#                          doc.sents                        sents_p
#                                                           sents_r
#
# 2   entities_gazetteer                                                    False
#
# ✔ No problems found.
# {'attrs': {'doc.ents': {'assigns': ['ner'], 'requires': []},
#            'doc.sents': {'assigns': ['sentencizer'], 'requires': []},
#            'token.ent_iob': {'assigns': ['ner'], 'requires': []},
#            'token.ent_type': {'assigns': ['ner'], 'requires': []},
#            'token.is_sent_start': {'assigns': ['sentencizer'], 'requires': []}},
#  'problems': {'entities_gazetteer': [], 'ner': [], 'sentencizer': []},
#  'summary': {'entities_gazetteer': {'assigns': [],
#                                     'requires': [],
#                                     'retokenizes': False,
#                                     'scores': []},
#              'ner': {'assigns': ['doc.ents', 'token.ent_iob', 'token.ent_type'],
#                      'requires': [],
#                      'retokenizes': False,
#                      'scores': ['ents_f', 'ents_p', 'ents_r', 'ents_per_type']},
#              'sentencizer': {'assigns': ['token.is_sent_start', 'doc.sents'],
#                              'requires': [],
#                              'retokenizes': False,
#                              'scores': ['sents_f', 'sents_p', 'sents_r']}}}

# %% [markdown]
# ### Test pipeline with one sentence

# %%
sentence = "POTUS 46 was born and raised in Scranton, Pennsylvania, and moved with his family to Delaware in 1953 when he was ten years old."
# initialize = nlp.initialize()
doc = nlp(sentence)
for ent in doc.ents:
  print(ent.text, ent.start_char, ent.end_char, ent.label_, ent._.qid, ent._.wd_name)
# Out:
# POTUS 46 0 8 PRODUCT None None
# Scranton 32 40 GPE None None
# Pennsylvania 42 54 GPE None None
# Delaware 85 93 GPE None None
# 1953 97 101 DATE None None
# ten years old 114 127 DATE None None

# %%
list_files = !ls /content/drive/MyDrive/IE/ie_course_2022_team03/retrieved_data/scrapped_data

# %%
# initialize main container of text
main_text_container = []
# main_text_woc_container = []
for file in list_files:
  print("Reading from file", file)
  with open(DRIVE_PATH + f"/IE/ie_course_2022_team03/retrieved_data/scrapped_data/{file}") as f:
    file_data = json.load(f)
    text = file_data["text"]
  # split text in paragraphs
  for index, paragraph in enumerate(text):
    # split paragraph in sentences
    sentences = [sent.text for sent in nlp(paragraph).sents]

    # process sentences individually in a stream (multi-thread)
    for doc in nlp.pipe(sentences, batch_size=50):
      sent = doc.text  # sentence
      chosen_sentence = [sent, {"entities": []}]
      for ent in doc.ents:
        if ent._.qid:
          chosen_sentence[1]["entities"].append([ent.start_char, ent.end_char, ent._.qid, ent.text, ent.label_, ent._.label, ent._.wd_name])
      if len(chosen_sentence[1]["entities"]):
        main_text_container.append(chosen_sentence)
        print()
        print(f"++ {sent}")
        for ent in doc.ents:
          if ent._.qid:
            print(f"    {ent.text, ent.start_char, ent.end_char, ent.label_, ent._.label, ent._.qid, ent._.wd_name}")
        print()
        
# save record in JSON file
if len(main_text_container):
  with open(DRIVE_PATH + "/IE/ie_course_2022_team03/output/extracted_sentences.json", "w", encoding = "utf-8") as f:
    json.dump(main_text_container, f, ensure_ascii = False, indent = 2)
    print()
    print(f"Saved {len(main_text_container)} extracted_sentences")
# Out:
# Streaming output truncated to the last 5000 lines.
#     ('Berlin', 2, 8, 'GPE', 'GPE', 'Q64', 'Berlin')
#
#
# ++
#           © Berlin Tourismus & Kongress GmbH
#
#     ('Berlin', 13, 19, 'GPE', 'GPE', 'Q64', 'Berlin')
#
# Reading from file visitberlindeenticketseventsattractionsberlin.json
#
# ++
#
# Berlin Unboxed: The visitBerlin Podcast
#
#
#
#
#     ('Berlin', 2, 8, 'GPE', 'GPE', 'Q64', 'Berlin')
#
#
# ++
#
# Museums in Berlin
#
#
#
#
#     ('Berlin', 13, 19, 'GPE', 'GPE', 'Q64', 'Berlin')
#
#
# ++
#
# 4 days Berlin from €190
#
#
#
#
#     ('Berlin', 9, 15, 'GPE', 'GPE', 'Q64', 'Berlin')
#
#
# ++
# Your entrance tickets to Berlin
#
#     ('Berlin', 26, 32, 'GPE', 'GPE', 'Q64', 'Berlin')
#
#
# ++ Find top experiences in Berlin
#     ('Berlin', 24, 30, 'GPE', 'GPE', 'Q64', 'Berlin')
#
#
# ++
# Enjoy a unique view over the Skyline of Berlin
#
#     ('Berlin', 41, 47, 'GPE', 'GPE', 'Q64', 'Berlin')
#
#
# ++
# Explore Berlin with popular bus tours in Berlin
#
#     ('Berlin', 9, 15, 'GPE', 'GPE', 'Q64', 'Berlin')
#     ('Berlin', 42, 48, 'GPE', 'GPE', 'Q64', 'Berlin')
#
#
# ++
# Discover popular sights in Berlin
#
#     ('Berlin', 28, 34, 'GPE', 'GPE', 'Q64', 'Berlin')
#
#
# ++
# Discover Berlin by boat
#
#     ('Berlin', 10, 16, 'GPE', 'GPE', 'Q64', 'Berlin')
#
#
# ++ Top activities in Berlin | Get your ticket now
#     ('Berlin', 18, 24, 'GPE', 'GPE', 'Q64', 'Berlin')
#
#
# ++
# Fast Track Entry to the Restaurant & fantastic view over Berlin
#
#     ('Berlin', 58, 64, 'GPE', 'GPE', 'Q64', 'Berlin')
#
#
# ++
# A time travel through the divided Berlin of the 80s
#
#     ('Berlin', 35, 41, 'GPE', 'GPE', 'Q64', 'Berlin')
#
#
# ++ Enjoy and Experience popular attractions and museums in Berlin with the whole family.
#     ('Berlin', 56, 62, 'GPE', 'GPE', 'Q64', 'Berlin')
#
#
# ++
# Creativity and fun on Berlin's most colorful indoor playground
#
#     ('Berlin', 23, 29, 'GPE', 'GPE', 'Q64', 'Berlin')
#
#
# ++
# A journey through 800 years of Berlin's eerie history
#
#     ('Berlin', 32, 38, 'GPE', 'GPE', 'Q64', 'Berlin')
#
#
# ++
# The popular light spectacle in the Botanical Garden Berlin
#
#     ('Berlin', 53, 59, 'GPE', 'GPE', 'Q64', 'Berlin')
#
#
# ++
# The perfect tour along the most famous sights of Berlin
#
#     ('Berlin', 50, 56, 'GPE', 'GPE', 'Q64', 'Berlin')
#
#
# ++
# Discover hidden places in Berlin's trendy centre
#
#     ('Berlin', 27, 33, 'GPE', 'GPE', 'Q64', 'Berlin')
#
#
# ++ Are you planning your museum visit in Berlin and looking for the right ticket?
#     ('Berlin', 38, 44, 'GPE', 'GPE', 'Q64', 'Berlin')
#
#
# ++ The Natural History Museum Berlin attracts more than 600,000 visitors every year.
#     ('Berlin', 27, 33, 'GPE', 'GPE', 'Q64', 'Berlin')
#
#
# ++ In addition, the GDR Museum Berlin offers a fascinating overview of life in the GDR.
#     ('Museum', 21, 27, 'ORG', '', 'Q48322275', 'Museum')
#     ('Berlin', 28, 34, 'GPE', 'GPE', 'Q64', 'Berlin')
#
#
# ++ Enjoy Berlin from the waterside.
#     ('Berlin', 6, 12, 'GPE', 'GPE', 'Q64', 'Berlin')
#
#
# ++ With a sightseeing tour by ship you will discover the sights of Berlin in a new and exciting perspective.
#     ('Berlin', 64, 70, 'GPE', 'GPE', 'Q64', 'Berlin')
#
#
# ++ Whether you are passing historic buildings such as the Berlin Cathedral or Bellevue Palace - boat trips or trips on the Spree are the perfect way to enjoy Berlin.
#     ('Berlin', 55, 61, 'GPE', 'GPE', 'Q64', 'Berlin')
#     ('way', 142, 145, 'PERSON', 'PERSON', 'Q17641254', 'Andrew John Henry Way')
#     ('Berlin', 155, 161, 'GPE', 'GPE', 'Q64', 'Berlin')
#
#
# ++
# Classic city tour: Discover the historical & modern Berlin
#
#     ('Berlin', 53, 59, 'GPE', 'GPE', 'Q64', 'Berlin')
#
#
# ++
# Discover the historic city and famous sights of Berlin
#
#     ('Berlin', 49, 55, 'GPE', 'GPE', 'Q64', 'Berlin')
#
#
# ++ We have compiled an overview for you of popular exhibitions in Berlin.
#     ('Berlin', 63, 69, 'GPE', 'GPE', 'Q64', 'Berlin')
#
#
# ++
# Deutsches Historisches Museum Berlin
#
#     ('Berlin', 31, 37, 'GPE', 'GPE', 'Q64', 'Berlin')
#
#
# ++
# Exhibition: Jewish Life in Germany: Past and Present
#
#     ('Germany', 28, 35, 'GPE', 'GPE', 'Q183', 'Germany')
#
#
# ++
# Art of divided Berlin & Dada Berlin & New Objectivity
#
#     ('Berlin', 16, 22, 'GPE', 'GPE', 'Q64', 'Berlin')
#     ('Berlin', 30, 36, 'GPE', 'GPE', 'Q64', 'Berlin')
#
#
# ++
# A 360 Degree Exhibition about the divided Berlin from Asisi
#
#     ('Berlin', 43, 49, 'GPE', 'GPE', 'Q64', 'Berlin')
#
#
# ++
# Multimedia exhibition on the history of the Berlin Wall
#
#     ('Berlin', 45, 51, 'GPE', 'GPE', 'Q64', 'Berlin')
#
#
# ++ Visiting Berlin – and looking to make the most of your trip?
#     ('Berlin', 9, 15, 'GPE', 'GPE', 'Q64', 'Berlin')
#
#
# ++ With its rich history and wealth of sights, Berlin is always fascinating to explore.
#     ('Berlin', 44, 50, 'GPE', 'GPE', 'Q64', 'Berlin')
#
#
# ++ For any Berlin visit, some things are an absolute must – from a river cruise down the Spree to the breath-taking view from the TV Tower.
#     ('Berlin', 8, 14, 'GPE', 'GPE', 'Q64', 'Berlin')
#
#
# ++
# Tickets for the museums & exhibitions in Berlin
#
#
#     ('Berlin', 42, 48, 'GPE', 'GPE', 'Q64', 'Berlin')
#
#
# ++
# Tickets for attractions in Berlin
#
#
#     ('Berlin', 28, 34, 'GPE', 'GPE', 'Q64', 'Berlin')
#
#
# ++ Discover the best-known and most beautiful sights of Berlin on a city tour by boat or bus or book a guided tour through this fascinating city.
#     ('Berlin', 53, 59, 'GPE', 'GPE', 'Q64', 'Berlin')
#
#
# ++ Learn more about Berlin's history on a guided tour or explore the city's varied museum landscape.
#     ('Berlin', 17, 23, 'GPE', 'GPE', 'Q64', 'Berlin')
#
#
# ++ Experience Berlin and book your tickets for current events and exhibitions here.
#     ('Berlin', 11, 17, 'GPE', 'GPE', 'Q64', 'Berlin')
#
#
# ++ Plan your Berlin trip with us and book your entry tickets for the most popular sights online.
#     ('Berlin', 10, 16, 'GPE', 'GPE', 'Q64', 'Berlin')
#
#
# ++
# Discover Berlin by boat
#
#     ('Berlin', 10, 16, 'GPE', 'GPE', 'Q64', 'Berlin')
#
#
# ++
# Discover popular sights in Berlin
#
#     ('Berlin', 28, 34, 'GPE', 'GPE', 'Q64', 'Berlin')
#
#
# ++
# Berlin's official tourist card
#
#     ('Berlin', 1, 7, 'GPE', 'GPE', 'Q64', 'Berlin')
#
#
# ++
#
#                       The Berlin
#
#
#                       classic
#
#
#                       for over 20 years
#
#
#     ('Berlin', 28, 34, 'GPE', 'GPE', 'Q64', 'Berlin')
#
#
# ++ In Berlin, there’s always so much to do, every day of the year, any time of day or night – a sparkling array of events, highlights, entertainment and culture.
#     ('Berlin', 3, 9, 'GPE', 'GPE', 'Q64', 'Berlin')
#
#
# ++ Event tickets in Berlin
#     ('Berlin', 17, 23, 'GPE', 'GPE', 'Q64', 'Berlin')
#
#
# ++
#                 Berlin's official tourist ticket
#
#     ('Berlin', 17, 23, 'GPE', 'GPE', 'Q64', 'Berlin')
#
#
# ++
# More about the Berlin WelcomeCard
#
#     ('Berlin', 16, 22, 'GPE', 'GPE', 'Q64', 'Berlin')
#
#
# ++ Get information and advice for your Berlin visit from the experts at the Berlin Tourist Information Offices dotted around the city.
#     ('Berlin', 36, 42, 'GPE', 'GPE', 'Q64', 'Berlin')
#     ('Berlin', 73, 79, 'GPE', 'GPE', 'Q64', 'Berlin')
#
#
# ++
# Show details
#
#
#
#     ('Show', 1, 5, 'PERSON', 'PERSON', 'Q53858110', 'Manuel Luís Cafumana')
#
#
# ++
# The best deals for your Berlin trip
#
#     ('Berlin', 25, 31, 'GPE', 'GPE', 'Q64', 'Berlin')
#
#
# ++ Attractive prices for your city trip to Berlin.
#     ('Berlin', 40, 46, 'GPE', 'GPE', 'Q64', 'Berlin')
#
#
# ++
# Show details
#
#
#
#     ('Show', 1, 5, 'PERSON', 'PERSON', 'Q53858110', 'Manuel Luís Cafumana')
#
#
# ++
# Art and culture, knowledge and entertainment in the German capital
#
#     ('German', 53, 59, 'NORP', 'NORP', 'Q188', 'German')
#
#
# ++ What can I experience in Berlin?
#     ('Berlin', 25, 31, 'GPE', 'GPE', 'Q64', 'Berlin')
#
#
# ++
# Show details
#
#
#
#     ('Show', 1, 5, 'PERSON', 'PERSON', 'Q53858110', 'Manuel Luís Cafumana')
#
#
# ++
#           Do you need help?
#     ('Do', 11, 13, 'PERSON', 'PERSON', 'Q2621234', 'Marshall Applewhite')
#
#
# ++ Berlin's official travel website visitBerlin.de
#     ('Berlin', 0, 6, 'GPE', 'GPE', 'Q64', 'Berlin')
#
#
# ++
# visitBerlin-Blog
# Here write the Berlin insiders
#
#     ('Berlin', 33, 39, 'GPE', 'GPE', 'Q64', 'Berlin')
#
#
# ++
#
# Berlin's official tourist ticket
#           berlin-welcomecard.de
#
#     ('Berlin', 2, 8, 'GPE', 'GPE', 'Q64', 'Berlin')
#
#
# ++
#           © Berlin Tourismus & Kongress GmbH
#
#     ('Berlin', 13, 19, 'GPE', 'GPE', 'Q64', 'Berlin')
#
# Reading from file visitberlindeenticketsfastviewticketberlintvtower.json
#
# ++
#
# Berlin Unboxed: The visitBerlin Podcast
#
#
#
#
#     ('Berlin', 2, 8, 'GPE', 'GPE', 'Q64', 'Berlin')
#
#
# ++
#
# Museums in Berlin
#
#
#
#
#     ('Berlin', 13, 19, 'GPE', 'GPE', 'Q64', 'Berlin')
#
#
# ++
#
# 4 days Berlin from €190
#
#
#
#
#     ('Berlin', 9, 15, 'GPE', 'GPE', 'Q64', 'Berlin')
#
#
# ++ Berlin's official travel website visitBerlin.de
#     ('Berlin', 0, 6, 'GPE', 'GPE', 'Q64', 'Berlin')
#
#
# ++
# visitBerlin-Blog
# Here write the Berlin insiders
#
#     ('Berlin', 33, 39, 'GPE', 'GPE', 'Q64', 'Berlin')
#
#
# ++
#
# Berlin's official tourist ticket
#           berlin-welcomecard.de
#
#     ('Berlin', 2, 8, 'GPE', 'GPE', 'Q64', 'Berlin')
#
#
# ++
#           © Berlin Tourismus & Kongress GmbH
#
#     ('Berlin', 13, 19, 'GPE', 'GPE', 'Q64', 'Berlin')
#
# Reading from file visitberlindeenticketsguidedwalkingtoursberlin.json
#
# ++
#
# Berlin Unboxed: The visitBerlin Podcast
#
#
#
#
#     ('Berlin', 2, 8, 'GPE', 'GPE', 'Q64', 'Berlin')
#
#
# ++
#
# Museums in Berlin
#
#
#
#
#     ('Berlin', 13, 19, 'GPE', 'GPE', 'Q64', 'Berlin')
#
#
# ++
#
# 4 days Berlin from €190
#
#
#
#
#     ('Berlin', 9, 15, 'GPE', 'GPE', 'Q64', 'Berlin')
#
#
# ++ In 2021, the Discover Berlin tour by Original Berlin Walks was awarded "Travelers' Choice - Best of the Best" via Tripadvisor and not without reason!
#     ('Berlin', 22, 28, 'GPE', 'GPE', 'Q64', 'Berlin')
#     ('Berlin', 46, 52, 'GPE', 'GPE', 'Q64', 'Berlin')
#     ('not', 130, 133, 'ORG', 'ORG', 'Q18035109', 'ALG3')
#
#
# ++ This tour covers all the major sights of Berlin and offers a perfect overview of the city for first-time visitors.
#     ('Berlin', 41, 47, 'GPE', 'GPE', 'Q64', 'Berlin')
#
#
# ++ But Original Berlin Walks also has a wide range of other exciting walking tours with special focus on for instance street art, food culture or the division of Berlin.
#     ('Berlin', 13, 19, 'GPE', 'GPE', 'Q64', 'Berlin')
#     ('Berlin', 159, 165, 'GPE', 'GPE', 'Q64', 'Berlin')
#
#
# ++
# The perfect tour along the most famous sights of Berlin
#
#     ('Berlin', 50, 56, 'GPE', 'GPE', 'Q64', 'Berlin')
#
#
# ++
#
#                       from
#
#
#                       € 20.00
#
#
#                       Guide: English
#
#
#     ('Guide', 121, 126, 'PERSON', 'PERSON', 'Q109061', 'Guido Reni')
#
#
# ++
#
#                       from
#
#
#                       €20.00
#
#
#                       Guide: English
#
#
#     ('Guide', 120, 125, 'PERSON', 'PERSON', 'Q109061', 'Guido Reni')
#
#
# ++
#
#                       6 hours
#
#
#                       tour
#
#
#                       from Berlin
#
#
#     ('Berlin', 126, 132, 'GPE', 'GPE', 'Q64', 'Berlin')
#
#
# ++
# Original Berlin Walks English Guided Tour
#
#     ('Berlin', 10, 16, 'GPE', 'GPE', 'Q64', 'Berlin')
#
#
# ++
#
#                       from
#
#
#                        € 20.00
#
#
#                       Guide: English
#
#
#     ('Guide', 122, 127, 'PERSON', 'PERSON', 'Q109061', 'Guido Reni')
#
#
# ++
# A guided city tour through Berlin's Cold War history
#
#     ('Berlin', 28, 34, 'GPE', 'GPE', 'Q64', 'Berlin')
#
#
# ++
# Berlin in the footsteps of famous women
#
#     ('Berlin', 1, 7, 'GPE', 'GPE', 'Q64', 'Berlin')
#
#
# ++ Secret Tours Berlin is the perfect way to experience the city in a way you've never seen it before!
#     ('Berlin', 13, 19, 'GPE', 'GPE', 'Q64', 'Berlin')
#     ('way', 35, 38, 'PERSON', 'PERSON', 'Q17641254', 'Andrew John Henry Way')
#     ('way', 67, 70, 'PERSON', 'PERSON', 'Q17641254', 'Andrew John Henry Way')
#
#
# ++ The specialised walking tours will lead you away from everyday places by showing you a completely different perspective of Berlin.
#     ('Berlin', 123, 129, 'GPE', 'GPE', 'Q64', 'Berlin')
#
#
# ++
# Insights and stories about Berlin's oldest hospital
#
#     ('Berlin', 28, 34, 'GPE', 'GPE', 'Q64', 'Berlin')
#
#
# ++
# Discover hidden places in Berlin's trendy centre
#
#     ('Berlin', 27, 33, 'GPE', 'GPE', 'Q64', 'Berlin')
#
#
# ++
# Discover one of Berlin's most famous lost places
#
#     ('Berlin', 17, 23, 'GPE', 'GPE', 'Q64', 'Berlin')
#
#
# ++
# Sights and hidden places in the western part of Berlin
#
#     ('Berlin', 49, 55, 'GPE', 'GPE', 'Q64', 'Berlin')
#
#
# ++
# With Karl-Heinz Richter through East Berlin
#
#     ('East', 33, 37, 'GPE', '', 'Q684', 'east')
#     ('Berlin', 38, 44, 'GPE', 'GPE', 'Q64', 'Berlin')
#
#
# ++ The Olympic Stadium Berlin is an exciting and unique place for sports and history enthusiasts alike.
#     ('Berlin', 20, 26, 'GPE', 'GPE', 'Q64', 'Berlin')
#
#
# ++ Explore Berlin by bike: Berlin on Bike is the ideal way to do it!
#     ('Berlin', 8, 14, 'GPE', 'GPE', 'Q64', 'Berlin')
#     ('Berlin', 24, 30, 'GPE', 'GPE', 'Q64', 'Berlin')
#     ('way', 52, 55, 'PERSON', 'PERSON', 'Q17641254', 'Andrew John Henry Way')
#
#
# ++ The best way to explore the city?
#     ('way', 9, 12, 'PERSON', 'PERSON', 'Q17641254', 'Andrew John Henry Way')
#
#
# ++
# Guided tour alongside the former Berlin Wall
#
#     ('Berlin', 34, 40, 'GPE', 'GPE', 'Q64', 'Berlin')
#
#
# ++
# Discover Berlin's highlights on bike
#
#     ('Berlin', 10, 16, 'GPE', 'GPE', 'Q64', 'Berlin')
#
#
# ++
# Guided canoe tour in the east of Berlin
#
#     ('Berlin', 34, 40, 'GPE', 'GPE', 'Q64', 'Berlin')
#
#
# ++
# Explore Berlin by canoe
#
#     ('Berlin', 9, 15, 'GPE', 'GPE', 'Q64', 'Berlin')
#
#
# ++
#
#                       from
#
#
#                       € 45.00
#
#
#                       Price per day
#
#
#     ('day', 132, 135, 'DATE', '', 'Q573', 'day')
#
#
# ++ By foot or by bike - discover exciting and amazing, well-known and hidden places in Berlin.
#     ('Berlin', 84, 90, 'GPE', 'GPE', 'Q64', 'Berlin')
#
#
# ++ Find out a lot of fascinating and interesting facts about Berlin in an amusing way.
#     ('Berlin', 58, 64, 'GPE', 'GPE', 'Q64', 'Berlin')
#     ('way', 79, 82, 'PERSON', 'PERSON', 'Q17641254', 'Andrew John Henry Way')
#
#
# ++ A wide range of various guided tours in Berlin
#     ('Berlin', 40, 46, 'GPE', 'GPE', 'Q64', 'Berlin')
#
#
# ++ Would you like to learn more about the history of the city, about the UNESCO World Heritage Museum Island in Berlin or find out more about the street art scene?
#     ('Berlin', 109, 115, 'GPE', 'GPE', 'Q64', 'Berlin')
#
#
# ++ Certified tour guides with many years of experience and a wide range of tours will guarenteed an enjoyable and varied guided city tour - suitable for all Berlin explorers.
#     ('Berlin', 154, 160, 'GPE', 'GPE', 'Q64', 'Berlin')
#
#
# ++ Book your tickets now and explore Berlin with a smile.
#     ('Berlin', 34, 40, 'GPE', 'GPE', 'Q64', 'Berlin')
#
#
# ++
#           Do you need help?
#     ('Do', 11, 13, 'PERSON', 'PERSON', 'Q2621234', 'Marshall Applewhite')
#
#
# ++ Everything for your perfect Berlin experience
#     ('Berlin', 28, 34, 'GPE', 'GPE', 'Q64', 'Berlin')
#
#
# ++ Berlin's official travel website visitBerlin.de
#     ('Berlin', 0, 6, 'GPE', 'GPE', 'Q64', 'Berlin')
#
#
# ++
# visitBerlin-Blog
# Here write the Berlin insiders
#
#     ('Berlin', 33, 39, 'GPE', 'GPE', 'Q64', 'Berlin')
#
#
# ++
#
# Berlin's official tourist ticket
#           berlin-welcomecard.de
#
#     ('Berlin', 2, 8, 'GPE', 'GPE', 'Q64', 'Berlin')
#
#
# ++
#           © Berlin Tourismus & Kongress GmbH
#
#     ('Berlin', 13, 19, 'GPE', 'GPE', 'Q64', 'Berlin')
#
# Reading from file visitberlindeenticketshoponhopoffsightseeingbustoursberlin.json
#
# ++
#
# Berlin Unboxed: The visitBerlin Podcast
#
#
#
#
#     ('Berlin', 2, 8, 'GPE', 'GPE', 'Q64', 'Berlin')
#
#
# ++
#
# Museums in Berlin
#
#
#
#
#     ('Berlin', 13, 19, 'GPE', 'GPE', 'Q64', 'Berlin')
#
#
# ++
#
# 4 days Berlin from €190
#
#
#
#
#     ('Berlin', 9, 15, 'GPE', 'GPE', 'Q64', 'Berlin')
#
#
# ++
# Explore Berlin with popular bus tours in Berlin
#
#     ('Berlin', 9, 15, 'GPE', 'GPE', 'Q64', 'Berlin')
#     ('Berlin', 42, 48, 'GPE', 'GPE', 'Q64', 'Berlin')
#
#
# ++ Popular bus tours by Stromma Berlin
#     ('Berlin', 29, 35, 'GPE', 'GPE', 'Q64', 'Berlin')
#
#
# ++ Popular bus tours by City Circle Sightseeing
#     ('City', 21, 25, 'GPE', 'GPE', 'Q50602', 'Manchester City F.C.')
#
#
# ++
# Explore the most beautiful sights of Berlin
#
#     ('Berlin', 38, 44, 'GPE', 'GPE', 'Q64', 'Berlin')
#
#
# ++
# Discover Potsdam with City Circle Sightseeing
#
#     ('City', 23, 27, 'GPE', 'GPE', 'Q50602', 'Manchester City F.C.')
#
#
# ++
# Sightseeing in Berlin by bus & ship
#
#     ('Berlin', 16, 22, 'GPE', 'GPE', 'Q64', 'Berlin')
#
#
# ++ City bus tours by Top Tour Sightseeing
#     ('City', 0, 4, 'GPE', 'GPE', 'Q50602', 'Manchester City F.C.')
#
#
# ++
# Discover the most beautiful Berlin sights
#
#     ('Berlin', 29, 35, 'GPE', 'GPE', 'Q64', 'Berlin')
#
#
# ++ Popular bus tours by Berlin City Tour
#     ('Berlin', 21, 27, 'GPE', 'GPE', 'Q64', 'Berlin')
#     ('City', 28, 32, 'GPE', 'GPE', 'Q50602', 'Manchester City F.C.')
#
#
# ++
# Sightseeing tour Berlin by bus
#
#     ('Berlin', 18, 24, 'GPE', 'GPE', 'Q64', 'Berlin')
#
#
# ++
# Discover Berlin by bus and boat
#
#     ('Berlin', 10, 16, 'GPE', 'GPE', 'Q64', 'Berlin')
#
#
# ++ City tours with Big Bus Tours Berlin
#     ('City', 0, 4, 'GPE', 'GPE', 'Q50602', 'Manchester City F.C.')
#     ('Berlin', 30, 36, 'GPE', 'GPE', 'Q64', 'Berlin')
#
#
# ++
# Discover the highlights of Berlin at your own pace
#
#     ('Berlin', 28, 34, 'GPE', 'GPE', 'Q64', 'Berlin')
#
#
# ++ Would you like to explore as many beautiful sights as possible on your Berlin tour?
#     ('Berlin', 71, 77, 'GPE', 'GPE', 'Q64', 'Berlin')
#
#
# ++ Experience Berlin in a comfortable way by bus.
#     ('Berlin', 11, 17, 'GPE', 'GPE', 'Q64', 'Berlin')
#     ('way', 35, 38, 'PERSON', 'PERSON', 'Q17641254', 'Andrew John Henry Way')
#
#
# ++ Berlin explorers can comfortably explore the highlights of this fascinating city.
#     ('Berlin', 0, 6, 'GPE', 'GPE', 'Q64', 'Berlin')
#
#
# ++ Just sit back relaxed and enjoy the city view on a sightseeing tour through Berlin by bus.
#     ('Berlin', 76, 82, 'GPE', 'GPE', 'Q64', 'Berlin')
#
#
# ++ Hop-On Hop-Off Bus Tours - Especially Flexible City Tours
#     ('City', 47, 51, 'GPE', 'GPE', 'Q50602', 'Manchester City F.C.')
#
#
# ++ Everything for your perfect Berlin experience
#     ('Berlin', 28, 34, 'GPE', 'GPE', 'Q64', 'Berlin')
#
#
# ++
# Discover popular sights in Berlin
#
#     ('Berlin', 28, 34, 'GPE', 'GPE', 'Q64', 'Berlin')
#
#
# ++
# The best deals for your Berlin trip
#
#     ('Berlin', 25, 31, 'GPE', 'GPE', 'Q64', 'Berlin')
#
#
# ++ Attractive prices for your city trip to Berlin.
#     ('Berlin', 40, 46, 'GPE', 'GPE', 'Q64', 'Berlin')
#
#
# ++
# Show details
#
#
#
#     ('Show', 1, 5, 'PERSON', 'PERSON', 'Q53858110', 'Manuel Luís Cafumana')
#
#
# ++
#           Do you need help?
#     ('Do', 11, 13, 'PERSON', 'PERSON', 'Q2621234', 'Marshall Applewhite')
#
#
# ++ Berlin's official travel website visitBerlin.de
#     ('Berlin', 0, 6, 'GPE', 'GPE', 'Q64', 'Berlin')
#
#
# ++
# visitBerlin-Blog
# Here write the Berlin insiders
#
#     ('Berlin', 33, 39, 'GPE', 'GPE', 'Q64', 'Berlin')
#
#
# ++
#
# Berlin's official tourist ticket
#           berlin-welcomecard.de
#
#     ('Berlin', 2, 8, 'GPE', 'GPE', 'Q64', 'Berlin')
#
#
# ++
#           © Berlin Tourismus & Kongress GmbH
#
#     ('Berlin', 13, 19, 'GPE', 'GPE', 'Q64', 'Berlin')
#
# Reading from file visitberlindeenticketsmuseumexhibitionsberlin.json
#
# ++
#
# Berlin Unboxed: The visitBerlin Podcast
#
#
#
#
#     ('Berlin', 2, 8, 'GPE', 'GPE', 'Q64', 'Berlin')
#
#
# ++
#
# Museums in Berlin
#
#
#
#
#     ('Berlin', 13, 19, 'GPE', 'GPE', 'Q64', 'Berlin')
#
#
# ++
#
# 4 days Berlin from €190
#
#
#
#
#     ('Berlin', 9, 15, 'GPE', 'GPE', 'Q64', 'Berlin')
#
#
# ++ For your next museum tour in Berlin, we compiled a list of the state museums in Berlin (Staatliche Museen zu Berlin) for you, clearly arranged and up-to-date.
#     ('Berlin', 29, 35, 'GPE', 'GPE', 'Q64', 'Berlin')
#     ('Berlin', 80, 86, 'GPE', 'GPE', 'Q64', 'Berlin')
#     ('zu', 106, 108, 'GPE', 'GPE', 'Q10179', 'Zulu')
#     ('Berlin', 109, 115, 'GPE', 'GPE', 'Q64', 'Berlin')
#
#
# ++
# Museum for Contemporary Art Berlin
#
#     ('Berlin', 29, 35, 'GPE', 'GPE', 'Q64', 'Berlin')
#
#
# ++ We have compiled an overview for you of popular exhibitions in Berlin.
#     ('Berlin', 63, 69, 'GPE', 'GPE', 'Q64', 'Berlin')
#
#
# ++
# Deutsches Historisches Museum Berlin
#
#     ('Berlin', 31, 37, 'GPE', 'GPE', 'Q64', 'Berlin')
#
#
# ++
# Exhibition: Jewish Life in Germany: Past and Present
#
#     ('Germany', 28, 35, 'GPE', 'GPE', 'Q183', 'Germany')
#
#
# ++
# Art of divided Berlin & Dada Berlin & New Objectivity
#
#     ('Berlin', 16, 22, 'GPE', 'GPE', 'Q64', 'Berlin')
#     ('Berlin', 30, 36, 'GPE', 'GPE', 'Q64', 'Berlin')
#
#
# ++
# A 360 Degree Exhibition about the divided Berlin from Asisi
#
#     ('Berlin', 43, 49, 'GPE', 'GPE', 'Q64', 'Berlin')
#
#
# ++
# Multimedia exhibition on the history of the Berlin Wall
#
#     ('Berlin', 45, 51, 'GPE', 'GPE', 'Q64', 'Berlin')
#
#
# ++ Our recommendations for family & children activities in Berlin
#     ('Berlin', 56, 62, 'GPE', 'GPE', 'Q64', 'Berlin')
#
#
# ++ You want to see as many museums as possible in Berlin, or would you prefer a very specific one?
#     ('Berlin', 47, 53, 'GPE', 'GPE', 'Q64', 'Berlin')
#
#
# ++ Berlin has more museums than rainy days - that's 180 museums with an average of 100 rainy days a year.
#     ('Berlin', 0, 6, 'GPE', 'GPE', 'Q64', 'Berlin')
#
#
# ++ This means you have to choose which museums you want to visit first - we cannot decide that for you.
#     ('not', 76, 79, 'ORG', 'ORG', 'Q18035109', 'ALG3')
#
#
# ++ Whether you came to Berlin specifically for its museum culture, or if you only want to pay a visit to Nefertiti, you can buy the right ticket from us at visitBerlin.de.
#     ('Berlin', 20, 26, 'GPE', 'GPE', 'Q64', 'Berlin')
#
#
# ++ Would you like to visit the famous museums of the Museum Island and discover Berlin in a more flexible way?
#     ('Berlin', 77, 83, 'GPE', 'GPE', 'Q64', 'Berlin')
#     ('way', 103, 106, 'PERSON', 'PERSON', 'Q17641254', 'Andrew John Henry Way')
#
#
# ++ The Berlin Welcome Card Museum Island is perfect choice for museum lovers and Berlin explorers.
#     ('Berlin', 4, 10, 'GPE', 'GPE', 'Q64', 'Berlin')
#     ('Berlin', 78, 84, 'GPE', 'GPE', 'Q64', 'Berlin')
#
#
# ++ If you are a real culture fan and cannot get enough of the museums in Berlin, the museum pass is the ticket for you.
#     ('not', 37, 40, 'ORG', 'ORG', 'Q18035109', 'ALG3')
#     ('Berlin', 70, 76, 'GPE', 'GPE', 'Q64', 'Berlin')
#
#
# ++ With the Berlin museum pass, you get free admission to more than 30 exhibitions and museums on three consecutive days.
#     ('Berlin', 9, 15, 'GPE', 'GPE', 'Q64', 'Berlin')
#
#
# ++ Here you will get more tickets for Berlin
#     ('Berlin', 35, 41, 'GPE', 'GPE', 'Q64', 'Berlin')
#
#
# ++ Are you perhaps in Berlin for the first time and want to combine sightseeing and culture in Berlin?
#     ('Berlin', 19, 25, 'GPE', 'GPE', 'Q64', 'Berlin')
#     ('Berlin', 92, 98, 'GPE', 'GPE', 'Q64', 'Berlin')
#
#
# ++ The official tourist ticket is a public transport ticket and a discount card in one - and you can choose how many days the Berlin Welcome Card covers.
#     ('Berlin', 123, 129, 'GPE', 'GPE', 'Q64', 'Berlin')
#
#
# ++ For 48 hours, the Berlin Welcome Card is from  €19.90.
#     ('Berlin', 18, 24, 'GPE', 'GPE', 'Q64', 'Berlin')
#
#
# ++ Here are the advantages of the Berlin Welcome Card at a glance:
#     ('Berlin', 31, 37, 'GPE', 'GPE', 'Q64', 'Berlin')
#
#
# ++ Buy the Berlin Welcome Card
#     ('Berlin', 8, 14, 'GPE', 'GPE', 'Q64', 'Berlin')
#
#
# ++ Discover Berlin without having to wait around everywhere and buy tickets?
#     ('Berlin', 9, 15, 'GPE', 'GPE', 'Q64', 'Berlin')
#
#
# ++ Treat yourself to a little comfort and make your visit to Berlin something special without stress.
#     ('Berlin', 58, 64, 'GPE', 'GPE', 'Q64', 'Berlin')
#
#
# ++ With the Berlin Welcome Card all inclusive, you pay once and then have free admission to 30 of the most exciting sights and museums in Berlin, such as the Pergamon Museum and the Neues Museum.
#     ('Berlin', 9, 15, 'GPE', 'GPE', 'Q64', 'Berlin')
#     ('Berlin', 135, 141, 'GPE', 'GPE', 'Q64', 'Berlin')
#
#
# ++ Here are the advantages of the Berlin Welcome Card all inclusive at a glance:
#     ('Berlin', 31, 37, 'GPE', 'GPE', 'Q64', 'Berlin')
#
#
# ++ Buy the Berlin Welcome Card all inclusive
#     ('Berlin', 8, 14, 'GPE', 'GPE', 'Q64', 'Berlin')
#
#
# ++
#           Do you need help?
#     ('Do', 11, 13, 'PERSON', 'PERSON', 'Q2621234', 'Marshall Applewhite')
#
#
# ++ Berlin's official travel website visitBerlin.de
#     ('Berlin', 0, 6, 'GPE', 'GPE', 'Q64', 'Berlin')
#
#
# ++
# visitBerlin-Blog
# Here write the Berlin insiders
#
#     ('Berlin', 33, 39, 'GPE', 'GPE', 'Q64', 'Berlin')
#
#
# ++
#
# Berlin's official tourist ticket
#           berlin-welcomecard.de
#
#     ('Berlin', 2, 8, 'GPE', 'GPE', 'Q64', 'Berlin')
#
#
# ++
#           © Berlin Tourismus & Kongress GmbH
#
#     ('Berlin', 13, 19, 'GPE', 'GPE', 'Q64', 'Berlin')
#
# Reading from file visitberlindeenticketszooaquariumtierparkberlin.json
#
# ++
#
# Berlin Unboxed: The visitBerlin Podcast
#
#
#
#
#     ('Berlin', 2, 8, 'GPE', 'GPE', 'Q64', 'Berlin')
#
#
# ++
#
# Museums in Berlin
#
#
#
#
#     ('Berlin', 13, 19, 'GPE', 'GPE', 'Q64', 'Berlin')
#
#
# ++
#
# 4 days Berlin from €190
#
#
#
#
#     ('Berlin', 9, 15, 'GPE', 'GPE', 'Q64', 'Berlin')
#
#
# ++ Discover the polar bears, pandas, giraffes, fish, crocodiles, seahorses and around 1,200 other animal species at the Berlin Zoo, Tierpark (Animal Park) and Aquarium.
#     ('Berlin', 117, 123, 'GPE', 'GPE', 'Q64', 'Berlin')
#
#
# ++ An experience for the whole family - in the most species-rich zoo in the world, Berlin Zoo, with more than 20,000 animals, visitors will be able to enjoy and discover the fascinating world of animals.
#     ('Berlin', 80, 86, 'GPE', 'GPE', 'Q64', 'Berlin')
#
#
# ++ During your journey through Berlin Zoo, you can experience and discover around 10,000 native and exotic animals at close distance.
#     ('Berlin', 28, 34, 'GPE', 'GPE', 'Q64', 'Berlin')
#
#
# ++ With its 160 hectares and its lovingly designed park landscape, the Tierpark Berlin invites you not only to take a spectacular look at the world of animals, there is also time for an fantastic walk.
#     ('Berlin', 77, 83, 'GPE', 'GPE', 'Q64', 'Berlin')
#     ('not', 96, 99, 'ORG', 'ORG', 'Q18035109', 'ALG3')
#
#
# ++ At the Aquarium Berlin you can dive into the impressive underwater world full of fascinating aquatic creatures such as Fishes and Corals as well as a discovery tour through the world of amphibians, reptiles and insects.
#     ('Berlin', 16, 22, 'GPE', 'GPE', 'Q64', 'Berlin')
#
#
# ++
#           Do you need help?
#     ('Do', 11, 13, 'PERSON', 'PERSON', 'Q2621234', 'Marshall Applewhite')
#
#
# ++ Berlin's official travel website visitBerlin.de
#     ('Berlin', 0, 6, 'GPE', 'GPE', 'Q64', 'Berlin')
#
#
# ++
# visitBerlin-Blog
# Here write the Berlin insiders
#
#     ('Berlin', 33, 39, 'GPE', 'GPE', 'Q64', 'Berlin')
#
#
# ++
#
# Berlin's official tourist ticket
#           berlin-welcomecard.de
#
#     ('Berlin', 2, 8, 'GPE', 'GPE', 'Q64', 'Berlin')
#
#
# ++
#           © Berlin Tourismus & Kongress GmbH
#
#     ('Berlin', 13, 19, 'GPE', 'GPE', 'Q64', 'Berlin')
#
# Reading from file visitberlindeentipsofthedayeventsberlin.json
#
# ++
#
# Berlin Unboxed: The visitBerlin Podcast
#
#
#
#
#     ('Berlin', 2, 8, 'GPE', 'GPE', 'Q64', 'Berlin')
#
#
# ++
#
# Museums in Berlin
#
#
#
#
#     ('Berlin', 13, 19, 'GPE', 'GPE', 'Q64', 'Berlin')
#
#
# ++
#
# 4 days Berlin from €190
#
#
#
#
#     ('Berlin', 9, 15, 'GPE', 'GPE', 'Q64', 'Berlin')
#
#
# ++ Berlin's official travel website visitBerlin.de
#     ('Berlin', 0, 6, 'GPE', 'GPE', 'Q64', 'Berlin')
#
#
# ++
# visitBerlin-Blog
# Here write the Berlin insiders
#
#     ('Berlin', 33, 39, 'GPE', 'GPE', 'Q64', 'Berlin')
#
#
# ++
#
# Berlin's official tourist ticket
#           berlin-welcomecard.de
#
#     ('Berlin', 2, 8, 'GPE', 'GPE', 'Q64', 'Berlin')
#
#
# ++
#           © Berlin Tourismus & Kongress GmbH
#
#     ('Berlin', 13, 19, 'GPE', 'GPE', 'Q64', 'Berlin')
#
# Reading from file visitberlindeentopeventsberlin.json
#
# ++
#
# Berlin Unboxed: The visitBerlin Podcast
#
#
#
#
#     ('Berlin', 2, 8, 'GPE', 'GPE', 'Q64', 'Berlin')
#
#
# ++
#
# Museums in Berlin
#
#
#
#
#     ('Berlin', 13, 19, 'GPE', 'GPE', 'Q64', 'Berlin')
#
#
# ++
#
# 4 days Berlin from €190
#
#
#
#
#     ('Berlin', 9, 15, 'GPE', 'GPE', 'Q64', 'Berlin')
#
#
# ++
# The Highlights in Berlin’s event calendar
#
#     ('Berlin', 19, 25, 'GPE', 'GPE', 'Q64', 'Berlin')
#
#
# ++
#
# Location
#
#
# Berlinische Galerie - Landesmuseum für moderne Kunst, Fotografie und Architektur
#
#                                     Berlinische Galerie - Ausstellung
# Alte Jakobstraße 124
# 10969 Berlin
#
#
#
#
#     ('Berlin', 192, 198, 'GPE', 'GPE', 'Q64', 'Berlin')
#
#
# ++
#
# Grand Hyatt Berlin Career day
#
#
#
#     ('Berlin', 14, 20, 'GPE', 'GPE', 'Q64', 'Berlin')
#
#
# ++
#
# Grand Hyatt Berlin Career day
#
#
#
#     ('Berlin', 14, 20, 'GPE', 'GPE', 'Q64', 'Berlin')
#
#
# ++
#
# Location
#
#
# Hotel Grand Hyatt Berlin
#
#                                     Hotel Grand Hyatt Berlin
# Marlene-Dietrich-Platz 2
# 10785 Berlin
#
#
#
#
#     ('Berlin', 31, 37, 'GPE', 'GPE', 'Q64', 'Berlin')
#     ('Berlin', 93, 99, 'GPE', 'GPE', 'Q64', 'Berlin')
#     ('Berlin', 131, 137, 'GPE', 'GPE', 'Q64', 'Berlin')
#
#
# ++
#
# Location
#
#
# C/O Berlin (im Amerika-Haus)
#
#                                     C/O Berlin (im Amerika-Haus)
# Hardenbergstraße 22
# 10623 Berlin
#
#
#
#
#     ('Berlin', 17, 23, 'GPE', 'GPE', 'Q64', 'Berlin')
#     ('Berlin', 83, 89, 'GPE', 'GPE', 'Q64', 'Berlin')
#     ('Berlin', 134, 140, 'GPE', 'GPE', 'Q64', 'Berlin')
#
#
# ++
#
# Location
#
#
# Altstadt Spandau
#
#                                     Diverse Veranstaltungsorte in Spandau
#
#  Berlin
#
#
#
#
#     ('Berlin', 107, 113, 'GPE', 'GPE', 'Q64', 'Berlin')
#
#
# ++
#
# Location
#
#
# Haus Ungarn
#
#                                   Haus Ungarn
# 10178 Berlin
#
#
#
#
#     ('Berlin', 78, 84, 'GPE', 'GPE', 'Q64', 'Berlin')
#
#
# ++
#
# Light magic citadel - The unique Berlin Christmas event
#
#
#
#     ('Berlin', 35, 41, 'GPE', 'GPE', 'Q64', 'Berlin')
#
#
# ++
#
# Light magic citadel - The unique Berlin Christmas event
#
#
#
#     ('Berlin', 35, 41, 'GPE', 'GPE', 'Q64', 'Berlin')
#
#
# ++
#
# Location
#
#
# Zitadelle Spandau
#
#                                     Zitadelle Spandau
# Am Juliusturm
# 13599 Berlin
#
#
#
#
#     ('Am', 86, 88, 'GPE', 'GPE', 'Q1872', 'americium')
#     ('Berlin', 106, 112, 'GPE', 'GPE', 'Q64', 'Berlin')
#
#
# ++
#
# Time
#
#
#                     12:00 pm
#
#
#     ('pm', 35, 37, 'GPE PRODUCT', 'GPE PRODUCT', 'Q34617', 'Saint Pierre and Miquelon')
#
#
# ++
#
# Location
#
#
# ANOHA Kinderwelt des Jüdischen Museums Berlin
#
#                                   ANOHA Kinderwelt des Jüdischen Museums Berlin
#
#
#
#     ('Berlin', 52, 58, 'GPE', 'GPE', 'Q64', 'Berlin')
#     ('Berlin', 133, 139, 'GPE', 'GPE', 'Q64', 'Berlin')
#
#
# ++
#
# ARISE Grand Show at the Palast Berlin
#
#
#
#     ('Show', 14, 18, 'PERSON', 'PERSON', 'Q53858110', 'Manuel Luís Cafumana')
#     ('Berlin', 33, 39, 'GPE', 'GPE', 'Q64', 'Berlin')
#
#
# ++
#
# ARISE Grand Show at the Palast Berlin
#
#
#
#     ('Show', 14, 18, 'PERSON', 'PERSON', 'Q53858110', 'Manuel Luís Cafumana')
#     ('Berlin', 33, 39, 'GPE', 'GPE', 'Q64', 'Berlin')
#
#
# ++
#
# Location
#
#
# Friedrichstadt-Palast
#
#                                     Friedrichstadt-Palast
# Friedrichstraße 107
# 10117 Berlin
#
#
#
#
#     ('Berlin', 120, 126, 'GPE', 'GPE', 'Q64', 'Berlin')
#
#
# ++
#
# Location
#
#
# Museum für Naturkunde
#
#                                     Museum für Naturkunde
# Invalidenstraße 43
# 10115 Berlin
#
#
#
#
#     ('Berlin', 119, 125, 'GPE', 'GPE', 'Q64', 'Berlin')
#
#
# ++
#
# Location
#
#
# Gemäldegalerie
#
#                                     Gemäldegalerie
# Matthäikirchplatz 4
# 10785 Berlin
#
#
#
#
#     ('Berlin', 106, 112, 'GPE', 'GPE', 'Q64', 'Berlin')
#
#
# ++
#
# Location
#
#
# Spindler & Klatt
#
#                                     Spindler & Klatt
# Köpenicker Straße 16-17
# 10997 Berlin
#
#
#
#
#     ('Berlin', 114, 120, 'GPE', 'GPE', 'Q64', 'Berlin')
#
#
# ++
#
# Location
#
#
# Alte Nationalgalerie
#
#                                     Alte Nationalgalerie
# Bodestraße 1
# 10178 Berlin
#
#
#
#
#     ('Berlin', 111, 117, 'GPE', 'GPE', 'Q64', 'Berlin')
#
#
# ++
#
# Location
#
#
# James-Simon-Galerie
#
#                                     James-Simon-Galerie
# Bodestraße
# 10178 Berlin
#
#
#
#
#     ('Berlin', 107, 113, 'GPE', 'GPE', 'Q64', 'Berlin')
#
#
# ++
#
# An immersive VR trip in Berlin history
#
#
#
#     ('Berlin', 26, 32, 'GPE', 'GPE', 'Q64', 'Berlin')
#
#
# ++
#
# An immersive VR trip in Berlin history
#
#
#
#     ('Berlin', 26, 32, 'GPE', 'GPE', 'Q64', 'Berlin')
#
#
# ++
#
# Location
#
#
# Berliner Fernsehturm
#
#                                     Berliner Fernsehturm
# Panoramastraße 1A
# 10178 Berlin
#
#
#
#
#     ('Berliner', 13, 21, 'GPE', 'GPE', 'Q152526', 'Berliner')
#     ('Berliner', 71, 79, 'GPE', 'GPE', 'Q152526', 'Berliner')
#     ('Berlin', 116, 122, 'GPE', 'GPE', 'Q64', 'Berlin')
#
#
# ++
#
# Location
#
#
# Bode-Museum
#
#                                     Bode-Museum
# Am Kupfergraben 1
# 10178 Berlin
#
#
#
#
#     ('Am', 74, 76, 'GPE', 'GPE', 'Q1872', 'americium')
#     ('Berlin', 98, 104, 'GPE', 'GPE', 'Q64', 'Berlin')
#
#
# ++
#
# Location
#
#
# Neue Nationalgalerie
#
#                                     Neue Nationalgalerie
# Potsdamer Straße 50
# 10785 Berlin
#
#
#
#
#     ('Berlin', 118, 124, 'GPE', 'GPE', 'Q64', 'Berlin')
#
#
# ++
#
# Location
#
#
# Kabarett-Theater Die Stachelschweine
#
#                                     Kabarett-Theater Die Stachelschweine
# Tauentzienstraße 9-12
# 10789 Berlin
#
#
#
#
#     ('Berlin', 152, 158, 'GPE', 'GPE', 'Q64', 'Berlin')
#
#
# ++
#
# ARISE Grand Show
#
#
#
#     ('Show', 14, 18, 'PERSON', 'PERSON', 'Q53858110', 'Manuel Luís Cafumana')
#
#
# ++
#
# ARISE Grand Show
#
#
#
#     ('Show', 14, 18, 'PERSON', 'PERSON', 'Q53858110', 'Manuel Luís Cafumana')
#
#
# ++
#
# Location
#
#
# Friedrichstadt-Palast
#
#                                     Friedrichstadt-Palast
# Friedrichstraße 107
# 10117 Berlin
#
#
#
#
#     ('Berlin', 120, 126, 'GPE', 'GPE', 'Q64', 'Berlin')
#
#
# ++
#
# Time
#
#
#                     19:30 pm
#
#
#     ('pm', 35, 37, 'GPE PRODUCT', 'GPE PRODUCT', 'Q34617', 'Saint Pierre and Miquelon')
#
#
# ++
#
# Time
#
#
#                     19:30 pm
#
#
#     ('pm', 35, 37, 'GPE PRODUCT', 'GPE PRODUCT', 'Q34617', 'Saint Pierre and Miquelon')
#
#
# ++
#
# The Berlin Schlemmer Varieté
#
#
#
#     ('Berlin', 6, 12, 'GPE', 'GPE', 'Q64', 'Berlin')
#
#
# ++
#
# The Berlin Schlemmer Varieté
#
#
#
#     ('Berlin', 6, 12, 'GPE', 'GPE', 'Q64', 'Berlin')
#
#
# ++
#
# Location
#
#
# Arminius Markthalle Berlin
#
#                                     Arminius Markthalle Berlin
# Arminiusstr.
#     ('Berlin', 33, 39, 'GPE', 'GPE', 'Q64', 'Berlin')
#     ('Berlin', 97, 103, 'GPE', 'GPE', 'Q64', 'Berlin')
#
#
# ++ 2
# 10551 Berlin
#
#
#
#
#     ('Berlin', 8, 14, 'GPE', 'GPE', 'Q64', 'Berlin')
#
#
# ++ Berlin's official travel website visitBerlin.de
#     ('Berlin', 0, 6, 'GPE', 'GPE', 'Q64', 'Berlin')
#
#
# ++
# visitBerlin-Blog
# Here write the Berlin insiders
#
#     ('Berlin', 33, 39, 'GPE', 'GPE', 'Q64', 'Berlin')
#
#
# ++
#
# Berlin's official tourist ticket
#           berlin-welcomecard.de
#
#     ('Berlin', 2, 8, 'GPE', 'GPE', 'Q64', 'Berlin')
#
#
# ++
#           © Berlin Tourismus & Kongress GmbH
#
#     ('Berlin', 13, 19, 'GPE', 'GPE', 'Q64', 'Berlin')
#
# Reading from file visitberlindeentopexhibitionsberlin.json
#
# ++
#
# Berlin Unboxed: The visitBerlin Podcast
#
#
#
#
#     ('Berlin', 2, 8, 'GPE', 'GPE', 'Q64', 'Berlin')
#
#
# ++
#
# Museums in Berlin
#
#
#
#
#     ('Berlin', 13, 19, 'GPE', 'GPE', 'Q64', 'Berlin')
#
#
# ++
#
# 4 days Berlin from €190
#
#
#
#
#     ('Berlin', 9, 15, 'GPE', 'GPE', 'Q64', 'Berlin')
#
#
# ++ Must see: Highlights of Berlin’s museums and exhibition venues
#     ('Berlin', 24, 30, 'GPE', 'GPE', 'Q64', 'Berlin')
#
#
# ++ The art metropolis of Berlin inspires locals and visitors with its famous museum landscape and numerous UNESCO World Heritage sites.
#     ('Berlin', 22, 28, 'GPE', 'GPE', 'Q64', 'Berlin')
#
#
# ++ Did you know that Berlin is also the capital of sculptures?
#     ('Berlin', 18, 24, 'GPE', 'GPE', 'Q64', 'Berlin')
#
#
# ++ Turn your walk through Berlin's streets into an art-historical foray and let yourself be surprised by the unknown and the world-famous.
#     ('Berlin', 23, 29, 'GPE', 'GPE', 'Q64', 'Berlin')
#
#
# ++ The immersive pictorial effect of the Asisi panorama, in conjunction with 80 antique sculptures and new multimedia visualisations of the Pergamon Altar in the approximately 1000 square metre large exhibition setting, results in a unique and future-oriented overall concept to bring the appearance of the ancient metropolis of Pergamon back to life.
#     ('1000', 173, 177, 'CARDINAL', 'CARDINAL', 'Q43016', '1000')
#
#
# ++ Hungarian artists played an important role in the development of Classical Modernism in Berlin.
#     ('Berlin', 88, 94, 'GPE', 'GPE', 'Q64', 'Berlin')
#
#
# ++ In this first solo exhibition of clayborn "nothing left to be" in Europe, the two sculptures from the series "homegrown" (2021) take centre stage.
#     ('Europe', 66, 72, 'ORG', 'ORG', 'Q458', 'European Union')
#
#
# ++ In 2021, the US artist was awarded the Baloise Art Prize.
#     ('the US', 9, 15, 'GPE', 'GPE', 'Q30', 'United States of America')
#
#
# ++ On the occasion of the 200th birthday of Heinrich Schliemann, the Museum of Prehistory and Early History Berlin is showing Schliemann's life as a whole on the Museum Island.
#     ('Berlin', 105, 111, 'GPE', 'GPE', 'Q64', 'Berlin')
#
#
# ++ In addition to valuable pieces from theTrojan Collection of the Museum of Prehistory and Early History, first-class archaeological art objects from the National Museum of Athens as well as fascinating objects of contemporary art, for example from China, Japan, Russia and the USA, are on display.
#     ('Athens', 171, 177, 'GPE', 'GPE', 'Q1524', 'Athens')
#     ('China', 247, 252, 'ORG', 'ORG', 'Q148', "People's Republic of China")
#     ('the USA', 272, 279, 'GPE', 'GPE', 'Q30', 'United States of America')
#
#
# ++ Around 90 works by Donatello will be on display in the Gemäldegalerie this autumn: it is the first exhibition in Germany devoted entirely to the famous master of the Italian Renaissance.
#     ('autumn', 75, 81, 'DATE', 'DATE', 'Q1314', 'autumn')
#     ('Germany', 113, 120, 'GPE', 'GPE', 'Q183', 'Germany')
#
#
# ++ Seeing the familiar from a new perspective and realising how open historical processes basically are: That is the idea behind the new exhibition on the history of Germany, which examines 14 far-reaching processes in the period between 1848 and 1989.
#     ('Germany', 163, 170, 'GPE', 'GPE', 'Q183', 'Germany')
#
#
# ++ The works of the sculptor Johann Gottfried Schadow (1764 - 1850) embody German classicism like no other, among them the famous life-size "Princess Group", Schadow's main work.
#     ('German', 72, 78, 'NORP', 'NORP', 'Q188', 'German')
#
#
# ++ The double statue of two female historical Berlin personalities is the first of its kind in art history.
#     ('Berlin', 43, 49, 'GPE', 'GPE', 'Q64', 'Berlin')
#
#
# ++ Immerse yourself in the multitude of sculptures, graphics and paintings by the Berlin artist.
#     ('Berlin', 79, 85, 'GPE', 'GPE', 'Q64', 'Berlin')
#
#
# ++ Today, the often still existing original colours of the objects and their luminosity are just as fascinating as the diversity of the figurative representations.
#     ('Today', 0, 5, 'DATE', 'DATE', 'Q130838', 'Today')
#
#
# ++ YOYI is the name given by the Tiwi people of northern Australia to a ceremony in which they celebrate and mourn together through song and dance.
#     ('Australia', 54, 63, 'GPE', 'GPE', 'Q408', 'Australia')
#
#
# ++ The permanent exhibition Berlin Global at the Humboldt Forum puts Berlin in relation to the world.
#     ('Berlin', 25, 31, 'GPE', 'GPE', 'Q64', 'Berlin')
#     ('Berlin', 66, 72, 'GPE', 'GPE', 'Q64', 'Berlin')
#
#
# ++ Based on individual aspects such as revolution, freedom, borders, pleasure, war, fashion and interconnectedness, the exhibition tells the story of Berlin.
#     ('Berlin', 147, 153, 'GPE', 'GPE', 'Q64', 'Berlin')
#
#
# ++ Your entrance tickets to Berlin
#     ('Berlin', 25, 31, 'GPE', 'GPE', 'Q64', 'Berlin')
#
#
# ++ Show details
#
#     ('Show', 0, 4, 'PERSON', 'PERSON', 'Q53858110', 'Manuel Luís Cafumana')
#
#
# ++ The best deals for your Berlin trip
#     ('Berlin', 24, 30, 'GPE', 'GPE', 'Q64', 'Berlin')
#
#
# ++ Attractive prices for your city trip to Berlin.
#     ('Berlin', 40, 46, 'GPE', 'GPE', 'Q64', 'Berlin')
#
#
# ++ Show details
#
#     ('Show', 0, 4, 'PERSON', 'PERSON', 'Q53858110', 'Manuel Luís Cafumana')
#
#
# ++ Design-Bestseller on Friedrichstraße is the first address for interior enthusiasts in Berlin.
#     ('Berlin', 86, 92, 'GPE', 'GPE', 'Q64', 'Berlin')
#
#
# ++ Berlin's official travel website visitBerlin.de
#     ('Berlin', 0, 6, 'GPE', 'GPE', 'Q64', 'Berlin')
#
#
# ++
# visitBerlin-Blog
# Here write the Berlin insiders
#
#     ('Berlin', 33, 39, 'GPE', 'GPE', 'Q64', 'Berlin')
#
#
# ++
#
# Berlin's official tourist ticket
#           berlin-welcomecard.de
#
#     ('Berlin', 2, 8, 'GPE', 'GPE', 'Q64', 'Berlin')
#
#
# ++
#           © Berlin Tourismus & Kongress GmbH
#
#     ('Berlin', 13, 19, 'GPE', 'GPE', 'Q64', 'Berlin')
#
# Reading from file visitberlindeentravellingberlin.json
#
# ++
#
# Berlin Unboxed: The visitBerlin Podcast
#
#
#
#
#     ('Berlin', 2, 8, 'GPE', 'GPE', 'Q64', 'Berlin')
#
#
# ++
#
# Museums in Berlin
#
#
#
#
#     ('Berlin', 13, 19, 'GPE', 'GPE', 'Q64', 'Berlin')
#
#
# ++
#
# 4 days Berlin from €190
#
#
#
#
#     ('Berlin', 9, 15, 'GPE', 'GPE', 'Q64', 'Berlin')
#
#
# ++ The best way for you to get to Berlin – by car, by train, by coach: you can get to Berlin easily and comfortably.
#     ('way', 9, 12, 'PERSON', 'PERSON', 'Q17641254', 'Andrew John Henry Way')
#     ('Berlin', 31, 37, 'GPE', 'GPE', 'Q64', 'Berlin')
#     ('Berlin', 83, 89, 'GPE', 'GPE', 'Q64', 'Berlin')
#
#
# ++ With its own railroad station below Terminal 1, the new Berlin Brandenburg Airport (BER) is directly connected to the rail network.
#     ('Berlin', 56, 62, 'GPE', 'GPE', 'Q64', 'Berlin')
#
#
# ++ You can also get to the capital quickly and safely from German ports by train or car: everything you need to know about arrival by boat.
#     ('German', 56, 62, 'NORP', 'NORP', 'Q188', 'German')
#
#
# ++ Our tip: With the Bahnhit Berlin you can travel to Berlin at a low price: train ride and hotel are included.
#     ('Berlin', 26, 32, 'GPE', 'GPE', 'Q64', 'Berlin')
#     ('Berlin', 51, 57, 'GPE', 'GPE', 'Q64', 'Berlin')
#
#
# ++
# Welcome to the new airport Berlin Brandenburg BER
#
#
#
#     ('Berlin', 28, 34, 'GPE', 'GPE', 'Q64', 'Berlin')
#
#
# ++
# Camping sites in Berlin
#
#
#     ('Berlin', 18, 24, 'GPE', 'GPE', 'Q64', 'Berlin')
#
#
# ++ We've put together everything you need to know about getting to Berlin by train, by car or by coach in a handy little package.
#     ('Berlin', 64, 70, 'GPE', 'GPE', 'Q64', 'Berlin')
#
#
# ++ This way, you’ll get your bearings in advance and will arrive in the German capital without any stress.
#     ('way', 5, 8, 'PERSON', 'PERSON', 'Q17641254', 'Andrew John Henry Way')
#     ('German', 69, 75, 'NORP', 'NORP', 'Q188', 'German')
#
#
# ++ If you’re driving a car or a coach, please note: downtown Berlin is an environmental zone.
#     ('Berlin', 58, 64, 'GPE', 'GPE', 'Q64', 'Berlin')
#
#
# ++
#                 Berlin's official tourist ticket
#
#     ('Berlin', 17, 23, 'GPE', 'GPE', 'Q64', 'Berlin')
#
#
# ++
# More about the Berlin WelcomeCard
#
#     ('Berlin', 16, 22, 'GPE', 'GPE', 'Q64', 'Berlin')
#
#
# ++ You want to get from the airport to the city or discover Berlin's sights by S-Bahn, U-Bahn, streetcar (tram) and bus.
#     ('Berlin', 57, 63, 'GPE', 'GPE', 'Q64', 'Berlin')
#     ('U-Bahn', 84, 90, 'ORG', '', 'Q5503', 'rapid transit')
#
#
# ++ The public transport network is well developed throughout Berlin.
#     ('Berlin', 58, 64, 'GPE', 'GPE', 'Q64', 'Berlin')
#
#
# ++ Our video shows you how public transport works in Berlin.
#     ('Berlin', 50, 56, 'GPE', 'GPE', 'Q64', 'Berlin')
#
#
# ++ How to buy the right ticket and find your way around the subway network.
#     ('way', 42, 45, 'PERSON', 'PERSON', 'Q17641254', 'Andrew John Henry Way')
#
#
# ++ Also find info on fares, timetables and the zones in Berlin's public transport area.
#     ('Berlin', 53, 59, 'GPE', 'GPE', 'Q64', 'Berlin')
#
#
# ++ By the way: The new Berlin Brandenburg Airport BER is directly connected to the public transport network.
#     ('way', 7, 10, 'PERSON', 'PERSON', 'Q17641254', 'Andrew John Henry Way')
#     ('Berlin', 20, 26, 'GPE', 'GPE', 'Q64', 'Berlin')
#
#
# ++ And of course we'll tell you the best routes for sightseeing by public transport, something with the new U5 subway line.
#     ('U5', 105, 107, 'FAC', '', 'Q99711', 'U5')
#
#
# ++ Tip: With the Berlin WelcomeCard you can travel for free on public transport and get discounts for Berlin highlights on top of that!
#     ('Berlin', 14, 20, 'GPE', 'GPE', 'Q64', 'Berlin')
#     ('Berlin', 99, 105, 'GPE', 'GPE', 'Q64', 'Berlin')
#
#
# ++ Berlin WelcomeCard
#     ('Berlin', 0, 6, 'GPE', 'GPE', 'Q64', 'Berlin')
#
#
# ++ Public transportation is the most convenient way to travel around Berlin.
#     ('way', 45, 48, 'PERSON', 'PERSON', 'Q17641254', 'Andrew John Henry Way')
#     ('Berlin', 66, 72, 'GPE', 'GPE', 'Q64', 'Berlin')
#
#
# ++ Check out our 101 guide on Berlin public transportation.
#     ('Berlin', 27, 33, 'GPE', 'GPE', 'Q64', 'Berlin')
#
#
# ++
# Show details
#
#
#
#     ('Show', 1, 5, 'PERSON', 'PERSON', 'Q53858110', 'Manuel Luís Cafumana')
#
#
# ++ Berlin’s public transport will take you to almost every sight in Berlin.
#     ('Berlin', 0, 6, 'GPE', 'GPE', 'Q64', 'Berlin')
#     ('Berlin', 65, 71, 'GPE', 'GPE', 'Q64', 'Berlin')
#
#
# ++ By combining the S-Bahn (city train), U-Bahn (metro), tram and bus
#     ('U-Bahn', 38, 44, 'ORG', '', 'Q5503', 'rapid transit')
#     ('metro', 46, 51, 'FAC', '', 'Q5503', 'rapid transit')
#
#
# ++
# Show details
#
#
#
#     ('Show', 1, 5, 'PERSON', 'PERSON', 'Q53858110', 'Manuel Luís Cafumana')
#
#
# ++
# 7 ways to explore Berlin
#
#     ('Berlin', 19, 25, 'GPE', 'GPE', 'Q64', 'Berlin')
#
#
# ++ Many of Berlin's sights are easily reachable by public transport.
#     ('Berlin', 8, 14, 'GPE', 'GPE', 'Q64', 'Berlin')
#
#
# ++
# Show details
#
#
#
#     ('Show', 1, 5, 'PERSON', 'PERSON', 'Q53858110', 'Manuel Luís Cafumana')
#
#
# ++ Get information and advice for your Berlin visit from the experts at the Berlin Tourist Information Offices dotted around the city.
#     ('Berlin', 36, 42, 'GPE', 'GPE', 'Q64', 'Berlin')
#     ('Berlin', 73, 79, 'GPE', 'GPE', 'Q64', 'Berlin')
#
#
# ++
# Show details
#
#
#
#     ('Show', 1, 5, 'PERSON', 'PERSON', 'Q53858110', 'Manuel Luís Cafumana')
#
#
# ++
# The best deals for your Berlin trip
#
#     ('Berlin', 25, 31, 'GPE', 'GPE', 'Q64', 'Berlin')
#
#
# ++ Attractive prices for your city trip to Berlin.
#     ('Berlin', 40, 46, 'GPE', 'GPE', 'Q64', 'Berlin')
#
#
# ++
# Show details
#
#
#
#     ('Show', 1, 5, 'PERSON', 'PERSON', 'Q53858110', 'Manuel Luís Cafumana')
#
#
# ++ Our Berlin hotels are hits with young and old.
#     ('Berlin', 4, 10, 'GPE', 'GPE', 'Q64', 'Berlin')
#
#
# ++
# Show details
#
#
#
#     ('Show', 1, 5, 'PERSON', 'PERSON', 'Q53858110', 'Manuel Luís Cafumana')
#
#
# ++ Berlin's official travel website visitBerlin.de
#     ('Berlin', 0, 6, 'GPE', 'GPE', 'Q64', 'Berlin')
#
#
# ++
# visitBerlin-Blog
# Here write the Berlin insiders
#
#     ('Berlin', 33, 39, 'GPE', 'GPE', 'Q64', 'Berlin')
#
#
# ++
#
# Berlin's official tourist ticket
#           berlin-welcomecard.de
#
#     ('Berlin', 2, 8, 'GPE', 'GPE', 'Q64', 'Berlin')
#
#
# ++
#           © Berlin Tourismus & Kongress GmbH
#
#     ('Berlin', 13, 19, 'GPE', 'GPE', 'Q64', 'Berlin')
#
# Reading from file visitberlindeentravelplanning.json
#
# ++
#
# Berlin Unboxed: The visitBerlin Podcast
#
#
#
#
#     ('Berlin', 2, 8, 'GPE', 'GPE', 'Q64', 'Berlin')
#
#
# ++
#
# Museums in Berlin
#
#
#
#
#     ('Berlin', 13, 19, 'GPE', 'GPE', 'Q64', 'Berlin')
#
#
# ++
#
# 4 days Berlin from €190
#
#
#
#
#     ('Berlin', 9, 15, 'GPE', 'GPE', 'Q64', 'Berlin')
#
#
# ++
# Important infos for your trip to Berlin
#
#     ('Berlin', 34, 40, 'GPE', 'GPE', 'Q64', 'Berlin')
#
#
# ++ What is the best way to get to Berlin?
#     ('way', 17, 20, 'PERSON', 'PERSON', 'Q17641254', 'Andrew John Henry Way')
#     ('Berlin', 31, 37, 'GPE', 'GPE', 'Q64', 'Berlin')
#
#
# ...
#     ('not', 63, 66, 'ORG', 'ORG', 'Q18035109', 'ALG3')
#     ('Berlin', 160, 166, 'GPE', 'GPE', 'Q64', 'Berlin')
#
#
# ++ From 1 july 2020, we will also be back again and offer our regular guided tours in Italian, Spanish and French as usual.
#     ('Spanish', 92, 99, 'NORP', 'NORP', 'Q1321', 'Spanish')
#
#
# ++ In German, Portuguese and English you can still contact us directly for a private guided tour in Berlin; we are always at your disposal.
#     ('German', 3, 9, 'NORP', 'NORP', 'Q188', 'German')
#     ('Berlin', 97, 103, 'GPE', 'GPE', 'Q64', 'Berlin')
#
#
# ++ Vive Berlin Tours will finally return in full and in a variety of ways with all its group and individual offers in and around Berlin from July 1st, 2020!
#     ('Berlin', 5, 11, 'GPE', 'GPE', 'Q64', 'Berlin')
#     ('Berlin', 126, 132, 'GPE', 'GPE', 'Q64', 'Berlin')
#
#
# ++ In March, we were therefore the first tourist company in Berlin who cancelled all guided tours, two weeks before the measures imposed by the German government.
#     ('Berlin', 57, 63, 'GPE', 'GPE', 'Q64', 'Berlin')
#     ('German', 141, 147, 'NORP', 'NORP', 'Q188', 'German')
#
#
# ++ We have come to the conclusion that we can offer you an unforgettable experience in our city of Berlin even under these still unusual circumstances.
#     ('Berlin', 96, 102, 'GPE', 'GPE', 'Q64', 'Berlin')
#
#
# ++ Of course, we also look forward to welcome you soon in Berlin and accompanying you on your chosen tour, so that you can discover this incredible city for yourself, with all the security and passion that distinguishes us from the rest in our profession.
#     ('Berlin', 55, 61, 'GPE', 'GPE', 'Q64', 'Berlin')
#
#
# ++ Your email address will not be published.
#     ('not', 24, 27, 'ORG', 'ORG', 'Q18035109', 'ALG3')
#
#
# ++ Copyright © Vive Berlin 2008-2021.
#     ('Berlin', 17, 23, 'GPE', 'GPE', 'Q64', 'Berlin')
#
#
# ++ 16 / 10785 Berlin.
#     ('Berlin', 11, 17, 'GPE', 'GPE', 'Q64', 'Berlin')
#
# Reading from file viveberlintourscomenviveberlinandthestumblingstones.json
#
# ++ The installation of six Stumbling Stones (Stolpersteine) in Berlin brought together the only living survivor of ae family and twenty-two descendants from England, Israel, and Argentina.
#     ('Berlin', 60, 66, 'GPE', 'GPE', 'Q64', 'Berlin')
#
#
# ++ Events like the one narrated by Blas make us especially proud; they distinguish the commitment and dedication that we put into our work as Berlin tourist guides.
#     ('Berlin', 139, 145, 'GPE', 'GPE', 'Q64', 'Berlin')
#
#
# ++ In addition to showing the city to all those who wish to discover it, we are dedicated to keeping Berlin’s tragic and fascinating history alive.
#     ('Berlin', 98, 104, 'GPE', 'GPE', 'Q64', 'Berlin')
#
#
# ++ There is something very special about Berlin.
#     ('Berlin', 38, 44, 'GPE', 'GPE', 'Q64', 'Berlin')
#
#
# ++ The history we talk about during the guided tours is the history of the people you meet on the street, not something abstract or distant.
#     ('not', 103, 106, 'ORG', 'ORG', 'Q18035109', 'ALG3')
#
#
# ++ Mauricio, Magda, Julio and Edith took part in the group guided tour “Berlin during the Third Reich” with our tourist guide cooperative.
#     ('Berlin', 69, 75, 'GPE', 'GPE', 'Q64', 'Berlin')
#
#
# ++ At the end of the tour, we started talking about the approach we take during our guided tours of Berlin.
#     ('Berlin', 97, 103, 'GPE', 'GPE', 'Q64', 'Berlin')
#
#
# ++ The family was particularly struck by our way of working, by how we presented such delicate subjects and by the choice of places visited during the tour Berlin in the III Reich.
#     ('way', 42, 45, 'PERSON', 'PERSON', 'Q17641254', 'Andrew John Henry Way')
#     ('Berlin', 153, 159, 'GPE', 'GPE', 'Q64', 'Berlin')
#
#
# ++ Following this conversation, Mauricio confided in me that he came from a Jewish family and that his grandparents had been killed in Berlin in 1938.
#     ('Berlin', 132, 138, 'GPE', 'GPE', 'Q64', 'Berlin')
#
#
# ++ The mother, a child at the time, had managed to escape from Nazi Germany and reached Argentina, where Mauricio was born.
#     ('Germany', 65, 72, 'GPE', 'GPE', 'Q183', 'Germany')
#
#
# ++ Intimate information had been confided in me, and it was clear that these four customers were not only tourists interested in getting to know Berlin during the holidays, but three people who accompanying a fourth man on his journey towards back to roots and terrible family past.
#     ('not', 94, 97, 'ORG', 'ORG', 'Q18035109', 'ALG3')
#     ('Berlin', 142, 148, 'GPE', 'GPE', 'Q64', 'Berlin')
#
#
# ++ Before starting the tour I told Mauricio that I had found the name of his grandfather in the list of heads of Berlin families from 1938, but not in the list of victims of the Night of Crystals, and that I could confirm the fire in the building where his grandparents had lived on the night of November 9th.
#     ('Berlin', 110, 116, 'GPE', 'GPE', 'Q64', 'Berlin')
#     ('not', 141, 144, 'ORG', 'ORG', 'Q18035109', 'ALG3')
#     ('November', 293, 301, 'DATE', 'DATE', 'Q125', 'November')
#
#
# ++ This was the administrative proof that his grandparents, or at least his grandfather, had not died in 1938 as the family thought.
#     ('not', 90, 93, 'ORG', 'ORG', 'Q18035109', 'ALG3')
#
#
# ++ At the end of the guided tour of the city of Potsdam I asked them if they wanted to be accompanied to the place where the grandparents’ house was and where Mauricio’s mother had spent her childhood.
#     ('house', 136, 141, 'ORG', 'ORG', 'Q20502', 'house music')
#
#
# ++ The group left Berlin and I took care of adding them to the waiting list of the Stolpersteine project by contacting the local association responsible for the installation of Stumbling Stones.
#     ('Berlin', 15, 21, 'GPE', 'GPE', 'Q64', 'Berlin')
#
#
# ++ Stumbling Stones, in German Stolpersteine, are small 10cm x 10cm cobblestones with a brass surface that are installed flush with the sidewalks so that no one can actually trip over them.
#     ('German', 21, 27, 'NORP', 'NORP', 'Q188', 'German')
#
#
# ++ Under the title “Hier wohnte” – “Here lived” the name, date of birth and deportation date are reported, as well as the place where the victim of Nazism was murdered.
#     ('Hier', 17, 21, 'PERSON', '', 'Q37503541', 'Hier')
#
#
# ++ With the Stumbling Stones, the history of the victims of Nazism in our daily life is reported directly in front of the house where the victim lived.
#     ('house', 119, 124, 'ORG', 'ORG', 'Q20502', 'house music')
#
#
# ++ The Stumbling Stones project was initiated by the German artist Gunter Demnig.
#     ('German', 50, 56, 'NORP', 'NORP', 'Q188', 'German')
#
#
# ++ Since November 2000, about 70,000 have been laid, both in Germany and in other European countries from which the death trains departed.
#     ('Germany', 58, 65, 'GPE', 'GPE', 'Q183', 'Germany')
#
#
# ++ I continued my investigations in the following weeks, discovering that Mauricio’s grandfather, David, was deported to the Sachsenhausen concentration camp, a few kilometers from Berlin.
#     ('Berlin', 178, 184, 'GPE', 'GPE', 'Q64', 'Berlin')
#
#
# ++ Marja, his grandmother, was probably murdered in Auschwitz, I say probably because in her case there is no definitive certainty but only indications that suggest that she was deported to the extermination camps of the East.
#     ('East', 218, 222, 'LOC', '', 'Q684', 'east')
#
#
# ++ On September 8, 2017, the descendants of Marja and David, from 3 different continents (Argentina, Israel, and England), met, some for the first time, at number 10 Kleine Auguststraße in the Mitte neighborhood of Berlin.
#     ('Berlin', 212, 218, 'GPE', 'GPE', 'Q64', 'Berlin')
#
#
# ++ Gunter Demnig, the artist who had the idea of putting these little memorials on the streets and who still takes care of their installation, installed two Stumbling Stones in the sidewalk in front of the place where the synagogue had been located for those who were killed by National Socialism and for their children, who managed to escape clandestinely from Germany, separating in four different directions.
#     ('Germany', 359, 366, 'GPE', 'GPE', 'Q183', 'Germany')
#
#
# ++ Among those who were part of the family group was the last surviving child of David and Marja, Itzchak “Isi”, a 90-year-old man, and probably one of the last Jews to have had his Bar Mitzvah in Berlin.
#     ('Berlin', 194, 200, 'GPE', 'GPE', 'Q64', 'Berlin')
#
#
# ++ In the city from which he had fled and in the street where he had seen his house burned on the night of November 9, 1938, while firemen watched passively, because what burned was Jewish property.
#     ('house', 75, 80, 'ORG', 'ORG', 'Q20502', 'house music')
#     ('November', 104, 112, 'DATE', 'DATE', 'Q125', 'November')
#
#
# ++ Isi, so they call him in the family, had managed to leave Berlin clandestinely and had arrived after three years of ups and downs in Palestine, where he now lives with his children and grandchildren.
#     ('Berlin', 58, 64, 'GPE', 'GPE', 'Q64', 'Berlin')
#
#
# ++ Isi smiled at me and said: “Sie können mit mir gerne auf Deutsch reden, Ich habe sehr lange diese Sprache nicht gesprochen, aber wir können es so machen” – “You can speak to me in German.
#     ('mit', 39, 42, 'ORG', 'ORG', 'Q843297', 'Iwate Menkoi Television')
#     ('es', 140, 142, 'NORP', 'NORP', 'Q1321', 'Spanish')
#     ('German', 180, 186, 'NORP', 'NORP', 'Q188', 'German')
#
#
# ++ For me, with a German mother, and therefore a grandchild of the generation responsible for the Holocaust, it was an extremely moving moment.
#     ('German', 15, 21, 'NORP', 'NORP', 'Q188', 'German')
#
#
# ++ At the Stumbling Stone installation ceremony, Mauricio said: “The Stolpersteine represent in some way the tomb that my grandparents do not have”.
#     ('way', 98, 101, 'PERSON', 'PERSON', 'Q17641254', 'Andrew John Henry Way')
#     ('not', 135, 138, 'ORG', 'ORG', 'Q18035109', 'ALG3')
#
#
# ++ Isi added a phrase I later adopted to describe what I believe our job is as Berlin ambassadors: “I’m not here to close a cycle, but to put an extra link in a long chain of events“.
#     ('Berlin', 76, 82, 'GPE', 'GPE', 'Q64', 'Berlin')
#     ('not', 101, 104, 'ORG', 'ORG', 'Q18035109', 'ALG3')
#
#
# ++ I personally believe that the profession of tourist guide is a two-way street: changing the experience of those who accompany us and being open to our customers to change ourselves.
#     ('way', 67, 70, 'PERSON', 'PERSON', 'Q17641254', 'Andrew John Henry Way')
#
#
# ++ Copyright © Vive Berlin 2008-2021.
#     ('Berlin', 17, 23, 'GPE', 'GPE', 'Q64', 'Berlin')
#
#
# ++ 16 / 10785 Berlin.
#     ('Berlin', 11, 17, 'GPE', 'GPE', 'Q64', 'Berlin')
#
# Reading from file viveberlintourscomfr.json
#
# ++ Découvrez Berlin comme vous ne l’avez jamais imaginé avec des visites guidées en français à fort contenu historique et culturel.
#     ('Berlin', 10, 16, 'GPE', 'GPE', 'Q64', 'Berlin')
#
#
# ++ Nous vous proposons des itinéraires qui vous permettent de connaître tous les aspects fondamentaux de la ville.
#     ('de', 56, 58, 'NORP', ['NORP', 'GPE'], ['Q188', 'Q183'], ['German', 'Germany'])
#     ('de', 99, 101, 'NORP', ['NORP', 'GPE'], ['Q188', 'Q183'], ['German', 'Germany'])
#
#
# ++ Du plus classique au plus particulier.
#     ('au', 18, 20, 'GPE', 'GPE', 'Q408', 'Australia')
#
#
# ++ Découvrez nos offres et vous comprendrez pourquoi nos visites en français à Berlin reçoivent les meilleures notes sur TripAdvisor et les médias sociaux.
#     ('Berlin', 76, 82, 'GPE', 'GPE', 'Q64', 'Berlin')
#
#
# ++ Vive Berlin Tours : la meilleure façon de découvrir Berlin !
#     ('Berlin', 5, 11, 'GPE', 'GPE', 'Q64', 'Berlin')
#     ('de', 39, 41, 'NORP', ['NORP', 'GPE'], ['Q188', 'Q183'], ['German', 'Germany'])
#     ('Berlin', 52, 58, 'GPE', 'GPE', 'Q64', 'Berlin')
#
#
# ++ Apprenez en plus sur nos mesures de prévention du Covid-19.
#     ('de', 33, 35, 'NORP', ['NORP', 'GPE'], ['Q188', 'Q183'], ['German', 'Germany'])
#
#
# ++ Copyright © Vive Berlin 2008-2021.
#     ('Berlin', 17, 23, 'GPE', 'GPE', 'Q64', 'Berlin')
#
#
# ++ 16 / 10785 Berlin.
#     ('Berlin', 11, 17, 'GPE', 'GPE', 'Q64', 'Berlin')
#
# Reading from file viveberlintourscomimpressum.json
#
# ++ Angaben gemäß § 5 TMG: Vive Berlin e.G. | Flottwellstr.
#     ('Berlin', 28, 34, 'GPE', 'GPE', 'Q64', 'Berlin')
#
#
# ++ 16 | 10785 Berlin
#     ('Berlin', 11, 17, 'GPE', 'GPE', 'Q64', 'Berlin')
#
#
# ++ Die Inhalte unserer Seiten wurden mit größter Sorgfalt erstellt.
#     ('mit', 34, 37, 'ORG', 'ORG', 'Q843297', 'Iwate Menkoi Television')
#
#
# ++ Nach §§ 8 bis 10 TMG sind wir als Diensteanbieter jedoch nicht verpflichtet, übermittelte oder gespeicherte fremde Informationen zu überwachen oder nach Umständen zu forschen, die auf eine rechtswidrige Tätigkeit hinweisen.
#     ('bis', 10, 13, 'ORG', 'ORG', 'Q2074546', 'bisj pole')
#     ('zu', 129, 131, 'GPE', 'GPE', 'Q10179', 'Zulu')
#     ('zu', 163, 165, 'GPE', 'GPE', 'Q10179', 'Zulu')
#
#
# ++ Eine diesbezügliche Haftung ist jedoch erst ab dem Zeitpunkt der Kenntnis einer konkreten Rechtsverletzung möglich.
#     ('ab', 44, 46, 'NORP', 'NORP', 'Q5111', 'Abkhaz')
#
#
# ++ Unser Angebot enthält Links zu externen Webseiten Dritter, auf deren Inhalte wir keinen Einfluss haben.
#     ('zu', 28, 30, 'GPE', 'GPE', 'Q10179', 'Zulu')
#
#
# ++ Eine permanente inhaltliche Kontrolle der verlinkten Seiten ist jedoch ohne konkrete Anhaltspunkte einer Rechtsverletzung nicht zumutbar.
#     ('Eine', 0, 4, 'ORG', '', 'Q2693730', 'Eine')
#
#
# ++ Copyright © Vive Berlin 2008-2021.
#     ('Berlin', 17, 23, 'GPE', 'GPE', 'Q64', 'Berlin')
#
#
# ++ 16 / 10785 Berlin.
#     ('Berlin', 11, 17, 'GPE', 'GPE', 'Q64', 'Berlin')
#
# Reading from file viveberlintourscomit.json
#
# ++ Copyright © Vive Berlin 2008-2021.
#     ('Berlin', 17, 23, 'GPE', 'GPE', 'Q64', 'Berlin')
#
#
# ++ 16 / 10785 Berlin.
#     ('Berlin', 11, 17, 'GPE', 'GPE', 'Q64', 'Berlin')
#
# Reading from file viveberlintourscom.json
#
# ++ Descubre y disfruta Berlín como nunca imaginaste con visitas guiadas de alto contenido histórico y cultural.
#     ('de', 69, 71, 'NORP', ['NORP', 'GPE'], ['Q188', 'Q183'], ['German', 'Germany'])
#
#
# ++ Hemos preparado para ti rutas que nadie más ofrece, además de los paseos más clásicos, para que te lleves una experiencia inolvidable de tu viaje a Berlín.
#     ('de', 59, 61, 'NORP', ['NORP', 'GPE'], ['Q188', 'Q183'], ['German', 'Germany'])
#     ('de', 134, 136, 'NORP', ['NORP', 'GPE'], ['Q188', 'Q183'], ['German', 'Germany'])
#
#
# ++ Revisa nuestro catálogo de tours en Berlín y descubre por qué los viajeros nos confieren las mejores valoraciones y comentarios en TripAdvisor.
#     ('de', 24, 26, 'NORP', ['NORP', 'GPE'], ['Q188', 'Q183'], ['German', 'Germany'])
#
#
# ++  Deja que te acompañemos a descubrir la fascinante capital de Alemania.
#     ('de', 59, 61, 'NORP', ['NORP', 'GPE'], ['Q188', 'Q183'], ['German', 'Germany'])
#
#
# ++ Para los numerosos tours privados que proponemos estamos disponibles cualquier día de la semana.
#     ('de', 83, 85, 'NORP', ['NORP', 'GPE'], ['Q188', 'Q183'], ['German', 'Germany'])
#
#
# ++ Copyright © Vive Berlin 2008-2021.
#     ('Berlin', 17, 23, 'GPE', 'GPE', 'Q64', 'Berlin')
#
#
# ++ 16 / 10785 Berlin.
#     ('Berlin', 11, 17, 'GPE', 'GPE', 'Q64', 'Berlin')
#
# Reading from file viveberlintourscompt.json
#
# ++ Descubra e aproveite Berlim como você nunca imaginou com visitas guiadas de alto conteúdo histórico e cultural.
#     ('de', 73, 75, 'NORP', ['NORP', 'GPE'], ['Q188', 'Q183'], ['German', 'Germany'])
#
#
# ++ Confira as nossas ofertas de tours em Berlim em português e descubra porque recebemos as melhores avaliações no TripAdvisor.
#     ('de', 26, 28, 'NORP', ['NORP', 'GPE'], ['Q188', 'Q183'], ['German', 'Germany'])
#
#
# ++ Conheça a capital alemã na companhia de guias experientes e com formação acadêmica, preparados para oferecer o melhor passeio para você.
#     ('de', 37, 39, 'NORP', ['NORP', 'GPE'], ['Q188', 'Q183'], ['German', 'Germany'])
#
#
# ++ Copyright © Vive Berlin 2008-2021.
#     ('Berlin', 17, 23, 'GPE', 'GPE', 'Q64', 'Berlin')
#
#
# ++ 16 / 10785 Berlin.
#     ('Berlin', 11, 17, 'GPE', 'GPE', 'Q64', 'Berlin')
#
# Reading from file wordpressorg.json
#
# ++ Style it your way
#     ('way', 14, 17, 'PERSON', 'PERSON', 'Q17641254', 'Andrew John Henry Way')
#
#
# Saved 13601 extracted_sentences
