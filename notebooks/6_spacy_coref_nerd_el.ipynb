# %% [markdown]
# # Coreference Resolution

# %%
###########################################################
# IMPORTANT NOTE: 
# In this notebook we use an experimental spaCy model 
# named "en_coreference_web_trf", which is not part of the 
# official library. At the current date, the official 
# documentation is unaccurate regarding the version used
# in this tutorial. We can expect an update on the spaCy's
# documentation: https://spacy.io/api/coref
###########################################################

# %% [markdown]
# ## #1. Setup development environment

# %% [markdown]
# ###Update & import Python modules

# %%
import locale
def getpreferredencoding(do_setlocale = True):
    return "UTF-8"
locale.getpreferredencoding = getpreferredencoding

# %%
# install and download spaCy related modules and dependencies
# !pip install "spacy~=3.4.4"
# !python -m spacy download en_core_web_lg
# !pip install https://github.com/explosion/spacy-experimental/releases/download/v0.6.0/en_coreference_web_trf-3.4.0a0-py3-none-any.whl

# spaCy
import spacy
from spacy.language import Language
from spacy.tokens import DocBin, Span
from spacy.matcher import PhraseMatcher
from spacy.kb import KnowledgeBase
from spacy.training import Example
from spacy.ml.models import load_kb
from spacy.util import minibatch, compounding

# Google Drive
from google.colab import drive

# Firebase/Firestore
import firebase_admin
from firebase_admin import credentials
from firebase_admin import firestore

# general Python modules
import json
import datetime
import requests
import csv
import random
from collections import Counter
from pprint import pprint
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: spacy~=3.4.4 in /usr/local/lib/python3.8/dist-packages (3.4.4)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<1.11.0,>=1.7.4 in /usr/local/lib/python3.8/dist-packages (from spacy~=3.4.4) (1.10.4)
# Requirement already satisfied: langcodes<4.0.0,>=3.2.0 in /usr/local/lib/python3.8/dist-packages (from spacy~=3.4.4) (3.3.0)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in /usr/local/lib/python3.8/dist-packages (from spacy~=3.4.4) (1.0.9)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in /usr/local/lib/python3.8/dist-packages (from spacy~=3.4.4) (1.0.4)
# Requirement already satisfied: wasabi<1.1.0,>=0.9.1 in /usr/local/lib/python3.8/dist-packages (from spacy~=3.4.4) (0.10.1)
# Requirement already satisfied: typer<0.8.0,>=0.3.0 in /usr/local/lib/python3.8/dist-packages (from spacy~=3.4.4) (0.7.0)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in /usr/local/lib/python3.8/dist-packages (from spacy~=3.4.4) (2.25.1)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.10 in /usr/local/lib/python3.8/dist-packages (from spacy~=3.4.4) (3.0.12)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in /usr/local/lib/python3.8/dist-packages (from spacy~=3.4.4) (4.64.1)
# Requirement already satisfied: smart-open<7.0.0,>=5.2.1 in /usr/local/lib/python3.8/dist-packages (from spacy~=3.4.4) (6.3.0)
# Requirement already satisfied: srsly<3.0.0,>=2.4.3 in /usr/local/lib/python3.8/dist-packages (from spacy~=3.4.4) (2.4.5)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.8/dist-packages (from spacy~=3.4.4) (57.4.0)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.8/dist-packages (from spacy~=3.4.4) (23.0)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in /usr/local/lib/python3.8/dist-packages (from spacy~=3.4.4) (3.0.8)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.8/dist-packages (from spacy~=3.4.4) (2.11.3)
# Requirement already satisfied: numpy>=1.15.0 in /usr/local/lib/python3.8/dist-packages (from spacy~=3.4.4) (1.21.6)
# Requirement already satisfied: pathy>=0.3.5 in /usr/local/lib/python3.8/dist-packages (from spacy~=3.4.4) (0.10.1)
# Requirement already satisfied: thinc<8.2.0,>=8.1.0 in /usr/local/lib/python3.8/dist-packages (from spacy~=3.4.4) (8.1.7)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in /usr/local/lib/python3.8/dist-packages (from spacy~=3.4.4) (2.0.8)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in /usr/local/lib/python3.8/dist-packages (from spacy~=3.4.4) (2.0.7)
# Requirement already satisfied: typing-extensions>=4.2.0 in /usr/local/lib/python3.8/dist-packages (from pydantic!=1.8,!=1.8.1,<1.11.0,>=1.7.4->spacy~=3.4.4) (4.4.0)
# Requirement already satisfied: chardet<5,>=3.0.2 in /usr/local/lib/python3.8/dist-packages (from requests<3.0.0,>=2.13.0->spacy~=3.4.4) (4.0.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.8/dist-packages (from requests<3.0.0,>=2.13.0->spacy~=3.4.4) (2022.12.7)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.8/dist-packages (from requests<3.0.0,>=2.13.0->spacy~=3.4.4) (1.24.3)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.8/dist-packages (from requests<3.0.0,>=2.13.0->spacy~=3.4.4) (2.10)
# Requirement already satisfied: blis<0.8.0,>=0.7.8 in /usr/local/lib/python3.8/dist-packages (from thinc<8.2.0,>=8.1.0->spacy~=3.4.4) (0.7.9)
# Requirement already satisfied: confection<1.0.0,>=0.0.1 in /usr/local/lib/python3.8/dist-packages (from thinc<8.2.0,>=8.1.0->spacy~=3.4.4) (0.0.4)
# Requirement already satisfied: click<9.0.0,>=7.1.1 in /usr/local/lib/python3.8/dist-packages (from typer<0.8.0,>=0.3.0->spacy~=3.4.4) (7.1.2)
# Requirement already satisfied: MarkupSafe>=0.23 in /usr/local/lib/python3.8/dist-packages (from jinja2->spacy~=3.4.4) (2.0.1)
# 2023-02-13 22:14:56.918541: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 AVX512F FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-02-13 22:15:00.102658: W tensorflow/compiler/xla/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer.so.7'; dlerror: libnvinfer.so.7: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/lib64-nvidia
# 2023-02-13 22:15:00.102862: W tensorflow/compiler/xla/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer_plugin.so.7'; dlerror: libnvinfer_plugin.so.7: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/lib64-nvidia
# 2023-02-13 22:15:00.102883: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Cannot dlopen some TensorRT libraries. If you would like to use Nvidia GPU with TensorRT, please make sure the missing libraries mentioned above are installed properly.
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting en-core-web-lg==3.4.1
#   Downloading https://github.com/explosion/spacy-models/releases/download/en_core_web_lg-3.4.1/en_core_web_lg-3.4.1-py3-none-any.whl (587.7 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 587.7/587.7 MB 2.8 MB/s eta 0:00:00
# Requirement already satisfied: spacy<3.5.0,>=3.4.0 in /usr/local/lib/python3.8/dist-packages (from en-core-web-lg==3.4.1) (3.4.4)
# Requirement already satisfied: typer<0.8.0,>=0.3.0 in /usr/local/lib/python3.8/dist-packages (from spacy<3.5.0,>=3.4.0->en-core-web-lg==3.4.1) (0.7.0)
# Requirement already satisfied: langcodes<4.0.0,>=3.2.0 in /usr/local/lib/python3.8/dist-packages (from spacy<3.5.0,>=3.4.0->en-core-web-lg==3.4.1) (3.3.0)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in /usr/local/lib/python3.8/dist-packages (from spacy<3.5.0,>=3.4.0->en-core-web-lg==3.4.1) (1.0.9)
# Requirement already satisfied: thinc<8.2.0,>=8.1.0 in /usr/local/lib/python3.8/dist-packages (from spacy<3.5.0,>=3.4.0->en-core-web-lg==3.4.1) (8.1.7)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in /usr/local/lib/python3.8/dist-packages (from spacy<3.5.0,>=3.4.0->en-core-web-lg==3.4.1) (2.0.7)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in /usr/local/lib/python3.8/dist-packages (from spacy<3.5.0,>=3.4.0->en-core-web-lg==3.4.1) (4.64.1)
# Requirement already satisfied: smart-open<7.0.0,>=5.2.1 in /usr/local/lib/python3.8/dist-packages (from spacy<3.5.0,>=3.4.0->en-core-web-lg==3.4.1) (6.3.0)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in /usr/local/lib/python3.8/dist-packages (from spacy<3.5.0,>=3.4.0->en-core-web-lg==3.4.1) (2.25.1)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in /usr/local/lib/python3.8/dist-packages (from spacy<3.5.0,>=3.4.0->en-core-web-lg==3.4.1) (1.0.4)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.10 in /usr/local/lib/python3.8/dist-packages (from spacy<3.5.0,>=3.4.0->en-core-web-lg==3.4.1) (3.0.12)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in /usr/local/lib/python3.8/dist-packages (from spacy<3.5.0,>=3.4.0->en-core-web-lg==3.4.1) (3.0.8)
# Requirement already satisfied: wasabi<1.1.0,>=0.9.1 in /usr/local/lib/python3.8/dist-packages (from spacy<3.5.0,>=3.4.0->en-core-web-lg==3.4.1) (0.10.1)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.8/dist-packages (from spacy<3.5.0,>=3.4.0->en-core-web-lg==3.4.1) (57.4.0)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<1.11.0,>=1.7.4 in /usr/local/lib/python3.8/dist-packages (from spacy<3.5.0,>=3.4.0->en-core-web-lg==3.4.1) (1.10.4)
# Requirement already satisfied: srsly<3.0.0,>=2.4.3 in /usr/local/lib/python3.8/dist-packages (from spacy<3.5.0,>=3.4.0->en-core-web-lg==3.4.1) (2.4.5)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.8/dist-packages (from spacy<3.5.0,>=3.4.0->en-core-web-lg==3.4.1) (2.11.3)
# Requirement already satisfied: pathy>=0.3.5 in /usr/local/lib/python3.8/dist-packages (from spacy<3.5.0,>=3.4.0->en-core-web-lg==3.4.1) (0.10.1)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in /usr/local/lib/python3.8/dist-packages (from spacy<3.5.0,>=3.4.0->en-core-web-lg==3.4.1) (2.0.8)
# Requirement already satisfied: numpy>=1.15.0 in /usr/local/lib/python3.8/dist-packages (from spacy<3.5.0,>=3.4.0->en-core-web-lg==3.4.1) (1.21.6)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.8/dist-packages (from spacy<3.5.0,>=3.4.0->en-core-web-lg==3.4.1) (23.0)
# Requirement already satisfied: typing-extensions>=4.2.0 in /usr/local/lib/python3.8/dist-packages (from pydantic!=1.8,!=1.8.1,<1.11.0,>=1.7.4->spacy<3.5.0,>=3.4.0->en-core-web-lg==3.4.1) (4.4.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.8/dist-packages (from requests<3.0.0,>=2.13.0->spacy<3.5.0,>=3.4.0->en-core-web-lg==3.4.1) (2022.12.7)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.8/dist-packages (from requests<3.0.0,>=2.13.0->spacy<3.5.0,>=3.4.0->en-core-web-lg==3.4.1) (1.24.3)
# Requirement already satisfied: chardet<5,>=3.0.2 in /usr/local/lib/python3.8/dist-packages (from requests<3.0.0,>=2.13.0->spacy<3.5.0,>=3.4.0->en-core-web-lg==3.4.1) (4.0.0)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.8/dist-packages (from requests<3.0.0,>=2.13.0->spacy<3.5.0,>=3.4.0->en-core-web-lg==3.4.1) (2.10)
# Requirement already satisfied: confection<1.0.0,>=0.0.1 in /usr/local/lib/python3.8/dist-packages (from thinc<8.2.0,>=8.1.0->spacy<3.5.0,>=3.4.0->en-core-web-lg==3.4.1) (0.0.4)
# Requirement already satisfied: blis<0.8.0,>=0.7.8 in /usr/local/lib/python3.8/dist-packages (from thinc<8.2.0,>=8.1.0->spacy<3.5.0,>=3.4.0->en-core-web-lg==3.4.1) (0.7.9)
# Requirement already satisfied: click<9.0.0,>=7.1.1 in /usr/local/lib/python3.8/dist-packages (from typer<0.8.0,>=0.3.0->spacy<3.5.0,>=3.4.0->en-core-web-lg==3.4.1) (7.1.2)
# Requirement already satisfied: MarkupSafe>=0.23 in /usr/local/lib/python3.8/dist-packages (from jinja2->spacy<3.5.0,>=3.4.0->en-core-web-lg==3.4.1) (2.0.1)
# ✔ Download and installation successful
# You can now load the package via spacy.load('en_core_web_lg')
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting en-coreference-web-trf==3.4.0a0
#   Downloading https://github.com/explosion/spacy-experimental/releases/download/v0.6.0/en_coreference_web_trf-3.4.0a0-py3-none-any.whl (490.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 490.3/490.3 MB 2.8 MB/s eta 0:00:00
# Requirement already satisfied: spacy-experimental<0.7.0,>=0.6.0 in /usr/local/lib/python3.8/dist-packages (from en-coreference-web-trf==3.4.0a0) (0.6.1)
# Requirement already satisfied: spacy<3.5.0,>=3.3.0 in /usr/local/lib/python3.8/dist-packages (from en-coreference-web-trf==3.4.0a0) (3.4.4)
# Requirement already satisfied: spacy-transformers<1.2.0,>=1.1.2 in /usr/local/lib/python3.8/dist-packages (from en-coreference-web-trf==3.4.0a0) (1.1.9)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in /usr/local/lib/python3.8/dist-packages (from spacy<3.5.0,>=3.3.0->en-coreference-web-trf==3.4.0a0) (3.0.8)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<1.11.0,>=1.7.4 in /usr/local/lib/python3.8/dist-packages (from spacy<3.5.0,>=3.3.0->en-coreference-web-trf==3.4.0a0) (1.10.4)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in /usr/local/lib/python3.8/dist-packages (from spacy<3.5.0,>=3.3.0->en-coreference-web-trf==3.4.0a0) (2.0.7)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.8/dist-packages (from spacy<3.5.0,>=3.3.0->en-coreference-web-trf==3.4.0a0) (2.11.3)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in /usr/local/lib/python3.8/dist-packages (from spacy<3.5.0,>=3.3.0->en-coreference-web-trf==3.4.0a0) (1.0.9)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.8/dist-packages (from spacy<3.5.0,>=3.3.0->en-coreference-web-trf==3.4.0a0) (57.4.0)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in /usr/local/lib/python3.8/dist-packages (from spacy<3.5.0,>=3.3.0->en-coreference-web-trf==3.4.0a0) (1.0.4)
# Requirement already satisfied: typer<0.8.0,>=0.3.0 in /usr/local/lib/python3.8/dist-packages (from spacy<3.5.0,>=3.3.0->en-coreference-web-trf==3.4.0a0) (0.7.0)
# Requirement already satisfied: langcodes<4.0.0,>=3.2.0 in /usr/local/lib/python3.8/dist-packages (from spacy<3.5.0,>=3.3.0->en-coreference-web-trf==3.4.0a0) (3.3.0)
# Requirement already satisfied: thinc<8.2.0,>=8.1.0 in /usr/local/lib/python3.8/dist-packages (from spacy<3.5.0,>=3.3.0->en-coreference-web-trf==3.4.0a0) (8.1.7)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in /usr/local/lib/python3.8/dist-packages (from spacy<3.5.0,>=3.3.0->en-coreference-web-trf==3.4.0a0) (2.0.8)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.10 in /usr/local/lib/python3.8/dist-packages (from spacy<3.5.0,>=3.3.0->en-coreference-web-trf==3.4.0a0) (3.0.12)
# Requirement already satisfied: numpy>=1.15.0 in /usr/local/lib/python3.8/dist-packages (from spacy<3.5.0,>=3.3.0->en-coreference-web-trf==3.4.0a0) (1.21.6)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in /usr/local/lib/python3.8/dist-packages (from spacy<3.5.0,>=3.3.0->en-coreference-web-trf==3.4.0a0) (2.25.1)
# Requirement already satisfied: pathy>=0.3.5 in /usr/local/lib/python3.8/dist-packages (from spacy<3.5.0,>=3.3.0->en-coreference-web-trf==3.4.0a0) (0.10.1)
# Requirement already satisfied: wasabi<1.1.0,>=0.9.1 in /usr/local/lib/python3.8/dist-packages (from spacy<3.5.0,>=3.3.0->en-coreference-web-trf==3.4.0a0) (0.10.1)
# Requirement already satisfied: smart-open<7.0.0,>=5.2.1 in /usr/local/lib/python3.8/dist-packages (from spacy<3.5.0,>=3.3.0->en-coreference-web-trf==3.4.0a0) (6.3.0)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in /usr/local/lib/python3.8/dist-packages (from spacy<3.5.0,>=3.3.0->en-coreference-web-trf==3.4.0a0) (4.64.1)
# Requirement already satisfied: srsly<3.0.0,>=2.4.3 in /usr/local/lib/python3.8/dist-packages (from spacy<3.5.0,>=3.3.0->en-coreference-web-trf==3.4.0a0) (2.4.5)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.8/dist-packages (from spacy<3.5.0,>=3.3.0->en-coreference-web-trf==3.4.0a0) (23.0)
# Requirement already satisfied: torch>=1.6.0 in /usr/local/lib/python3.8/dist-packages (from spacy-transformers<1.2.0,>=1.1.2->en-coreference-web-trf==3.4.0a0) (1.13.1+cu116)
# Requirement already satisfied: spacy-alignments<1.0.0,>=0.7.2 in /usr/local/lib/python3.8/dist-packages (from spacy-transformers<1.2.0,>=1.1.2->en-coreference-web-trf==3.4.0a0) (0.9.0)
# Requirement already satisfied: transformers<4.26.0,>=3.4.0 in /usr/local/lib/python3.8/dist-packages (from spacy-transformers<1.2.0,>=1.1.2->en-coreference-web-trf==3.4.0a0) (4.25.1)
# Requirement already satisfied: typing-extensions>=4.2.0 in /usr/local/lib/python3.8/dist-packages (from pydantic!=1.8,!=1.8.1,<1.11.0,>=1.7.4->spacy<3.5.0,>=3.3.0->en-coreference-web-trf==3.4.0a0) (4.4.0)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.8/dist-packages (from requests<3.0.0,>=2.13.0->spacy<3.5.0,>=3.3.0->en-coreference-web-trf==3.4.0a0) (1.24.3)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.8/dist-packages (from requests<3.0.0,>=2.13.0->spacy<3.5.0,>=3.3.0->en-coreference-web-trf==3.4.0a0) (2.10)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.8/dist-packages (from requests<3.0.0,>=2.13.0->spacy<3.5.0,>=3.3.0->en-coreference-web-trf==3.4.0a0) (2022.12.7)
# Requirement already satisfied: chardet<5,>=3.0.2 in /usr/local/lib/python3.8/dist-packages (from requests<3.0.0,>=2.13.0->spacy<3.5.0,>=3.3.0->en-coreference-web-trf==3.4.0a0) (4.0.0)
# Requirement already satisfied: blis<0.8.0,>=0.7.8 in /usr/local/lib/python3.8/dist-packages (from thinc<8.2.0,>=8.1.0->spacy<3.5.0,>=3.3.0->en-coreference-web-trf==3.4.0a0) (0.7.9)
# Requirement already satisfied: confection<1.0.0,>=0.0.1 in /usr/local/lib/python3.8/dist-packages (from thinc<8.2.0,>=8.1.0->spacy<3.5.0,>=3.3.0->en-coreference-web-trf==3.4.0a0) (0.0.4)
# Requirement already satisfied: filelock in /usr/local/lib/python3.8/dist-packages (from transformers<4.26.0,>=3.4.0->spacy-transformers<1.2.0,>=1.1.2->en-coreference-web-trf==3.4.0a0) (3.9.0)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.8/dist-packages (from transformers<4.26.0,>=3.4.0->spacy-transformers<1.2.0,>=1.1.2->en-coreference-web-trf==3.4.0a0) (2022.6.2)
# Requirement already satisfied: tokenizers!=0.11.3,<0.14,>=0.11.1 in /usr/local/lib/python3.8/dist-packages (from transformers<4.26.0,>=3.4.0->spacy-transformers<1.2.0,>=1.1.2->en-coreference-web-trf==3.4.0a0) (0.13.2)
# Requirement already satisfied: huggingface-hub<1.0,>=0.10.0 in /usr/local/lib/python3.8/dist-packages (from transformers<4.26.0,>=3.4.0->spacy-transformers<1.2.0,>=1.1.2->en-coreference-web-trf==3.4.0a0) (0.12.0)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.8/dist-packages (from transformers<4.26.0,>=3.4.0->spacy-transformers<1.2.0,>=1.1.2->en-coreference-web-trf==3.4.0a0) (6.0)
# Requirement already satisfied: click<9.0.0,>=7.1.1 in /usr/local/lib/python3.8/dist-packages (from typer<0.8.0,>=0.3.0->spacy<3.5.0,>=3.3.0->en-coreference-web-trf==3.4.0a0) (7.1.2)
# Requirement already satisfied: MarkupSafe>=0.23 in /usr/local/lib/python3.8/dist-packages (from jinja2->spacy<3.5.0,>=3.3.0->en-coreference-web-trf==3.4.0a0) (2.0.1)

# %%
# list all Python packages installed 
# !pip list
# Out:
# Package                       Version
# ----------------------------- ----------------------
# absl-py                       1.4.0
# aeppl                         0.0.33
# aesara                        2.7.9
# aiohttp                       3.8.3
# aiosignal                     1.3.1
# alabaster                     0.7.13
# albumentations                1.2.1
# altair                        4.2.2
# appdirs                       1.4.4
# arviz                         0.12.1
# astor                         0.8.1
# astropy                       4.3.1
# astunparse                    1.6.3
# async-timeout                 4.0.2
# atari-py                      0.2.9
# atomicwrites                  1.4.1
# attrs                         22.2.0
# audioread                     3.0.0
# autograd                      1.5
# Babel                         2.11.0
# backcall                      0.2.0
# beautifulsoup4                4.6.3
# bleach                        6.0.0
# blis                          0.7.9
# bokeh                         2.3.3
# branca                        0.6.0
# bs4                           0.0.1
# CacheControl                  0.12.11
# cachetools                    5.3.0
# catalogue                     2.0.8
# certifi                       2022.12.7
# cffi                          1.15.1
# cftime                        1.6.2
# chardet                       4.0.0
# charset-normalizer            2.1.1
# click                         7.1.2
# clikit                        0.6.2
# cloudpickle                   2.2.1
# cmake                         3.22.6
# cmdstanpy                     1.1.0
# colorcet                      3.0.1
# colorlover                    0.3.0
# community                     1.0.0b1
# confection                    0.0.4
# cons                          0.4.5
# contextlib2                   0.5.5
# convertdate                   2.4.0
# crashtest                     0.3.1
# crcmod                        1.7
# cufflinks                     0.17.3
# cupy-cuda11x                  11.0.0
# cvxopt                        1.3.0
# cvxpy                         1.2.3
# cycler                        0.11.0
# cymem                         2.0.7
# Cython                        0.29.33
# daft                          0.0.4
# dask                          2022.2.1
# datascience                   0.17.5
# db-dtypes                     1.0.5
# dbus-python                   1.2.16
# debugpy                       1.0.0
# decorator                     4.4.2
# defusedxml                    0.7.1
# descartes                     1.1.0
# dill                          0.3.6
# distributed                   2022.2.1
# dlib                          19.24.0
# dm-tree                       0.1.8
# dnspython                     2.3.0
# docutils                      0.16
# dopamine-rl                   1.0.5
# earthengine-api               0.1.340
# easydict                      1.10
# ecos                          2.0.12
# editdistance                  0.5.3
# en-core-web-lg                3.4.1
# en-core-web-sm                3.4.1
# en-coreference-web-trf        3.4.0a0
# entrypoints                   0.4
# ephem                         4.1.4
# et-xmlfile                    1.1.0
# etils                         1.0.0
# etuples                       0.3.8
# fa2                           0.3.5
# fastai                        2.7.10
# fastcore                      1.5.28
# fastdownload                  0.0.7
# fastdtw                       0.3.4
# fastjsonschema                2.16.2
# fastprogress                  1.0.3
# fastrlock                     0.8.1
# feather-format                0.4.1
# filelock                      3.9.0
# firebase-admin                5.3.0
# fix-yahoo-finance             0.0.22
# Flask                         1.1.4
# flatbuffers                   23.1.21
# folium                        0.12.1.post1
# frozenlist                    1.3.3
# fsspec                        2023.1.0
# future                        0.16.0
# gast                          0.4.0
# GDAL                          3.3.2
# gdown                         4.4.0
# gensim                        3.6.0
# geographiclib                 1.52
# geopy                         1.17.0
# gin-config                    0.5.0
# glob2                         0.7
# google                        2.0.3
# google-api-core               2.11.0
# google-api-python-client      2.70.0
# google-auth                   2.16.0
# google-auth-httplib2          0.1.0
# google-auth-oauthlib          0.4.6
# google-cloud-bigquery         3.4.2
# google-cloud-bigquery-storage 2.18.1
# google-cloud-core             2.3.2
# google-cloud-datastore        2.11.1
# google-cloud-firestore        2.7.3
# google-cloud-language         2.6.1
# google-cloud-storage          2.7.0
# google-cloud-translate        3.8.4
# google-colab                  1.0.0
# google-crc32c                 1.5.0
# google-pasta                  0.2.0
# google-resumable-media        2.4.1
# googleapis-common-protos      1.58.0
# googledrivedownloader         0.4
# graphviz                      0.10.1
# greenlet                      2.0.2
# grpcio                        1.51.1
# grpcio-status                 1.48.2
# gspread                       3.4.2
# gspread-dataframe             3.0.8
# gym                           0.25.2
# gym-notices                   0.0.8
# h5py                          3.1.0
# HeapDict                      1.0.1
# hijri-converter               2.2.4
# holidays                      0.19
# holoviews                     1.14.9
# html5lib                      1.0.1
# httpimport                    0.5.18
# httplib2                      0.17.4
# httpstan                      4.6.1
# huggingface-hub               0.12.0
# humanize                      0.5.1
# hyperopt                      0.1.2
# idna                          2.10
# imageio                       2.9.0
# imagesize                     1.4.1
# imbalanced-learn              0.8.1
# imblearn                      0.0
# imgaug                        0.4.0
# importlib-metadata            6.0.0
# importlib-resources           5.10.2
# imutils                       0.5.4
# inflect                       2.1.0
# intel-openmp                  2023.0.0
# intervaltree                  2.1.0
# ipykernel                     5.3.4
# ipython                       7.9.0
# ipython-genutils              0.2.0
# ipython-sql                   0.3.9
# ipywidgets                    7.7.1
# itsdangerous                  1.1.0
# jax                           0.3.25
# jaxlib                        0.3.25+cuda11.cudnn805
# jieba                         0.42.1
# Jinja2                        2.11.3
# joblib                        1.2.0
# jpeg4py                       0.1.4
# jsonschema                    4.3.3
# jupyter-client                6.1.12
# jupyter-console               6.1.0
# jupyter_core                  5.2.0
# jupyterlab-widgets            3.0.5
# kaggle                        1.5.12
# kapre                         0.3.7
# keras                         2.11.0
# keras-vis                     0.4.1
# kiwisolver                    1.4.4
# korean-lunar-calendar         0.3.1
# langcodes                     3.3.0
# libclang                      15.0.6.1
# librosa                       0.8.1
# lightgbm                      2.2.3
# llvmlite                      0.39.1
# lmdb                          0.99
# locket                        1.0.0
# logical-unification           0.4.5
# LunarCalendar                 0.0.9
# lxml                          4.9.2
# Markdown                      3.4.1
# MarkupSafe                    2.0.1
# marshmallow                   3.19.0
# matplotlib                    3.2.2
# matplotlib-venn               0.11.7
# miniKanren                    1.0.3
# missingno                     0.5.1
# mistune                       0.8.4
# mizani                        0.7.3
# mkl                           2019.0
# mlxtend                       0.14.0
# more-itertools                9.0.0
# moviepy                       0.2.3.5
# mpmath                        1.2.1
# msgpack                       1.0.4
# multidict                     6.0.4
# multipledispatch              0.6.0
# multitasking                  0.0.11
# murmurhash                    1.0.9
# music21                       5.5.0
# natsort                       5.5.0
# nbconvert                     5.6.1
# nbformat                      5.7.3
# netCDF4                       1.6.2
# networkx                      3.0
# nibabel                       3.0.2
# nltk                          3.7
# notebook                      5.7.16
# numba                         0.56.4
# numexpr                       2.8.4
# numpy                         1.21.6
# oauth2client                  4.1.3
# oauthlib                      3.2.2
# okgrade                       0.4.3
# opencv-contrib-python         4.6.0.66
# opencv-python                 4.6.0.66
# opencv-python-headless        4.7.0.68
# openpyxl                      3.0.10
# opt-einsum                    3.3.0
# osqp                          0.6.2.post0
# packaging                     23.0
# palettable                    3.3.0
# pandas                        1.3.5
# pandas-datareader             0.9.0
# pandas-gbq                    0.17.9
# pandas-profiling              1.4.1
# pandocfilters                 1.5.0
# panel                         0.12.1
# param                         1.12.3
# parso                         0.8.3
# partd                         1.3.0
# pastel                        0.2.1
# pathlib                       1.0.1
# pathy                         0.10.1
# patsy                         0.5.3
# pep517                        0.13.0
# pexpect                       4.8.0
# pickleshare                   0.7.5
# Pillow                        7.1.2
# pip                           22.0.4
# pip-tools                     6.6.2
# platformdirs                  3.0.0
# plotly                        5.5.0
# plotnine                      0.8.0
# pluggy                        0.7.1
# pooch                         1.6.0
# portpicker                    1.3.9
# prefetch-generator            1.0.3
# preshed                       3.0.8
# prettytable                   3.6.0
# progressbar2                  3.38.0
# prometheus-client             0.16.0
# promise                       2.3
# prompt-toolkit                2.0.10
# prophet                       1.1.2
# proto-plus                    1.22.2
# protobuf                      3.19.6
# psutil                        5.4.8
# psycopg2                      2.9.5
# ptyprocess                    0.7.0
# py                            1.11.0
# pyarrow                       9.0.0
# pyasn1                        0.4.8
# pyasn1-modules                0.2.8
# pycocotools                   2.0.6
# pycparser                     2.21
# pyct                          0.5.0
# pydantic                      1.10.4
# pydata-google-auth            1.7.0
# pydot                         1.3.0
# pydot-ng                      2.0.0
# pydotplus                     2.0.2
# PyDrive                       1.3.1
# pyemd                         0.5.1
# pyerfa                        2.0.0.1
# Pygments                      2.6.1
# PyGObject                     3.36.0
# pylev                         1.4.0
# pymc                          4.1.4
# PyMeeus                       0.5.12
# pymongo                       4.3.3
# pymystem3                     0.2.0
# PyOpenGL                      3.1.6
# pyparsing                     3.0.9
# pyrsistent                    0.19.3
# pysimdjson                    3.2.0
# PySocks                       1.7.1
# pystan                        3.3.0
# pytest                        3.6.4
# python-apt                    2.0.1
# python-dateutil               2.8.2
# python-louvain                0.16
# python-slugify                8.0.0
# python-utils                  3.5.0
# pytz                          2022.7.1
# pyviz-comms                   2.2.1
# PyWavelets                    1.4.1
# PyYAML                        6.0
# pyzmq                         23.2.1
# qdldl                         0.1.5.post3
# qudida                        0.0.4
# regex                         2022.6.2
# requests                      2.25.1
# requests-oauthlib             1.3.1
# requests-unixsocket           0.2.0
# resampy                       0.4.2
# rpy2                          3.5.5
# rsa                           4.9
# scikit-image                  0.18.3
# scikit-learn                  1.0.2
# scipy                         1.7.3
# screen-resolution-extra       0.0.0
# scs                           3.2.2
# seaborn                       0.11.2
# Send2Trash                    1.8.0
# setuptools                    57.4.0
# shapely                       2.0.1
# six                           1.15.0
# sklearn-pandas                1.8.0
# smart-open                    6.3.0
# snowballstemmer               2.2.0
# sortedcontainers              2.4.0
# soundfile                     0.11.0
# spacy                         3.4.4
# spacy-alignments              0.9.0
# spacy-experimental            0.6.1
# spacy-legacy                  3.0.12
# spacy-loggers                 1.0.4
# spacy-transformers            1.1.9
# Sphinx                        3.5.4
# sphinxcontrib-applehelp       1.0.4
# sphinxcontrib-devhelp         1.0.2
# sphinxcontrib-htmlhelp        2.0.1
# sphinxcontrib-jsmath          1.0.1
# sphinxcontrib-qthelp          1.0.3
# sphinxcontrib-serializinghtml 1.1.5
# SQLAlchemy                    1.4.46
# sqlparse                      0.4.3
# srsly                         2.4.5
# statsmodels                   0.12.2
# sympy                         1.7.1
# tables                        3.7.0
# tabulate                      0.8.10
# tblib                         1.7.0
# tenacity                      8.2.0
# tensorboard                   2.11.2
# tensorboard-data-server       0.6.1
# tensorboard-plugin-wit        1.8.1
# tensorflow                    2.11.0
# tensorflow-datasets           4.8.2
# tensorflow-estimator          2.11.0
# tensorflow-gcs-config         2.11.0
# tensorflow-hub                0.12.0
# tensorflow-io-gcs-filesystem  0.30.0
# tensorflow-metadata           1.12.0
# tensorflow-probability        0.19.0
# termcolor                     2.2.0
# terminado                     0.13.3
# testpath                      0.6.0
# text-unidecode                1.3
# textblob                      0.15.3
# thinc                         8.1.7
# threadpoolctl                 3.1.0
# tifffile                      2023.2.3
# tokenizers                    0.13.2
# toml                          0.10.2
# tomli                         2.0.1
# toolz                         0.12.0
# torch                         1.13.1+cu116
# torchaudio                    0.13.1+cu116
# torchsummary                  1.5.1
# torchtext                     0.14.1
# torchvision                   0.14.1+cu116
# tornado                       6.0.4
# tqdm                          4.64.1
# traitlets                     5.7.1
# transformers                  4.25.1
# tweepy                        3.10.0
# typeguard                     2.7.1
# typer                         0.7.0
# typing_extensions             4.4.0
# tzlocal                       1.5.1
# uritemplate                   4.1.1
# urllib3                       1.24.3
# vega-datasets                 0.9.0
# wasabi                        0.10.1
# wcwidth                       0.2.6
# webargs                       8.2.0
# webencodings                  0.5.1
# Werkzeug                      1.0.1
# wheel                         0.38.4
# widgetsnbextension            3.6.1
# wordcloud                     1.8.2.2
# wrapt                         1.14.1
# xarray                        2022.12.0
# xarray-einstats               0.5.1
# xgboost                       0.90
# xkit                          0.0.0
# xlrd                          1.2.0
# xlwt                          1.3.0
# yarl                          1.8.2
# yellowbrick                   1.5
# zict                          2.2.0
# zipp                          3.12.1

# %% [markdown]
# ### Get access to Firebase and Drive

# %%
# remount drive, forced if needed
drive.mount("/content/drive/", force_remount = True)
print("Stablished access to Google Drive")

# initialize Drive path
DRIVE_PATH = "/content/drive/My Drive"
# Out:
# Mounted at /content/drive/
# Stablished access to Google Drive

# %% [markdown]
# ### Retrieve main data structures

# %%
list_files = !ls /content/drive/MyDrive/IE/ie_course_2022_team03/retrieved_data/scrapped_data

# %% [markdown]
# ## #2. Resolve references

# %% [markdown]
# ### Create pipeline

# %%
nlp = spacy.load("en_coreference_web_trf")

# %% [markdown]
# ### Coreference resolution

# %%
# main_text_woc_container = []
texts = []
for file in list_files:
  print("Reading from file", file)
  with open(DRIVE_PATH + f"/IE/ie_course_2022_team03/retrieved_data/scrapped_data/{file}", encoding='utf-8') as f:
    file_data = json.load(f)
    texts.append(file_data["text"])
# Out:
# Reading from file aboutvisitberlindejobs.json
# Reading from file aboutvisitberlinde.json
# Reading from file aboutvisitberlindeteammarktmanagement.json
# Reading from file aboutvisitberlindeunsermedienservicefuersie.json
# Reading from file aboutvisitberlindewerbekunden.json
# Reading from file absolutemunichcomaboutabsolutemunich.json
# Reading from file absolutemunichcomaltepinakothekmunich.json
# Reading from file absolutemunichcomalteuttingmunich.json
# Reading from file absolutemunichcomauthorabsolutemunichgmailcom.json
# Reading from file absolutemunichcomauthorfred.json
# Reading from file absolutemunichcombavariancuisineguide.json
# Reading from file absolutemunichcombavarianforestnationalpark.json
# Reading from file absolutemunichcombavarianstatelibrary.json
# Reading from file absolutemunichcombavariaparkmunich.json
# Reading from file absolutemunichcombavariastatuemunich.json
# Reading from file absolutemunichcomblog.json
# Reading from file absolutemunichcomblogpage2.json
# Reading from file absolutemunichcomblogpage7.json
# Reading from file absolutemunichcomcategoryfoodanddrink.json
# Reading from file absolutemunichcomcategorymunichmuseums.json
# Reading from file absolutemunichcomcategorymunichtravel.json
# Reading from file absolutemunichcomcoronavirusmunichimportantinformationandresources.json
# Reading from file absolutemunichcomdiscoverbavariandrinks.json
# Reading from file absolutemunichcomegyptianmuseummunich.json
# Reading from file absolutemunichcomendlessstaircasemunich.json
# Reading from file absolutemunichcomfeldherrnhalleodeonsplatz.json
# Reading from file absolutemunichcomfoodinmunichsociallyawarecityeateries.json
# Reading from file absolutemunichcomfruhlingsfestmunichspringfestival.json
# Reading from file absolutemunichcomgettingaroundmunich.json
# Reading from file absolutemunichcomglyptothekmunich.json
# Reading from file absolutemunichcomgreenmunich.json
# Reading from file absolutemunichcomgrunwaldcastlemunichsmedievalhillcastle.json
# Reading from file absolutemunichcomismunichsafe.json
# Reading from file absolutemunichcom.json
# Reading from file absolutemunichcomkarlstormunichcitygate.json
# Reading from file absolutemunichcomkvrappointmentandregistrationinmunich.json
# Reading from file absolutemunichcomlearngermanonlinepaidfreeresources.json
# Reading from file absolutemunichcomlivinginmunichguidetohomerental.json
# Reading from file absolutemunichcommapsofmunichpdfdownloads.json
# Reading from file absolutemunichcommaximilianeummunich.json
# Reading from file absolutemunichcommunichcafesbestcoffeeinmunich.json
# Reading from file absolutemunichcommunichcityfaqs.json
# Reading from file absolutemunichcommunichemergencynumberspolicefireambulance.json
# Reading from file absolutemunichcommunichindianrestaurantbindaasreview.json
# Reading from file absolutemunichcommunichresidenzbiggestcitypalacegermany.json
# Reading from file absolutemunichcommunichtoymuseum.json
# Reading from file absolutemunichcommunichtravel.json
# Reading from file absolutemunichcommvgmuseummunich.json
# Reading from file absolutemunichcompoppifarmermunichcafereview.json
# Reading from file absolutemunichcompregnancyingermanynewmumsinmunich.json
# Reading from file absolutemunichcomprivacypolicy.json
# Reading from file absolutemunichcomruhmeshallemunichbavariashalloffame.json
# Reading from file absolutemunichcomschweinshaxegermanporkknuckle.json
# Reading from file absolutemunichcomsiegestormunichbavariasfamousvictorygate.json
# Reading from file absolutemunichcomsteckerlfisch.json
# Reading from file absolutemunichcomthalkirchenmunich.json
# Reading from file admiralspalasttheaterveranstaltungberlinberlinhtmlsourcebdego.json
# Reading from file akismetcomprivacy.json
# Reading from file berlindeeaen.json
# Reading from file berlindeenaccommodation.json
# Reading from file berlindeenairportber.json
# Reading from file berlindeenattractionsandsights.json
# Reading from file berlindeenbusinessandeconomy.json
# Reading from file berlindeenergieen.json
# Reading from file berlindeenevents.json
# Reading from file berlindeen.json
# Reading from file berlindeenpoliticsadministration.json
# Reading from file berlindeenpublictransportation.json
# Reading from file berlindeenshopping.json
# Reading from file berlindeenticketssearchemssearchresultsanchor.json
# Reading from file berlindeentourismguides.json
# Reading from file berlindeentourismtravelinformation17495122862820policeenhtml.json
# Reading from file berlindefr.json
# Reading from file berlindeit.json
# Reading from file berlinde.json
# Reading from file berlindelabowillkommeninberlinartikel600679enphp.json
# Reading from file berlinderbmskzlen.json
# Reading from file berlindevhskursedeutschintegrationintegrationskurseintegrationcourses403809enphp.json
# Reading from file berlindevhskursedeutschintegrationkursefuergefluechtetehintergrundinformationenartikel469718enphp.json
# Reading from file berlindewillkommenszentrumen.json
# Reading from file berlinenjoycomaboutberlinenjoyaboutberlinenjoyrespond.json
# Reading from file berlinenjoycomaboutberlinenjoycomment13234.json
# Reading from file berlinenjoycomaboutberlinenjoycomment13282.json
# Reading from file berlinenjoycomaboutberlinenjoycomment181632.json
# Reading from file berlinenjoycomaboutberlinenjoycomment186002.json
# Reading from file berlinenjoycomaboutberlinenjoycomment229447.json
# Reading from file berlinenjoycomaboutberlinenjoycomment229489.json
# Reading from file berlinenjoycomaboutberlinenjoycomment292344.json
# Reading from file berlinenjoycomaboutberlinenjoycomment295904.json
# Reading from file berlinenjoycomaboutberlinenjoycomment296603.json
# Reading from file berlinenjoycomaboutberlinenjoycomment32630.json
# Reading from file berlinenjoycomaboutberlinenjoycomment35165.json
# Reading from file berlinenjoycomaboutberlinenjoycomment7431.json
# Reading from file berlinenjoycomaboutberlinenjoycomment7472.json
# Reading from file berlinenjoycomaboutberlinenjoycomment7640.json
# Reading from file berlinenjoycomaboutberlinenjoy.json
# Reading from file berlinenjoycomcontact.json
# Reading from file berlinenjoycomcooperationwithberlinenjoy.json
# Reading from file berlinenjoycomdisclaimer.json
# Reading from file berlinenjoycomeatanddrinkbars.json
# Reading from file berlinenjoycomeatanddrinkfoodandrestaurantsbestburgersinfriedrichshain.json
# Reading from file berlinenjoycomeatanddrinkfoodandrestaurants.json
# Reading from file berlinenjoycomeatanddrink.json
# Reading from file berlinenjoycom.json
# Reading from file berlinenjoycommustseeabandonedplaces.json
# Reading from file berlinenjoycommustseeartandexhibitions.json
# Reading from file berlinenjoycommustsee.json
# Reading from file berlinenjoycommustseeparksandnature.json
# Reading from file berlinenjoycommustseesightseeing.json
# Reading from file berlinenjoycommustseethecoastofghana.json
# Reading from file berlinenjoycomotheraccommodation.json
# Reading from file berlinenjoycomotherbooksandmovies.json
# Reading from file berlinenjoycomother.json
# Reading from file berlinenjoycomotherphotos.json
# Reading from file berlinenjoycomothertipsandadvice.json
# Reading from file berlinenjoycomothertipsandadvicetravelberlintipsadvice.json
# Reading from file berlinenjoycompartybestparties.json
# Reading from file berlinenjoycompartybestpartiespartyinberlin.json
# Reading from file berlinenjoycompartyclubs.json
# Reading from file berlinenjoycompartyfestivalsbestgermanfestivals.json
# Reading from file berlinenjoycompartyfestivals.json
# Reading from file berlinenjoycomparty.json
# Reading from file berlinenjoycomtagaffordable.json
# Reading from file berlinenjoycomtagberlinforkids.json
# Reading from file berlinenjoycomtagbestof.json
# Reading from file berlinenjoycomtagclosedclub.json
# Reading from file berlinenjoycomtagfavorites.json
# Reading from file berlinenjoycomtagfree.json
# Reading from file berlinenjoycomtagfriedrichshain.json
# Reading from file berlinenjoycomtaggiveaway.json
# Reading from file berlinenjoycomtagindoor.json
# Reading from file berlinenjoycomtagmostread.json
# Reading from file berlinenjoycomtagrelaxation.json
# Reading from file berlinenjoycomtagreview.json
# Reading from file berlinenjoycomtagstreetfestival.json
# Reading from file berlinenjoycomtagsummer.json
# Reading from file berlinenjoycomtagswimming.json
# Reading from file berlinenjoycomtagwinter.json
# Reading from file berlinenjoycomtagworldwar2.json
# Reading from file berlinenjoycomthingstodoactivities.json
# Reading from file berlinenjoycomthingstodoberlinwithkids.json
# Reading from file berlinenjoycomthingstodo.json
# Reading from file berlinenjoycomthingstodoshoppingbestareastogoshopping.json
# Reading from file berlinenjoycomthingstodoshopping.json
# Reading from file berlinenjoycomthingstodoshowsandconcerts.json
# Reading from file berlinenjoycomthingstodosportsbeachvolleyball.json
# Reading from file berlinenjoycomthingstodosports.json
# Reading from file berlinenjoycomthingstodosportstennisinberlin.json
# Reading from file berlinenjoycomthingstodoyearlyevents.json
# Reading from file berlinenjoycomtravelangkorwattemple.json
# Reading from file berlinenjoycomtravel.json
# Reading from file berlinenjoycomtravelsrilankainoctober.json
# Reading from file berlinenjoycomtraveltraveltipineuropeweekendtripinprague.json
# Reading from file berlinenjoycomtravelunusualphotosfromaustralia.json
# Reading from file berlininfoinfodistrictsberlin.json
# Reading from file berlintoubizdeVisitBerlinPAUpackagedetail1BTM00020100428259477reset1langen.json
# Reading from file berlintoubizdeVisitBerlinPAUpackagedetail1BTM00020100440832662reset1langen.json
# Reading from file bvgdede.json
# Reading from file bvgdeen49euroticket.json
# Reading from file bvgdeenaccessibilitydeclaration.json
# Reading from file bvgdeenconnections.json
# Reading from file bvgdeengeneraltermsandconditions.json
# Reading from file bvgdeenimprint.json
# Reading from file bvgdeen.json
# Reading from file bvgdeenprivacypolicy.json
# Reading from file bvgdeenserviceandsupport.json
# Reading from file bvgdeenserviceandsupportpassengerrights.json
# Reading from file bvgdeenserviceandsupporttourists.json
# Reading from file bvgdeenserviceandsupportusagepolicy.json
# Reading from file bvgdeenticketstariffsallappsfahrinfoapp.json
# Reading from file bvgdeenticketstariffsallappsipr1appipr2alleappsipr3startseitekachelipr435.json
# Reading from file bvgdeenticketstariffsallapps.json
# Reading from file bvgdeenticketstariffsallappsticketapp.json
# Reading from file bvgdeenticketstariffsalltickets.json
# Reading from file bvgdeenticketstariffs.json
# Reading from file bvgdeenticketstariffssubscriptionsipr1aboipr2alleabosipr3startseitekachelipr425.json
# Reading from file bvgdeenticketstariffssubscriptions.json
# Reading from file bvgdeenticketstariffssubscriptionsschoolstudentticketberlin.json
# Reading from file bvgdeenticketstariffssubscriptionsvbb65plusticket.json
# Reading from file bvgdeenticketstariffssubscriptionsvbbecoticket.json
# Reading from file bvgdeenticketstariffssubscriptionsvbbtraineeticket.json
# Reading from file bvgdeenticketstariffstariffzonesandinformation.json
# Reading from file conventionvisitberlindede.json
# Reading from file destinationmunichcom20factsongermanyhtml.json
# Reading from file destinationmunichcomaccommodationmunichhtml.json
# Reading from file destinationmunichcomamberghtml.json
# Reading from file destinationmunichcomaugsburgplarrerhtml.json
# Reading from file destinationmunichcombavariamaphtml.json
# Reading from file destinationmunichcombavarianlederhosenhtml.json
# Reading from file destinationmunichcombeerhallsandrestaurantshtml.json
# Reading from file destinationmunichcombestrestaurantsinmunichhtml.json
# Reading from file destinationmunichcombustomunichhtml.json
# Reading from file destinationmunichcombuyingticketshtml.json
# Reading from file destinationmunichcomcampinginmunichhtml.json
# Reading from file destinationmunichcomcarrentalmunichgermanyhtml.json
# Reading from file destinationmunichcomcarsharingingermanyhtml.json
# Reading from file destinationmunichcomcheapmunichhostelshtml.json
# Reading from file destinationmunichcomcheapmunichhotelshtml.json
# Reading from file destinationmunichcomcheapmunichhtml.json
# Reading from file destinationmunichcomcinemasinmunichhtml.json
# Reading from file destinationmunichcomcitiesinbavariahtml.json
# Reading from file destinationmunichcomcouchsurfinginmunichhtml.json
# Reading from file destinationmunichcomdaytripsfrommunichhtml.json
# Reading from file destinationmunichcomderverrueckteeismacherhtml.json
# Reading from file destinationmunichcomdoesitsnowinmunichhtml.json
# Reading from file destinationmunichcomeatingoutwithkidsinmunichhtml.json
# Reading from file destinationmunichcomgaymunichhtml.json
# Reading from file destinationmunichcomgermanchristmastraditionshtml.json
# Reading from file destinationmunichcomgermandirndlhtml.json
# Reading from file destinationmunichcomgermanytopattractionshtml.json
# Reading from file destinationmunichcomgettingaroundmunichhtml.json
# Reading from file destinationmunichcomhelenesedlmayrhtml.json
# Reading from file destinationmunichcomherrenchiemseepalacehtml.json
# Reading from file destinationmunichcomhotelsnearmunichairporthtml.json
# Reading from file destinationmunichcominsideneuschwansteincastlephotoshtml.json
# Reading from file destinationmunichcomkaltenberghtml.json
# Reading from file destinationmunichcomkaltenbergknightsfestival2017photoshtml.json
# Reading from file destinationmunichcomklosterandechshtml.json
# Reading from file destinationmunichcomkocherlballhtml.json
# Reading from file destinationmunichcomkonigshausamschachenhtml.json
# Reading from file destinationmunichcomluxurymunichhotelshtml.json
# Reading from file destinationmunichcommapofmunichhtml.json
# Reading from file destinationmunichcommarienplatzhtml.json
# Reading from file destinationmunichcommuenchenerkindlhtml.json
# Reading from file destinationmunichcommunchenerfruhlingsfesthtml.json
# Reading from file destinationmunichcommunichairporthtml.json
# Reading from file destinationmunichcommunichairportmaphtml.json
# Reading from file destinationmunichcommunichandbavariamapshtml.json
# Reading from file destinationmunichcommunichattractionshtml.json
# Reading from file destinationmunichcommunichbackstoryhtml.json
# Reading from file destinationmunichcommunichbarsandclubshtml.json
# Reading from file destinationmunichcommunichbeergardenshtml.json
# Reading from file destinationmunichcommunichbeerhtml.json
# Reading from file destinationmunichcommunichbybikehtml.json
# Reading from file destinationmunichcommunichcafeshtml.json
# Reading from file destinationmunichcommunichchristmasmarketshtml.json
# Reading from file destinationmunichcommunichdocumentationcentreforthehistoryofnationalsocialismhtml.json
# Reading from file destinationmunichcommunichfestivalshtml.json
# Reading from file destinationmunichcommunichfordisabledtravellershtml.json
# Reading from file destinationmunichcommunichforkidshtml.json
# Reading from file destinationmunichcommunichglockenspielhtml.json
# Reading from file destinationmunichcommunichlovesyouhtml.json
# Reading from file destinationmunichcommunichmassacre1972html.json
# Reading from file destinationmunichcommunichskylineshtml.json
# Reading from file destinationmunichcommunichstreetlifefestivalhtml.json
# Reading from file destinationmunichcommunichstrongbeerfestivalhtml.json
# Reading from file destinationmunichcommunichtransportmapshtml.json
# Reading from file destinationmunichcommunichtravelguideshtml.json
# Reading from file destinationmunichcommunichtravelinfohtml.json
# Reading from file destinationmunichcommunichtravelinfohtmltransport.json
# Reading from file destinationmunichcommunichweatherhtml.json
# Reading from file destinationmunichcommunichwebcamhtml.json
# Reading from file destinationmunichcomneuschwansteincastlegermanyhtml.json
# Reading from file destinationmunichcomnewbeercarryingrecordsethtml.json
# Reading from file destinationmunichcomnymphenburgpalacehtml.json
# Reading from file destinationmunichcomoktoberfesthistoryhtml.json
# Reading from file destinationmunichcomoktoberfestmunichhtml.json
# Reading from file destinationmunichcomolympicparkhtml.json
# Reading from file destinationmunichcompartnachklammhtml.json
# Reading from file destinationmunichcompicturesofneuschwansteincastlehtml.json
# Reading from file destinationmunichcomschlosslinderhofhtml.json
# Reading from file destinationmunichcomshoppinginmunichhtml.json
# Reading from file destinationmunichcomskiresortsnearmunichhtml.json
# Reading from file destinationmunichcomsophieschollhtml.json
# Reading from file destinationmunichcomstpatricksdayinmunichhtml.json
# Reading from file destinationmunichcomsurfingmunichhtml.json
# Reading from file destinationmunichcomtheoldoktoberfestoidewiesnhtml.json
# Reading from file destinationmunichcomtollwoodhtml.json
# Reading from file destinationmunichcomtouristattractionsmunichhtml.json
# Reading from file destinationmunichcomtoursofbavariahtml.json
# Reading from file destinationmunichcomtoursofmunichhtml.json
# Reading from file destinationmunichcomtripadvisorstop10munichhotelshtml.json
# Reading from file destinationmunichcomvisarequirementsforgermanyhtml.json
# Reading from file destinationmunichcomwhereisbavariahtml.json
# Reading from file destinationmunichcomwhiterosemuseumhtml.json
# Reading from file destinationmunichcomwhiterosewalkingtourhtml.json
# Reading from file destinationmunichcomwomentravellersinmunichhtml.json
# Reading from file edgecastcom.json
# Reading from file elegantthemescom.json
# Reading from file germanyguideinfo.json
# Reading from file getyourguidecomactivitymuenchenl26drittesreichtourzufusst528partneridC2O0ZY3cmpvenmuenchenen.json
# Reading from file getyourguidedepsrcwidgetpartneridC2O0ZY3.json
# Reading from file hamburgde.json
# Reading from file jelbideenhome.json
# Reading from file karrierebvgde.json
# Reading from file koelnde.json
# Reading from file mdubaiinfodeschwabing.json
# Reading from file muenchendeenhome.json
# Reading from file munichinfoinfoairportmunich.json
# Reading from file munichinfoinfoallianzarena.json
# Reading from file munichinfoinfoaltepinakothekmunich.json
# Reading from file munichinfoinfoauthorsonya.json
# Reading from file munichinfoinfobavariankitchen.json
# Reading from file munichinfoinfobeergardensinmunich.json
# Reading from file munichinfoinfocampsitesinmunich.json
# Reading from file munichinfoinfocastlenymphenburg.json
# Reading from file munichinfoinfocategoryuncategorized.json
# Reading from file munichinfoinfodistrictsmunichdistrictsmunichrespond.json
# Reading from file munichinfoinfodistrictsmunich.json
# Reading from file munichinfoinfodistrictsmunichrespond.json
# Reading from file munichinfoinfoenglishgardenmunich.json
# Reading from file munichinfoinfofcbayernsaebenerstrasse.json
# Reading from file munichinfoinfofeldherrnhallemunich.json
# Reading from file munichinfoinfofrauenkirchemunich.json
# Reading from file munichinfoinfofussgaengerzonemuenchen.json
# Reading from file munichinfoinfogameparkpoing.json
# Reading from file munichinfoinfogarmischpartenkirchensights.json
# Reading from file munichinfoinfogasteigmunich.json
# Reading from file munichinfoinfogermanmuseum.json
# Reading from file munichinfoinfogettingroundmunich.json
# Reading from file munichinfoinfoglyptothekmunich.json
# Reading from file munichinfoinfogoodhotelsmunich.json
# Reading from file munichinfoinfohofbraeuhausmunich.json
# Reading from file munichinfoinfohofgartenmunich.json
# Reading from file munichinfoinfohostelsmunich.json
# Reading from file munichinfoinfoimprint.json
# Reading from file munichinfoinfoingolstadtsights.json
# Reading from file munichinfoinfoinnmunich.json
# Reading from file munichinfoinfo.json
# Reading from file munichinfoinfolenbachhausmunich.json
# Reading from file munichinfoinfomarienplatzmunich.json
# Reading from file munichinfoinfomaximilianeum.json
# Reading from file munichinfoinfomonasteryandechs.json
# Reading from file munichinfoinfomurnausights.json
# Reading from file munichinfoinfomuseumsmunich.json
# Reading from file munichinfoinfonationaltheatremunich.json
# Reading from file munichinfoinfonewpinacothequemuenchen.json
# Reading from file munichinfoinfonurembergsights.json
# Reading from file munichinfoinfooberammergausights.json
# Reading from file munichinfoinfooctoberfestmunich.json
# Reading from file munichinfoinfoodeonsplatzmunich.json
# Reading from file munichinfoinfoolympicmmunich.json
# Reading from file munichinfoinfoolympicparkmunich.json
# Reading from file munichinfoinfoolympicstadiummunich.json
# Reading from file munichinfoinfopensionsmunich.json
# Reading from file munichinfoinfopinakothekmodernmunich.json
# Reading from file munichinfoinfoprivacystatement.json
# Reading from file munichinfoinforesidencemunich.json
# Reading from file munichinfoinfoschwabing.json
# Reading from file munichinfoinfoseaifemunich.json
# Reading from file munichinfoinfosiegestormunich.json
# Reading from file munichinfoinfoswimmingpoolsmunich.json
# Reading from file munichinfoinfotheatergaertnerplatz.json
# Reading from file munichinfoinfotheatinerchurchmunich.json
# Reading from file munichinfoinfotraveltomunich.json
# Reading from file munichinfoinfoviktualienmarktmunich.json
# Reading from file munichinfoinfovoelkerkundemuseummunich.json
# Reading from file munichinfoinfowildparkforstenried.json
# Reading from file munichinfoinfozoomunich.json
# Reading from file munichmanualcomaboutus.json
# Reading from file munichmanualcomauthortara.json
# Reading from file munichmanualcomcategoryfirsttimer.json
# Reading from file munichmanualcomcategorylocalculture.json
# Reading from file munichmanualcomcategorywhattodo.json
# Reading from file munichmanualcomcategorywheretoeat.json
# Reading from file munichmanualcomfirsttimerhowtogettofrommunichairporttothecitycenter.json
# Reading from file munichmanualcomfirsttimerwheretostayinmunichforfirsttimevisitors.json
# Reading from file munichmanualcom.json
# Reading from file munichmanualcomlegalinformation.json
# Reading from file munichmanualcomlocalculturefirsttimetraveltipsformunich.json
# Reading from file munichmanualcomprivacypolicy.json
# Reading from file munichmanualcomwhattodobestattractionsinmunich.json
# Reading from file munichmanualcomwhattodowhattodoinmunichonsundaycomments.json
# Reading from file munichmanualcomwhattodowhattodoinmunichonsunday.json
# Reading from file munichmanualcomwheretoeatthe11coolestandtrendiestcocktailbarsinmunich.json
# Reading from file munichmanualcomwheretoeatthebestbrunchinmunichcomments.json
# Reading from file munichmanualcomwheretoeatthebestbrunchinmunich.json
# Reading from file munichmanualcomwheretoeattheultimateguidetobeergardensinmunich.json
# Reading from file munichmanualcomwheretoeatwheretofindthebestwhitesausageinmunich.json
# Reading from file munichmanualcomwheretoeatwheretofindthecheapestbarsinmunich.json
# Reading from file munichmap360communichmap.json
# Reading from file munichtravelencategoriesplanthingstodobrochuresfordownload.json
# Reading from file munichtravelen.json
# Reading from file newyearseveberlinbacktolifediegoldenenzwanzigerbeginnensilvester2022sourcede.json
# Reading from file newyearseveberlindiscotequenewyearseve202223sourcebde.json
# Reading from file newyearseveberlinoceans22newyearseveeditionsourcebde.json
# Reading from file silvesterkulturbrauereidesourcebde.json
# Reading from file soundcloudcomjobvanhardeveld.json
# Reading from file spandauerweihnachtsmarktdesourcebde.json
# Reading from file stadtmuenchendeenhtml.json
# Reading from file stadtmuenchendeinfosukrainehtml.json
# Reading from file stadtmuenchendeservice.json
# Reading from file themezeecom.json
# Reading from file unternehmenbvgdeaktuellemeldungen.json
# Reading from file unternehmenbvgdehomepage.json
# Reading from file unternehmenbvgdepress.json
# Reading from file valeriamuablogwordpresscom.json
# Reading from file visitberlindedekudamm56berlinsourcebde.json
# Reading from file visitberlindedemagyarmodern.json
# Reading from file visitberlindederomeojulialiebeistallesdasmusical.json
# Reading from file visitberlindeen15minutecity.json
# Reading from file visitberlindeenaccessibleberlin.json
# Reading from file visitberlindeenaccessiblehotelsberlin.json
# Reading from file visitberlindeenautumnberlin.json
# Reading from file visitberlindeenberlinbargainprice.json
# Reading from file visitberlindeenberlinbike.json
# Reading from file visitberlindeenberlinchildren.json
# Reading from file visitberlindeenberlincuisine.json
# Reading from file visitberlindeenberlinhistory.json
# Reading from file visitberlindeenberlinmodernismhousingestates.json
# Reading from file visitberlindeenberlinnews.json
# Reading from file visitberlindeenberlinsnewculturalcentre.json
# Reading from file visitberlindeenberlinstop10attractions.json
# Reading from file visitberlindeenberlintouristinfocentres.json
# Reading from file visitberlindeenberlinunboxedvisitberlinpodcast.json
# Reading from file visitberlindeenberlinwelcomecard.json
# Reading from file visitberlindeenbikefriendlyhotels.json
# Reading from file visitberlindeenblog.json
# Reading from file visitberlindeenchristmasberlin.json
# Reading from file visitberlindeenchristmasmarketsberlin.json
# Reading from file visitberlindeencitybreakberlin.json
# Reading from file visitberlindeenclasstripberlin.json
# Reading from file visitberlindeendeluxeberlin.json
# Reading from file visitberlindeendigitalaccessibilitydeclarationberlintourismuskongressgmbh.json
# Reading from file visitberlindeendrinkingnightlife.json
# Reading from file visitberlindeeneventberlintravelfestival.json
# Reading from file visitberlindeeneventcalendarberlin.json
# Reading from file visitberlindeeneventdonatelloinventorrenaissance.json
# Reading from file visitberlindeeneventmagyarmodern.json
# Reading from file visitberlindeeneventsberlin.json
# Reading from file visitberlindeeneventschliemannsworlds.json
# Reading from file visitberlindeeneventsclassicmusic.json
# Reading from file visitberlindeeneventtriennaledermoderne2022weimardessauberlin.json
# Reading from file visitberlindeenfamilyhotelsberlin.json
# Reading from file visitberlindeenfriedrichstadtpalastberlinsourcebde.json
# Reading from file visitberlindeengayberlinlgbtqguideberlin.json
# Reading from file visitberlindeengrouptravelberlin.json
# Reading from file visitberlindeenhotelsberlin.json
# Reading from file visitberlindeenhotelsinberlinluxuryhotels.json
# Reading from file visitberlindeenhotelsinberlinwellnesshotels.json
# Reading from file visitberlindeenindustrialarchitectureberlin.json
# Reading from file visitberlindeen.json
# Reading from file visitberlindeenlegalnotice.json
# Reading from file visitberlindeenlgbtihotelspinkpillowberlincollection.json
# Reading from file visitberlindeenlinkteasermenumonatsvorschauen.json
# Reading from file visitberlindeenlinkteasermenuticketsfurveranstaltungenen.json
# Reading from file visitberlindeenmuseumpassberlin.json
# Reading from file visitberlindeenmuseumsberlin.json
# Reading from file visitberlindeenneighbourhoodsberlin.json
# Reading from file visitberlindeenprivacystatement.json
# Reading from file visitberlindeenreportbarrier.json
# Reading from file visitberlindeenrestaurantsberlin.json
# Reading from file visitberlindeenshopping.json
# Reading from file visitberlindeenshowsmusicals.json
# Reading from file visitberlindeensightsberlin.json
# Reading from file visitberlindeensightseeinginberlin.json
# Reading from file visitberlindeensightseeingtoursberlin.json
# Reading from file visitberlindeenspecialdealsberlin.json
# Reading from file visitberlindeensportseventsleisuresportsberlin.json
# Reading from file visitberlindeenspringberlin.json
# Reading from file visitberlindeensummerberlin.json
# Reading from file visitberlindeensustainableberlin.json
# Reading from file visitberlindeentheatresvenuesberlin.json
# Reading from file visitberlindeenticketsattractionsberlin.json
# Reading from file visitberlindeenticketsberlinmuseumislanddayticket.json
# Reading from file visitberlindeenticketsberlintvtowerandrestaurantsphere.json
# Reading from file visitberlindeenticketsbestberlintourbusdiscoverfamoussights.json
# Reading from file visitberlindeenticketsboattoursrivercruisesberlin.json
# Reading from file visitberlindeenticketsdayticketnaturalhistorymuseumberlin.json
# Reading from file visitberlindeenticketseventsattractionsberlin.json
# Reading from file visitberlindeenticketsfastviewticketberlintvtower.json
# Reading from file visitberlindeenticketsguidedwalkingtoursberlin.json
# Reading from file visitberlindeenticketshoponhopoffsightseeingbustoursberlin.json
# Reading from file visitberlindeenticketsmuseumexhibitionsberlin.json
# Reading from file visitberlindeenticketszooaquariumtierparkberlin.json
# Reading from file visitberlindeentipsofthedayeventsberlin.json
# Reading from file visitberlindeentopeventsberlin.json
# Reading from file visitberlindeentopexhibitionsberlin.json
# Reading from file visitberlindeentravellingberlin.json
# Reading from file visitberlindeentravelplanning.json
# Reading from file visitberlindeenweekendtips.json
# Reading from file visitberlindeenwellnessberlin.json
# Reading from file visitberlindeenyourtraveladvisor.json
# Reading from file viveberlintourscomde.json
# Reading from file viveberlintourscomenaboutus.json
# Reading from file viveberlintourscomenberlintouristguides.json
# Reading from file viveberlintourscomencontactus.json
# Reading from file viveberlintourscomenfaq.json
# Reading from file viveberlintourscomenfoodinberlin.json
# Reading from file viveberlintourscomenguidecooperative.json
# Reading from file viveberlintourscomenmonumentsofberlinyouhavetovisit.json
# Reading from file viveberlintourscomenmuseumsinberlin.json
# Reading from file viveberlintourscomenprivatetoursinberlin.json
# Reading from file viveberlintourscomenpublictransportationinberlin.json
# Reading from file viveberlintourscomentermsandconditions.json
# Reading from file viveberlintourscomentourallofberlintour.json
# Reading from file viveberlintourscomentourfoodtourberlin.json
# Reading from file viveberlintourscomentoursachsenhausenconcentrationcampberlintour.json
# Reading from file viveberlintourscomentravelblogberlincharlottenburgpalaceberlin.json
# Reading from file viveberlintourscomentravelblogberlinhitlersbunkerinberlin.json
# Reading from file viveberlintourscomentravelblogberlin.json
# Reading from file viveberlintourscomentravelblogberlinthebookburninginberlin.json
# Reading from file viveberlintourscomentravelblogberlinunderdenlindenberlins.json
# Reading from file viveberlintourscomentravelblogberlinvirtualguidedtoursberlin.json
# Reading from file viveberlintourscomentravelblogberlinvisitberlinsummer2020covid19.json
# Reading from file viveberlintourscomenviveberlinandthestumblingstones.json
# Reading from file viveberlintourscomfr.json
# Reading from file viveberlintourscomimpressum.json
# Reading from file viveberlintourscomit.json
# Reading from file viveberlintourscom.json
# Reading from file viveberlintourscompt.json
# Reading from file wordpressorg.json

# %%
for text in texts[:10]:
# process paragraphs individually in a stream (multi-thread)
  for doc in nlp.pipe(text, batch_size=50):
    spans = doc.spans  # coreference
    pprint(doc.text)
    pprint(spans)
    print()
# Out:
# 'Bitte aktivieren Sie Javascript in Ihrem Browser.'
# {}
#
# ('Sie möchten für eine der faszinierendsten und erfolgreichsten Städte '
#  'arbeiten? Ob Beratung und Verkauf in einer Berlin Tourist Info, weltweites '
#  'Marketing oder als Vertriebsprofi – die Arbeitsgebiete bei uns sind sehr '
#  'vielfältig. Hier finden Sie alles rund um Jobs, Praktika undAusbildung bei '
#  'visitBerlin.')
# {'coref_clusters_1': [Sie möchten, Sie alles]}
#
# ('\n'
#  '    \n'
#  '                                \n'
#  '                                                                                                  \n'
#  '  Sie werben für Berlin\n'
#  '\n'
#  '  ')
# {}
#
# ('\n'
#  '    \n'
#  '                                \n'
#  '                                                                                                  \n'
#  '  Gutes Arbeitsklima\n'
#  '\n'
#  '  ')
# {}
#
# ('\n'
#  '    \n'
#  '                                \n'
#  '                                                                                                  \n'
#  '  Modernes und kreatives Destinationsmarketing\n'
#  '\n'
#  '  ')
# {}
#
# ('\n'
#  '    \n'
#  '                                \n'
#  '                                                                                                  \n'
#  '  Eigenverantwortliches Arbeiten\n'
#  '\n'
#  '  ')
# {}
#
# ('\n'
#  '    \n'
#  '                                \n'
#  '                                                                                                  \n'
#  '  Flexible Arbeitszeiten\n'
#  '\n'
#  '  ')
# {}
#
# ('\n'
#  '    \n'
#  '                                \n'
#  '                                                                                                  \n'
#  '  Vorteile eines Unternehmens der Reiseindustrie\n'
#  '\n'
#  '  ')
# {}
#
# ('\n'
#  '                                \n'
#  '                                                                                                  \n'
#  '  Erfahren Sie mehr über uns\n')
# {}
#
# ('\n'
#  '                                \n'
#  '                                                                                                  \n'
#  '  Was macht uns aus? Welche Vorteile genießen visitBerlin-Angestellte?\n')
# {}
#
# ('Hier finden Sie unsere aktuellen Stellenausschreibungen. Bewerben Sie sich '
#  'bei uns!')
# {'coref_clusters_1': [Sie unsere, Sie sich]}
#
# ('\n'
#  '            \n'
#  '                                \n'
#  '                                                                                                  \n'
#  '  Geschäftsfeld Produkt & Vertrieb / Abteilung Produktmanagement und '
#  '-entwicklung \n'
#  '\n'
#  '    ')
# {}
#
# ('\n'
#  '            \n'
#  '                                \n'
#  '                                                                                                  \n'
#  '  Geschäftsfeld Destinationsmanagement & Unternehmensentwicklung/ Abteilung '
#  'Controlling\n'
#  '\n'
#  '    ')
# {}
#
# ('\n'
#  '            \n'
#  '                                \n'
#  '                                                                                                  \n'
#  '  Geschäftsfeld Destinationsmanagement & Unternehmensentwicklung/ Abteilung '
#  'Personal & Recht\n'
#  '\n'
#  '    ')
# {}
#
# ('\n'
#  '            \n'
#  '                                \n'
#  '                                                                                                  \n'
#  '  Kaufleute für Marketingkommunikation planen, entwickeln kommunikative, '
#  'zielgruppengerechte Marketing- und Werbemaßnahmen, und strategische '
#  'Konzepte.\n'
#  '\n'
#  '    ')
# {}
#
# ('\n'
#  '            \n'
#  '                                \n'
#  '                                                                                                  \n'
#  '  Geschäftsfeld Produkt & Vertrieb/ Abteilung Berlin Tourist Information \n'
#  '\n'
#  '    ')
# {}
#
# ('\n'
#  '            \n'
#  '                                \n'
#  '                                                                                                  \n'
#  '  Geschäftsfeld Produkt & Vertrieb/ Abteilung Produktmanagement '
#  'und-entwicklung \n'
#  '\n'
#  '    ')
# {}
#
# ('\n'
#  '          \n'
#  '                                \n'
#  '                                                                                                  \n'
#  '  Ausbildung, duales Studieren und Praktika bei uns\n'
#  '\n'
#  '          ')
# {}
#
# ('\n'
#  '                \n'
#  '                                \n'
#  '                                                                                                  \n'
#  '  Wie läuft eine Bewerbung bei visitBerlin ab?\n'
#  '\n'
#  '                ')
# {}
#
# ('\n'
#  '                \n'
#  '                                \n'
#  '                                                                                                  \n'
#  '  Das berufliche Qualifizierungsnetzwerk\n'
#  '\n'
#  '                ')
# {}
#
# ('\n'
#  '                \n'
#  '                                \n'
#  '                                                                                                  \n'
#  '  Mit Bewerbungen gehen wir datenschutzkonform um\n'
#  '\n'
#  '                ')
# {}
#
# ('\n'
#  '                \n'
#  '                                \n'
#  '                                                                                                  \n'
#  '  hier bloggen wir\n'
#  '\n'
#  '                ')
# {}
#
# ('\n'
#  '                                \n'
#  '                                                                                                  \n'
#  '  Leiter Personal & Recht\n')
# {}
#
# ('\n'
#  '                                \n'
#  '                                                                                                  \n'
#  '  HR Administration Managerin\n')
# {}
#
# ('\n'
#  '                                \n'
#  '                                                                                                  \n'
#  '  Wer steckt hinter visitBerlin?\n')
# {}
#
# ('\n'
#  '                                \n'
#  '                                                                                                  \n'
#  '  Die Aufgaben unserer Geschäftsbereiche und unser Organigramm\n')
# {}
#
# 'Bitte aktivieren Sie Javascript in Ihrem Browser.'
# {}
#
# ('visitBerlin ist die offizielle Marketingagentur der Stadt und wirbt weltweit '
#  'für Berlin als Tourismus- und Kongressdestination. Gemeinsam mit Partnern '
#  'aus Politik, Wirtschaft und Gesellschaft verfolgt visitBerlin das Ziel, den '
#  'Berlin-Tourismus weiterzuentwickeln und zukunftsfähig aufzustellen. Im '
#  'Mittelpunkt stehen Stadtverträglichkeit und Nachhaltigkeit.')
# {'coref_clusters_1': [visitBerlin ist, visitBerlin das],
#  'coref_clusters_2': [Berlin als, Berlin-]}
#
# ('\n'
#  '          \n'
#  '                                \n'
#  '                                                                                                  \n'
#  '  Unsere Aufgaben\n'
#  '\n'
#  '          ')
# {}
#
# ('\n'
#  '                \n'
#  '                                \n'
#  '                                                                                                  \n'
#  '  Zahlen, Daten, Fakten zum Berlin-Tourismus\n'
#  '\n'
#  '                ')
# {}
#
# ('\n'
#  '                \n'
#  '                                \n'
#  '                                                                                                  \n'
#  '  Werden Sie visitBerliner!\n'
#  '\n'
#  '                ')
# {}
#
# ('\n'
#  '                \n'
#  '                                \n'
#  '                                                                                                  \n'
#  '  Ihre Ansprechpartner\n'
#  '\n'
#  '                ')
# {}
#
# ('\n'
#  '                \n'
#  '                                \n'
#  '                                                                                                  \n'
#  '  Unser Jahr im Rückblick\n'
#  '\n'
#  '                ')
# {}
#
# ('\n'
#  '          \n'
#  '                                \n'
#  '                                                                                                  \n'
#  '  visitBerlins E-Learning-Plattform für Partner\n'
#  '\n'
#  '          ')
# {}
#
# ('\n'
#  '          \n'
#  '                                \n'
#  '                                                                                                  \n'
#  '  Informationen, Termine, Förderungen\n'
#  '\n'
#  '          ')
# {}
#
# ('\n'
#  '          \n'
#  '                                \n'
#  '                                                                                                  \n'
#  '  Berlins & visitBerlins nachhaltiger Weg\n'
#  '\n'
#  '          ')
# {}
#
# ('\n'
#  '        \n'
#  '                                \n'
#  '                                                                                                  \n'
#  '  Nächste Woche startet Berlin mit 70 einzigartigen Weihnachtsmärkten in die '
#  'Weihnachtssaison. Ausblick auf 2023\n'
#  '\n'
#  '      ')
# {}
#
# ('Berlin, \n'
#  '                                \n'
#  '                                                                                                  \n'
#  '  14. November 2022')
# {}
#
# ('\n'
#  '        \n'
#  '                                \n'
#  '                                                                                                  \n'
#  '  Glitzer, Pailletten & Geschichten: In dieser „Berlin Unboxed“-Folge '
#  'blicken wir hinter die Kulissen des Theaters des Westens\n'
#  '\n'
#  '      ')
# {}
#
# ('Berlin, \n'
#  '                                \n'
#  '                                                                                                  \n'
#  '  14. November 2022')
# {}
#
# ('\n'
#  '        \n'
#  '                                \n'
#  '                                                                                                  \n'
#  '  Zusammen mit vielen Vertreter:innen der Berliner Visitor Economy '
#  'präsentierte visitBerlin die deutsche Hauptstadt in London\n'
#  '\n'
#  '      ')
# {}
#
# ('Berlin, \n'
#  '                                \n'
#  '                                                                                                  \n'
#  '  11. November 2022')
# {}
#
# ('\n'
#  '        \n'
#  '                                \n'
#  '                                                                                                  \n'
#  '  24 Köpfe für neue Impulse im Berlin-Tourismus - eine Initiative der '
#  'Senatsverwaltung für Wirtschaft, Bezirke & visitBerlins\n'
#  '\n'
#  '      ')
# {}
#
# ('Berlin, \n'
#  '                                \n'
#  '                                                                                                  \n'
#  '  11. November 2022')
# {}
#
# ('\n'
#  '        \n'
#  '                                \n'
#  '                                                                                                  \n'
#  '  Rund 1,1 Million Gäste und 2,6 Millionen Übernachtungen in den Hotels der '
#  'Stadt \n'
#  '\n'
#  '      ')
# {}
#
# ('Berlin, \n'
#  '                                \n'
#  '                                                                                                  \n'
#  '  10. November 2022')
# {}
#
# ('\n'
#  '        \n'
#  '                                \n'
#  '                                                                                                  \n'
#  '  Berlin hält sich laut „Global Destination Sustainability Index“ auf Platz '
#  '5 der weltweit nachhaltigsten Metropolen\n'
#  '\n'
#  '      ')
# {'coref_clusters_1': [Berlin hält, sich laut]}
#
# ('Berlin, \n'
#  '                                \n'
#  '                                                                                                  \n'
#  '  9. November 2022')
# {}
#
# ('\n'
#  '        \n'
#  '                                \n'
#  '                                                                                                  \n'
#  '  Berlin wird an die Silvestertradition anknüpfen und erstmals nationale und '
#  'internationale Gäste am Pariser Platz begrüßen\n'
#  '\n'
#  '      ')
# {}
#
# ('Berlin, \n'
#  '                                \n'
#  '                                                                                                  \n'
#  '  7. November 2022')
# {}
#
# ('\n'
#  '        \n'
#  '                                \n'
#  '                                                                                                  \n'
#  '  Einkaufen in Berlin ist so außergewöhnlich wie die Stadt selbst – '
#  'besonders cool im Winter. Neuer Pressetext\n'
#  '\n'
#  '      ')
# {}
#
# ('Berlin, \n'
#  '                                \n'
#  '                                                                                                  \n'
#  '  4. November 2022')
# {}
#
# ('\n'
#  '        \n'
#  '                                \n'
#  '                                                                                                  \n'
#  '  Das Konzept der 15-Minuten-Stadt wird erstmals auf den Tourismus '
#  'angewendet. Neue Kampagne gestartet. Zur PM und zum Video\n'
#  '\n'
#  '      ')
# {}
#
# ('Berlin, \n'
#  '                                \n'
#  '                                                                                                  \n'
#  '  4. November 2022')
# {}
#
# ('\n'
#  '        \n'
#  '                                \n'
#  '                                                                                                  \n'
#  '  Wie nehmen die Einwohner:innen den Tourismus in Berlin wahr? Sie sehen '
#  'große Vorteile für Berlin\n'
#  '\n'
#  '      ')
# {'coref_clusters_1': [Berlin wahr, Berlin
#
#       ]}
#
# ('Berlin, \n'
#  '                                \n'
#  '                                                                                                  \n'
#  '  2. November 2022')
# {}
#
# ('\n'
#  '        \n'
#  '                                \n'
#  '                                                                                                  \n'
#  '  Berlin hat sich als Standort für Wissenschaftskonferenzen etabliert\n'
#  '\n'
#  '      ')
# {'coref_clusters_1': [Berlin hat, sich als]}
#
# ('Berlin, \n'
#  '                                \n'
#  '                                                                                                  \n'
#  '  14. Oktober 2022')
# {}
#
# ('\n'
#  '        \n'
#  '                                \n'
#  '                                                                                                  \n'
#  '  Berliner Erfolgsmodell: Bereits 246 Veranstaltungen mit 200.000 '
#  'Teilnehmenden unterstützt. Verlängerung bis Ende 2023\n'
#  '\n'
#  '      ')
# {}
#
# ('Berlin, \n'
#  '                                \n'
#  '                                                                                                  \n'
#  '  13. Oktober 2022')
# {}
#
# ('\n'
#  '                                \n'
#  '                                                                                                  \n'
#  '  Tourismus ist gut für Berlin\n')
# {}
#
# ('\n'
#  '                                \n'
#  '                                                                                                  \n'
#  '  Neue Kampagne für Berlins Visitor Economy und Eventbranche: Berliner:innen '
#  'und Firmen haben einen Mehrwert vom Tourismus\n')
# {}
#
# ('In Berlin trifft man nicht nur die Welt. Berlin selbst ist eine Welt für '
#  'sich. Mehr über unsere Kampagne')
# {'coref_clusters_1': [Berlin trifft, Berlin selbst],
#  'coref_clusters_2': [die Welt., eine Welt für sich.]}
#
# ('\n'
#  '                                \n'
#  '                                                                                                  \n'
#  '  Das erwartet Sie 2023\n')
# {}
#
# ('\n'
#  '          \n'
#  '                                \n'
#  '                                                                                                  \n'
#  '  Unterstützung für Unternehmen \n'
#  '\n'
#  '          ')
# {}
#
# ('\n'
#  '          \n'
#  '                                \n'
#  '                                                                                                  \n'
#  '  Die wichtigsten Informationen\n'
#  '\n'
#  '          ')
# {}
#
# ('\n'
#  '          \n'
#  '                                \n'
#  '                                                                                                  \n'
#  '  Initiative Tourismus- und Veranstaltungswirtschaft\n'
#  '\n'
#  '          ')
# {}
#
# ('\n'
#  '                                \n'
#  '                                                                                                  \n'
#  '  Alle Informationen für Berlin-Besucher:innen\n')
# {}
#
# 'Bitte aktivieren Sie Javascript in Ihrem Browser.'
# {}
#
# ('Das Marktmanagement ist dafür verantwortlich, Berlin als touristische '
#  'Reisedestination weltweit zu positionieren und zu vermarkten. Dafür bieten '
#  'wir unseren Partnern aus der Reiseindustrie sowie Medienvertretern '
#  'zahlreiche Serviceleistungen: von der Produktschulung über Famtrips bis hin '
#  'zu Promotion-Materialien für Ihre Kunden sowie Unterstützung bei '
#  'Pressereisen und Recherchematerial für Ihre Arbeit. Fragen Sie uns – wir '
#  'kennen Berlin.')
# {'coref_clusters_1': [wir unseren, wir kennen],
#  'coref_clusters_2': [Berlin als touristische Reisedestination weltweit, Berlin.]}
#
# 'In den USA und Kanada haben wir eine\xa0Repräsentanz.'
# {}
#
# ('\n'
#  '                                \n'
#  '                                                                                                  \n'
#  '  Director Market Management I\r\n'
#  'Market & Media Relations Manager Asien, Nordamerika, Australien, Mittlerer '
#  'Osten\n')
# {}
#
# ('\n'
#  '                                \n'
#  '                                                                                                  \n'
#  '  Deputy Director Market Management I Market & Media Relations Manager für '
#  'DACH, UK/IE, Nordics, Osteuropa, Russland, Israel\n')
# {}
#
# ('\n'
#  '                                \n'
#  '                                                                                                  \n'
#  '  Market & Media Relations Manager I Lateinamerika, BeNeLux, Frankreich, '
#  'Spanien, Italien\n')
# {}
#
# ('\n'
#  '                                \n'
#  '                                                                                                  \n'
#  '  Projektmanagerin Presse- und Fam Trips\n')
# {}
#
# ('\n'
#  '                                \n'
#  '                                                                                                  \n'
#  '  Projektmangerin | Medical Tourism Managerin\n')
# {}
#
# ('\n'
#  '                                \n'
#  '                                                                                                  \n'
#  '  Special Projects Managerin \n')
# {}
#
# ('\n'
#  '                                \n'
#  '                                                                                                  \n'
#  '  Office-Managerin \n')
# {}
#
# ('\n'
#  '                                \n'
#  '                                                                                                  \n'
#  '  Backoffice-Managerin\n')
# {}
#
# ('\n'
#  '                                \n'
#  '                                                                                                  \n'
#  '  Projektmanagerin Presse- und Fam Trips\n')
# {}
#
# ('\n'
#  '                                \n'
#  '                                                                                                  \n'
#  '  in Elternzeit\n')
# {}
#
# 'Bitte aktivieren Sie Javascript in Ihrem Browser.'
# {}
#
# ('Wie entwickelt sich das Tourismus- und Kongressgeschäft in Berlin? Auf '
#  'unserer Webseite informieren wir über aktuelle Neuigkeiten.')
# {}
#
# ('\n'
#  '    \n'
#  '                                \n'
#  '                                                                                                  \n'
#  '  Texte, Fotos und Videos\n'
#  '\n'
#  '  ')
# {}
#
# ('\n'
#  '    \n'
#  '                                \n'
#  '                                                                                                  \n'
#  '  Presse- und Blogger-Reisen\n'
#  '\n'
#  '  ')
# {}
#
# ('\n'
#  '    \n'
#  '                                \n'
#  '                                                                                                  \n'
#  '  Unsere News via Twitter\n'
#  '\n'
#  '  ')
# {}
#
# ('\n'
#  '    \n'
#  '                                \n'
#  '                                                                                                  \n'
#  '  Presse-Verteiler\n'
#  '\n'
#  '  ')
# {}
#
# ('\n'
#  '          Berlin, 14.11.22\r\n'
#  'Nächste Woche startet Berlin mit 70 einzigartigen Weihnachtsmärkten in die '
#  'Weihnachtssaison \n'
#  '        ')
# {'coref_clusters_1': [Berlin,, Berlin mit]}
#
# ('\n'
#  '          Berlin, 10.11.22\r\n'
#  'Rund 1,1 Million Gäste und 2,6 Millionen Übernachtungen in den Hotels der '
#  'Stadt \n'
#  '        ')
# {}
#
# ('\n'
#  '          Berlin, 9.11.22\r\n'
#  'Berlin gehört laut „Global Destination Sustainability Index“ zu den 30 '
#  'nachhaltigsten Reisezielen weltweit und hält Platz 5 der welt\n'
#  '        ')
# {'coref_clusters_1': [Berlin,, Berlin gehört]}
#
# ('\n'
#  '                                \n'
#  '                                                                                                  \n'
#  '  Pressesprecher')
# {}
#
# ('\n'
#  '                                \n'
#  '                                                                                                  \n'
#  '  Team der Pressestelle\n')
# {}
#
# ('\n'
#  '                                \n'
#  '                                                                                                  \n'
#  '  Team Pressereisen\n')
# {}
#
# 'Folgen Sie unserem Corporate Twitter-Kanal @visitBerlinNews.'
# {}
#
# ('\n'
#  '          \n'
#  '                                \n'
#  '                                                                                                  \n'
#  '  Texte, Fotos und Videos herunterladen\n'
#  '\n'
#  '          ')
# {}
#
# ('\n'
#  '                \n'
#  '                                \n'
#  '                                                                                                  \n'
#  '  Informiert bleiben\n'
#  '\n'
#  '                ')
# {}
#
# ('\n'
#  '                \n'
#  '                                \n'
#  '                                                                                                  \n'
#  '  Wir unterstützen Sie bei der Recherche in Berlin\n'
#  '\n'
#  '                ')
# {'coref_clusters_1': [Wir unterstützen, Sie bei]}
#
# ('\n'
#  '                \n'
#  '                                \n'
#  '                                                                                                  \n'
#  '   Aktuelle Statistiken\n'
#  '\n'
#  '                ')
# {}
#
# ('\n'
#  '                \n'
#  '                                \n'
#  '                                                                                                  \n'
#  '  Wir schreiben über unsere Stadt\n'
#  '\n'
#  '                ')
# {}
#
# 'Bitte aktivieren Sie Javascript in Ihrem Browser.'
# {}
#
# ('visitBerlin ist Berlins offizielle Tourismusorganisation und erreicht mit '
#  'seinen Medien Millionen von Berlin-Besuchern. Profitieren Sie mit Ihrer '
#  'Werbung von unseren digitalen Reichweiten, den touristischen Publikationen '
#  'oder zielgruppenspezifischen Newslettern.')
# {}
#
# ('\n'
#  '                                \n'
#  '                                                                                                  \n'
#  '  Werben Sie auf Berlins offiziellem Reiseportal.\n')
# {}
#
# ('\n'
#  '                                \n'
#  '                                                                                                  \n'
#  '  Sie möchten Ihre Anzeige in unseren Publikationen der City Cards '
#  'platzieren oder mit einem redaktionellen Eintrag werben?\n')
# {}
#
# ('\n'
#  '                                \n'
#  '                                                                                                  \n'
#  '  Integrieren Sie einen Teaser in den Newslettern oder gestalten Sie ein '
#  'eigenes Mailing.\n')
# {}
#
# ('\n'
#  '                                \n'
#  '                                                                                                  \n'
#  '  Wir bieten unseren Partnern zielgruppenspezifische Aktionen: für '
#  'Endkunden, Journalisten, Reise- und Kongressindustrie.\n')
# {}
#
# ('\n'
#  '                                \n'
#  '                                                                                                  \n'
#  '  Leitung Key Account Sales\n')
# {}
#
# ('\n'
#  '                                \n'
#  '                                                                                                  \n'
#  '  Projektmanagerin Stakeholderformate')
# {}
#
# 'Hi and Welcome to the Absolute Munich blog!\xa0'
# {}
#
# ('We’re FRED and MARK, just a couple of regular bloggers who happen to LOVE '
#  'Munich, care DEEPLY for the environment, and have a PASSION for sharing our '
#  'extensive and diverse range of Munich and Bavarian experiences with others.')
# {'coref_clusters_1': [We’re, our extensive],
#  'coref_clusters_2': [Munich,, Munich and]}
#
# ('We aim to research, experience and deliver our content in the most\xa0'
#  'SOCIALLY responsible form, and we strive to publish the best possible '
#  'content on Munich and Bavaria that we are mentally and physically able to.')
# {'coref_clusters_1': [We aim, our content, we strive, we are]}
#
# ('It is our SINCERE hope that this blog will assist and inspire you, our '
#  'readers, to be able to experience and enjoy this part of the world as much '
#  'as we do.')
# {'coref_clusters_1': [our SINCERE, our readers, we do]}
#
# 'The “Fun” About Me Bit:'
# {}
#
# 'I’m a curious fuzz ball who just wants to see more and know more!'
# {}
#
# ('With my Asian and Australian background, food, nature, and sport are '
#  'inescapable parts of me. Having lived in five different countries and '
#  'traveled (and backpacked) in between, I understand that it is never easy to '
#  'start in a new city.')
# {'coref_clusters_1': [my Asian, me., I understand]}
#
# ('This time around, lucky me, my partner in crime is German and he grew up in '
#  'Munich. So I have discovered so many fun, random and historical facts about '
#  'this city and I’m ready to share these with you, making your stay/visit here '
#  'more homely and exciting!')
# {'coref_clusters_1': [me,, my partner, I have, I’m],
#  'coref_clusters_2': [my partner in crime is, he grew],
#  'coref_clusters_3': [Munich., this city and],
#  'coref_clusters_4': [so many fun, random and historical facts about, these with]}
#
# ('My professional background is in interior design and visual merchandising. I '
#  'know it sounds typical, but I love wandering in markets, sussing out vintage '
#  'clothes and furniture, and taking pictures of beautiful things.')
# {'coref_clusters_1': [My professional, I know, I love],
#  'coref_clusters_2': [My professional background is, it sounds]}
#
# ('The other side of me is that I am a bit of a hippy, dirtbag climber. Whilst '
#  'I enjoy the fancy side of life, there’s nothing better than getting rugged '
#  'in Nature. This is where my “green” consciousness kicks in.')
# {'coref_clusters_1': [me is, I am, I enjoy, my “],
#  'coref_clusters_2': [getting rugged, This is]}
#
# ('As I spend most weekends climbing, nature affects me a lot! Being '
#  'sustainable is therefore part of my daily goal. In this blog, I hope to give '
#  'a positive spin on this!')
# {'coref_clusters_1': [I spend, me a, my daily, I hope],
#  'coref_clusters_2': [Being sustainable is, this!]}
#
# 'The “Boring” About Me Bit:\xa0'
# {}
#
# 'I started baking bread after arriving in Germany!'
# {}
#
# 'The “Fun” About Me Bit:'
# {}
#
# 'I’m just an average normal everyday Australian guy.\xa0'
# {}
#
# ('As long as average/normal and everyday means avid traveller (over 50 '
#  'countries), sports lover, everyday blogger and dedicated parent. Cause I’m '
#  'all those things as well.')
# {}
#
# ('I’ve been building websites and blogging for what seems like forever! You '
#  'could say it’s a bit of an addiction for me as I just can’t seem to stop. I '
#  'love the creative process of blogging and I also love helping others with '
#  'their blogging and business goals.\xa0')
# {'coref_clusters_1': [blogging for, it’s],
#  'coref_clusters_2': [I’ve, me as, I just, I love, I also],
#  'coref_clusters_3': [others with, their blogging]}
#
# ('From time-to-time my “inner kid” breaks out and takes charge and this '
#  'usually results in more travel, cultural faux pas and getting into some fun '
#  'mischief with my two girls, whom I adore.')
# {'coref_clusters_1': [breaks out, this usually],
#  'coref_clusters_2': [my “, my two, I adore]}
#
# ('I’ve been to Oktoberfest in Munich over twenty times and spent nearly 250 '
#  'days inside those famous Munich Beer Halls….and Munich is just one of my '
#  'many festival traveling vices. I’ve also been to the ridiculous Spanish '
#  'Tomato Fight of La Tomatina on multiple occasions, as well as the equally '
#  'amazing (but much less known) Wine Fight held annually in Haro, in the Rioja '
#  'region of Spain. Spain has some amazing festivities!')
# {'coref_clusters_1': [Munich over, Munich Beer, Munich is],
#  'coref_clusters_2': [I’ve, my many, I’ve],
#  'coref_clusters_3': [Spain., Spain has]}
#
# ('I’ve extensively traveled Africa, Europe, Asia, and Australia but am '
#  'continually plagued by the knowledge that there is so much more to see and '
#  'do on this incredible planet.')
# {}
#
# 'The “Boring” About Me Bit:\xa0'
# {}
#
# ('Whilst I still travel to Munich regularly I actually live in a small village '
#  'in Berkshire in the UK.')
# {'coref_clusters_1': [I still, I actually]}
#
# ('I actually do have my own Digital Marketing business which I’d love you to '
#  'check out if you have any interest! I am well versed in web design, social '
#  'media marketing, SEO, and video production.')
# {'coref_clusters_1': [I actually, my own, I’d, I am]}
#
# 'I like sleeping and kayaking!'
# {}
#
# ('Munich is one of the most incredible cities not only in Bavaria, but in '
#  'Germany as well. Munich is renowned throughout Europe for it’s green spaces, '
#  'architecture, history, cosmopolitan vibe and friendly people.')
# {'coref_clusters_1': [Munich is, Munich is, it’s green]}
#
# ('Noted as 3rd place in a list of The World’s Healthiest Cities,\xa0compiled '
#  'utilising advanced methodology by the team at Spot a Home, Munich is '
#  'consistently rated as both top place to live and a top place to visit. '
#  'Munich, being such a desirable place to live in Bavaria and in Germany, is a '
#  'little more expensive overall, than the rest of the country – but absolutely '
#  'the pros will always outweigh the cons of this incredible city.')
# {'coref_clusters_1': [Munich is, Munich, being such a desirable place to live in Bavaria and in Germany,, this incredible city.],
#  'coref_clusters_2': [Germany,, the country –]}
#
# ('To deliver the best possible content in the most socially responsible manner '
#  'we can. We strive to provide the most “on-point” information available, so '
#  'you too can have an AMAZING Munich experience.')
# {'coref_clusters_1': [we can, We strive]}
#
# ('Please check out our BLOG which we continually update with info about the '
#  'City of Munich, Things to do in Munich and all the Best Stuff to See in '
#  'Munich. We include day-trip experiences from Munich throughout Bavaria (and '
#  'even beyond), and we provide a unique insight and perspective from a locals '
#  'point of view (Fred) and from a regular visitors point of view (Mark).')
# {'coref_clusters_1': [our BLOG, we continually, We include, we provide],
#  'coref_clusters_2': [the City of Munich,, Munich and, Munich., Munich throughout]}
#
# 'Copyright © | 2022 | Absolute Munich'
# {}
#
# 'Munich - Bavaria - Germany\nEmail: hello@absolutemunich.com'
# {}
#
# ('There are a huge selection of art galleries, and museums in Munich, but if '
#  'you’re an art lover, particularly a classical art lover, then the Alte '
#  'Pinakothek Munich should definitely be number one on your list of Munich '
#  'Museums to visit. ')
# {'coref_clusters_1': [Munich,, Munich Museums]}
#
# ('Providing an enjoyable afternoon among beautiful paintings, the Alte '
#  'Pinakothek in Munich is a world-famous art gallery with a collection of '
#  'Classical Art that is favoured among tourists and locals alike. ')
# {}
#
# ('In this article, we outline what secrets the Alte Pinakothek holds for you '
#  'as a visitor, as well as detail its location, ticketing, and how to get '
#  'there. This is a Munich Art Museum you simply won’t want to miss.')
# {'coref_clusters_1': [the Alte Pinakothek holds, its location, This is]}
#
# ('The Alte Pinakothek is an Art Museum in central Munich housing paintings of '
#  'incredible worth, and it is one of the oldest and most magnificent painting '
#  'collections in all of Europe.')
# {'coref_clusters_1': [The Alte Pinakothek is, it is]}
#
# ('The Alte Pinakothek is specifically noted for its paintings by 14th- to '
#  '18th-century European masters, and is part of a number of art galleries '
#  'located throughout Munich and Bavaria and administered by Bayerische '
#  'Staatsgemäldesammlungen (Bavarian State Painting Collections). ')
# {'coref_clusters_1': [The Alte Pinakothek is, its paintings]}
#
# ('Known locally as the Die Pinakotheken, many of the pieces showcased within '
#  'the Alte Pinakothek originate from the Wittelsbach family collection of art '
#  'in a showcase of masterful paintings that grew so large, they had to '
#  'purpose-build a museum for the collection. On show at any one time, there '
#  'will only ever be 800 or so paintings, although the collection itself is '
#  'vastly larger and reported to be in the many thousands.')
# {'coref_clusters_1': [the Wittelsbach family collection of art in, they had],
#  'coref_clusters_2': [the Wittelsbach family collection of art in, the collection., the collection itself is, itself is]}
#
# ('It was in the year 1826 that King Ludwig I of Bavaria commissioned his court '
#  'architect, Leo Von Kleeze, to design and oversee construction of the Alte '
#  'Pinakothek as part of Munich’s first “group of “official” Art Galleries '
#  'centred around Königsplatz.')
# {'coref_clusters_1': [King Ludwig I of Bavaria commissioned, his court]}
#
# ('Completed in 1836, the Alte Pinakothek Munich was among the first of '
#  'Munich’s many art galleries!')
# {'coref_clusters_1': [the Alte Pinakothek Munich was, Munich’s many]}
#
# ('Leo Von Kleeze had previously been personally involved with excavations of '
#  'ancient buildings in\xa0Greece and had actually submitted his own proposals '
#  'for the restoration of the\xa0Acropolis. He shared and encouraged the vision '
#  'of King Ludwig I to create an “Athens on the Isar”.')
# {'coref_clusters_1': [Leo Von Kleeze had, his own, He shared]}
#
# ('Von Kleeze was actually a neoclassicist\xa0architect, painter and writer, '
#  'and was much favoured by the court due to his artistic talents. He was also '
#  'instrumental in designing other museums and monuments in Munich such as the '
#  'Glyptothek, which is Munich’s oldest public museum and the very well known '
#  'Bavaria Statue and Ruhmeshalle\xa0(“hall of fame”) that stands behind Lady '
#  'Bavaria.')
# {'coref_clusters_1': [Von Kleeze was, his artistic, He was],
#  'coref_clusters_2': [Munich such, Munich’s oldest]}
#
# ('Pinakothek basically translates to a place that houses old pictures, '
#  'statues, and other works of art. The word ALTE is German and simply means '
#  'old. So together the meaning is transcribed as a “place that house old works '
#  'of art”.')
# {}
#
# ('Pinakothek is the German version of an ancient Greek word that evolved into '
#  'a Latin variant of the same. So the historically famous, and world renowned '
#  'Pinacotheca Gallerias of Ancient Rome and Greece (art galleries) became the '
#  'Pinakothek in German.')
# {'coref_clusters_1': [an ancient Greek word that, the same.]}
#
# ('Originally built to be the largest art gallery in the world, there is no '
#  'shortage of stunning paintings to see at the Alte Pinakothek. The Munich art '
#  'museum is home to many hundreds of paintings, spanning a huge range of '
#  'styles. The artwork of the Old Masters is a must see when visiting this '
#  'collection of art in Munich, but you’ll also come across many famous works '
#  'by 18th century artists from across Europe.')
# {'coref_clusters_1': [the Alte Pinakothek., The Munich art museum is],
#  'coref_clusters_2': [Munich art, Munich,]}
#
# ('You can take a guided tour of this Munich art gallery, or make your own way '
#  'through the paintings, which include works by Peter Paul Reubens, Raphael, '
#  'and Leonardo Da Vinci to name only a few. Notable paintings on display at '
#  'the Alte Pinakothek Munich include Da Vinci’s ‘Virgin and Child’, and '
#  'Rembrandt’s first self portrait.')
# {'coref_clusters_1': [this Munich art gallery,, the Alte Pinakothek Munich include],
#  'coref_clusters_2': [Leonardo Da Vinci to, Da Vinci’s ‘]}
#
# ('If you have any interest in classical historical painting, then this museum '
#  'is a MUST visit for you! ')
# {}
#
# ('The Alte Pinakothek Munich can be found in the Kunstareal, also known as the '
#  'art district, or museum quarter. If you’re looking to make a day of art in '
#  'Munich, this is very handy, as here there are 18 museums in close proximity.')
# {'coref_clusters_1': [Munich can, Munich,]}
#
# ('With very little parking around the Kunstareal, it’s recommended that you '
#  'take public transport. This won’t be a problem, as there are a range of '
#  'handy public transport links to the Alte Pinakothek Munich.')
# {'coref_clusters_1': [take public, This wo]}
#
# 'If you’re arriving by tram, simply hop on the No 27 to Pinakotheken.'
# {}
#
# ('If you’re taking the U-Bahn to the Alte Pinakothek Munich, either take the '
#  'U2 to Königsplatz or Theresienstrasse and enjoy a 10 minute walk. Or the U3, '
#  'U4, U5, and U6 to Odeonsplatz will bring you within a 15 minute walk of the '
#  'Munich art gallery.\xa0')
# {'coref_clusters_1': [Munich,, Munich art]}
#
# ('If you’d like to take the bus to the Alte Pinakotheken Munich, the easiest '
#  'option is the dedicated Museum Line bus, the No 100 bus, to Pinakotheken.')
# {'coref_clusters_1': [the Alte Pinakotheken Munich,, Pinakotheken.]}
#
# ('In 2022, taking into account current Covid-19 measures in the State of '
#  'Bavaria, visiting museums of the\xa0Bayerische\xa0Staatsgemäldesammlungen\xa0'
#  'is possible according to the 3G-rule (Vaccinated Recovered Tested). Please '
#  'show your certificate at the entrance.\xa0')
# {}
#
# ('Admission for the permanent exhibition of art in Munich at the Alte '
#  'Pinakothek is 8,80€. If you’re over the age of 65, or a student in Germany, '
#  'you can take advantage of reduced admission rates, for 6,60€. For young '
#  'people (under the age of 18) admission to the Alte Pinakothek Munich is '
#  'completely free.')
# {'coref_clusters_1': [the Alte Pinakothek is, the Alte Pinakothek Munich is],
#  'coref_clusters_2': [Munich at, Munich is]}
#
# ('A handy tip is to visit the Alte Pinakothek Munich on a Sunday, as admission '
#  'is only 1€!')
# {}
#
# ('Alte pinakothek tickets are readily available to purchase at the museum '
#  'front desk. However, to avoid waiting in crowded lines it’s recommended by '
#  'this particular münchen museum to book tickets in advance to avoid '
#  'disappointment. This can easily be done online through the Pinakothek site.')
# {'coref_clusters_1': [book tickets, This can]}
#
# ('The Alte Pinakothek opens at 10 am daily, and on Wednesdays and Thursdays is '
#  'open past the usual closing time of 6pm, until 8.30pm. And don’t forget, the '
#  'Alte Pinakothek is closed on Mondays.')
# {'coref_clusters_1': [The Alte Pinakothek opens, the Alte Pinakothek is]}
#
# ('As we mentioned earlier this is the Kunstareal of Munich so there are a '
#  'plethora of other Munich Museums in the area as well as a number of Munich '
#  'Monuments and open spaces and gardens.')
# {'coref_clusters_1': [Munich so, Munich Museums, Munich Monuments],
#  'coref_clusters_2': [this is, the area as]}
#
# ('You can easily spend a couple of days in this compact area of Munich alone '
#  'and visit some incredible and historical sights that we’ve listed below for '
#  'you.')
# {}
#
# ('We hope you enjoyed our write up on Munich’s fantastic Alte Pinakothek '
#  'Museum and that you’re inspired to visit this wonderfully preserved '
#  'collection of artworks. ')
# {'coref_clusters_1': [We hope, our write],
#  'coref_clusters_2': [Munich’s fantastic Alte Pinakothek Museum and, this wonderfully preserved collection of artworks.]}
#
# ('We’ve visited ourselves many times, and because of their art rotation '
#  'policy, there is always something new to inspire us and we’re sure there '
#  'will be for you also. Indeed, you’ll often see budding artists sketching the '
#  'glorious and ancient artworks contained within the museum.')
# {'coref_clusters_1': [We’ve, ourselves many, us and, we’re]}
#
# ('This is a place that showcases Bavarian State History perfectly, and we '
#  'guarantee you that as art museums in Munich go, this is one of the very best '
#  'that can be found in all of Europe!')
# {'coref_clusters_1': [This is, this is]}
#
# 'Take care, enjoy the art and have a great day!'
# {}
#
# 'Copyright © | 2022 | Absolute Munich'
# {}
#
# 'Munich - Bavaria - Germany\nEmail: hello@absolutemunich.com'
# {}
#
# ('There’s an outdoor restaurant, bar and street food venue in Munich that is '
#  'both iconic and unique to the city, and it’s the totally awesome Alte '
#  'Utting.\xa0')
# {'coref_clusters_1': [Munich that, the city,],
#  'coref_clusters_2': [an outdoor restaurant, bar and street food venue in Munich that is both iconic and unique to the city, and it’s the totally awesome Alte Utting., it’s]}
#
# ('In summer, Munich is pretty much about enjoying the outdoors. Besides taking '
#  'a dip in the Isar and drinking a Maß in a Biergarten, hanging out in an '
#  'outdoor restaurant is just another thing locals savour.')
# {}
#
# ('Standing peculiarly (or should I say mounted) on an abandoned railway bridge '
#  'in Sendling, and only a few minutes walk from the unmistakable Bahnwärter '
#  'Thiel, a dance/party hub recreated from old containers and transportations, '
#  'lies a retired old steamboat from Lake Ammersee.\xa0')
# {}
#
# ('The MS Utting, built in 1950, has over 65 years of history. It has brought '
#  'locals and travellers across the lake and left bethought memories.')
# {'coref_clusters_1': [The MS Utting, built in 1950, has, It has]}
#
# ('For this reason, to avoid the retired boat from becoming worthless metal '
#  'scrapes, it has been brought back to life as part of the Alte Utting.\xa0')
# {'coref_clusters_1': [the retired boat from, it has]}
#
# ('Now, this is a centrepiece of the area and acts not only as a restaurant but '
#  'it also harbours a bar, a hip food market and a performance space for '
#  'regular live music and shows.')
# {'coref_clusters_1': [this is, it also]}
#
# ('If you like Ganz Woanders, Bahnwärtel Thiel or Gans am Wasser, they share a '
#  'similar ambient. Like the other projects by the Hahn brothers, there are '
#  'often live music and cultural programmes for adults and kids.')
# {'coref_clusters_1': [Ganz Woanders, Bahnwärtel Thiel or Gans am Wasser,, they share, the Hahn brothers,]}
#
# ('The new-found home of the MS Utting took over one year of planning, '
#  'relocating and renovating. A section of the Autobahn was even blocked to '
#  'transfer the boat to its current location.\xa0')
# {'coref_clusters_1': [the MS Utting took, the boat to, its current]}
#
# ('Sounds dramatic? Well, after your trip to the Alte Utting, you’ll see why '
#  'this was a mega project.\xa0')
# {}
#
# ('The revamp involved not only retaining sections of the interior of the boat '
#  'and turning it into a restaurant/mini-concert area but also creating an '
#  'outdoor area around the boat with an outdoor sitting space surrounded by '
#  'colourful murals.')
# {'coref_clusters_1': [sections of the interior of the boat and, it into],
#  'coref_clusters_2': [the boat and, the boat with]}
#
# ('You can snake through and around the boat to discover various food trucks '
#  'like in a cool neighbourhood in London or Christiania in Copenhagen.')
# {}
#
# ('If you have visitors in town and want to show them the Bavarian experience, '
#  'breakfast on board at the Alte Utting is perfect.')
# {'coref_clusters_1': [visitors in, them the]}
#
# ('For typical Bavarian Cuisine, there is a Weißwurst-Frühstuck (white sausage '
#  'breakfast) with Brezel served on deck on weekends and public holidays.')
# {}
#
# ('For more chilled settings, food trucks are scattered around the boat with '
#  'outdoor seating.')
# {}
#
# ('At the main entrance with the front view of the boat, you’ll be lured to the '
#  'smell of pizza baking crust and melted cheese. That’s Da Vito!')
# {}
#
# ('Towards the lower section, you’ll be stopped by colourful pots and aromas of '
#  'African curries. There are meat, vegetarian and vegan options. Mango curry '
#  'with couscous is our favourite.')
# {}
#
# ('If you feel peckish, an authentic French crepe at the stern of the boat will '
#  'hit the spot. There are sweet, savoury and even spicy jalapeños options!\xa0 '
#  'The classic crepe with Nutella is always a winner!')
# {}
#
# ('FYI:\xa0 not all the food trucks have the same running hours, so make sure '
#  'you check online for the individual opening hours.')
# {}
#
# ('The main bar is in the centre of the boat. This automatically makes it very '
#  'praktisch (practical)! It’s Selbstbedienung (self-serviced), so no waiters '
#  'are bringing or collecting your drinks. Instead, you will order and collect '
#  'your drink at the bar. ')
# {'coref_clusters_1': [is in, This automatically],
#  'coref_clusters_2': [The main bar is, it very, It’s, the bar.]}
#
# ('A Pfand (deposit) would be paid and will be returned when you drop off your '
#  'bottle/cup. This system is very common in Bavaria.')
# {}
#
# ('The bar itself is no frills with all the essentials. Besides beers and '
#  'wines, it also offers spirits and shots.')
# {'coref_clusters_1': [The bar itself, itself is, it also]}
#
# ('Unfortunately, beers are not from the tap, but at least they are '
#  'Augustiners. Helles, white beer, pils, Radler (beer with lemonade) and '
#  'non-alcoholic beers are available.\xa0')
# {'coref_clusters_1': [beers are, they are]}
#
# ('Prices for both food and drinks are gunstig (good valued) crossing different '
#  'price ranges.')
# {}
#
# ('From a classic strawberry marmalade crepe at 4€, curries at 10€ and a fancy '
#  'truffle tortelloni at 14€. Beers are around 4€ and a glass of bio wine '
#  'starts at 6,50€.')
# {}
#
# 'All coffee and teas are bio and are around 4€.'
# {}
#
# ('The Alte Utting is simply a great outdoor venue with a chilled vibe. It’s a '
#  'place where you can be part of a piece of Bavarian history and enjoy an '
#  'alternative, fun mood, which is a contrast to the classic Bavarian '
#  'neighbourhood.')
# {'coref_clusters_1': [The Alte Utting is, It’s]}
#
# ('We love going to Alte Utting also because is a place that can basically '
#  'please everyone. It’s a wonderful Treffpunkt (meeting place) for a group of '
#  'friends to enjoy a gig, family with kids or a date where you snuggle into a '
#  'little corner to enjoy a cosy moment.\xa0')
# {'coref_clusters_1': [Alte Utting also, It’s]}
#
# ('One thing is for sure, that you don’t need to argue with friends over what '
#  'to eat and for each visit, there’s also always something new to try.')
# {}
#
# 'In conclusion, it’s a thumbs-up!'
# {}
#
# ('What we really look forward to is actually the Sternenflotte taking place in '
#  'late Nov-Dec. The boat is transformed into a Weihnachtsmarkt (Christmas '
#  'market) twinkled with fairy lights, warm fireplaces, craft stalls, special '
#  'cultural programs and of course, Glühwein (mulled wine) is served!\xa0')
# {'coref_clusters_1': [the Sternenflotte taking, The boat is]}
#
# 'Is only autumn now, but we are already dreaming about this.'
# {}
#
# 'Lagerhausstraße 15, 81371'
# {}
#
# '(a 10min walk from U-Bahn Implerstraße)'
# {}
#
# ('You can reserve a space on the boat if you are over 8 people here | '
#  'reservierung@alte-utting.de')
# {}
#
# 'If you love your visit to the Alte Utting, you can actually rent the boat.'
# {}
#
# ('How exciting would it be to host a dressed-up on this boat, where guests can '
#  'feel like they are back in time!')
# {'coref_clusters_1': [guests can, they are]}
#
# 'event@alte-utting.de'
# {}
#
# ('Looking for more foodie inspirations? Check out some of our other posts on '
#  'our blog.')
# {'coref_clusters_1': [our other, our blog]}
#
# 'Copyright © | 2022 | Absolute Munich'
# {}
#
# 'Munich - Bavaria - Germany\nEmail: hello@absolutemunich.com'
# {}
#
# ('This is the story of the incredibly imposing and (almost) architecturally '
#  'plaigiarant Munich Feldherrnhalle (Field Marshals’ Hall) on Odeonsplatz. '
#  'Obviously historically important stories are behind any of the stunning '
#  'architectural buildings that abound in Munich today, but the story of the '
#  'Feldherrnhalle – whilst tainted by negative consequence – is one of the most '
#  'fascinating. …')
# {'coref_clusters_1': [This is, the story of the Feldherrnhalle – whilst tainted by negative consequence – is],
#  'coref_clusters_2': [the incredibly imposing and (almost) architecturally plaigiarant Munich Feldherrnhalle (Field Marshals’ Hall) on Odeonsplatz., the Feldherrnhalle –]}
#
# '  Feldherrnhalle: Munich Field Marshals’ Hall [What Is It?] Read More »'
# {'coref_clusters_1': [Munich Field Marshals’ Hall [, It?]}
#
# ('When Spring has Sprung, Frühlingsfest is imminent! This is Munich PARTY TIME '
#  'with Oktoberfest’s “little sister”!')
# {}
#
# ('The Bavarian State Parliament & gifted students both call the Maximilianeum '
#  'home. Find out why!')
# {}
#
# ('One of the lesser-known parks in Munich, Bavariapark should be visited! We '
#  'tell you why here.')
# {}
#
# ('If you’re on a very short trip to Munich then the Endless Staircase Munich '
#  'is probably not a must-see sight on your touristic radar – but it‘s a '
#  'fascinating piece of street art nonetheless. Encountering Sculptures, Street '
#  'Art, Monuments, Statues and Fountains in Munich as you walk about the city '
#  'is commonplace, but you’ll need …')
# {'coref_clusters_1': [the Endless Staircase Munich is, it‘s a],
#  'coref_clusters_2': [Munich then, Munich as, the city is]}
#
# ('  Endless Staircase Munich: A Powerful Statement of Bavarian Street Art Read '
#  'More »')
# {}
#
# ('The KARLSTOR is a popular tourist attraction in Munich & a great reminder of '
#  'the city’s long history.')
# {'coref_clusters_1': [Munich &, the city’s long]}
#
# 'Your FREE Guide to the Bavarian Forest National Park. Visit Today!'
# {}
#
# ('With evidence of Roman occupation, it’s highly likely that GRÜNWALD CASTLE, '
#  'just 12 kilometers to the south of Munich, was originally a defensive '
#  'military watchtower. This is certainly one of the lesser known Castles in '
#  'Bavaria and astoundingly, is rarely mentioned in any Munich guide book '
#  'despite its significance as an important medieval monument in …')
# {'coref_clusters_1': [GRÜNWALD CASTLE, just 12 kilometers to the south of Munich,, This is, its significance],
#  'coref_clusters_2': [Munich,, Munich guide]}
#
# '  Grünwald Castle: Munich’s Medieval Hill Castle Read More »'
# {'coref_clusters_1': [  Grünwald Castle:, Munich’s Medieval Hill Castle Read]}
#
# ('With so much about LAKE AMMERSEE to love, it’s no wonder this incredible '
#  'lake a much sought-out leisure destination for Müncheners.')
# {'coref_clusters_1': [LAKE AMMERSEE to, this incredible lake a]}
#
# ('Does Munich Have A Flag? Why yes, it does! ANd in this article, you’ll learn '
#  'all about it.')
# {'coref_clusters_1': [Munich Have, it does]}
#
# 'Copyright © | 2022 | Absolute Munich'
# {}
#
# 'Munich - Bavaria - Germany\nEmail: hello@absolutemunich.com'
# {}
#
# ('There’s an outdoor restaurant, bar and street food venue in Munich that is '
#  'both iconic and unique to the city, and it’s the totally awesome Alte '
#  'Utting.\xa0 In summer, Munich is pretty much about enjoying the outdoors. '
#  'Besides taking a dip in the Isar and drinking a Maß in a Biergarten, hanging '
#  'out in an …')
# {'coref_clusters_1': [Munich that, the city,, Munich is],
#  'coref_clusters_2': [an outdoor restaurant, bar and street food venue in Munich that is both iconic and unique to the city,, it’s]}
#
# '  Alte Utting Munich | Boat on a Bridge [Restaurant Review] Read More »'
# {}
#
# ('Bindaas Munich: Fun, Vibrant & Cheeky Indian Street Style Cuisine REVIEW: A '
#  'Munich Indian Restaurant with a modern interpretation of the streets in '
#  'India.\xa0 In Munich, there are numerous classic Indian restaurants that '
#  'feature nicely pressed white tablecloths, sparkling polished glassware and '
#  'perfectly folded red napkins. These types of Indian Eateries are often ideal '
#  'for …')
# {'coref_clusters_1': [Bindaas Munich:, Munich Indian, Munich,]}
#
# '  EXCITING Munich Indian Restaurant | Best Of Bindaas [Review] Read More »'
# {}
#
# ('There are a number of Do’s and Don’ts to be considered in Germany so we’ve '
#  'produced this SHORT GUIDE to help navigate your way.')
# {}
#
# ('The totally unique Gans Woanders Cafe is a kid-friendly neighbourhood café & '
#  'cultural centre where Quirky, Fun, & Community collide. ')
# {}
#
# ('Awesome Aussie-inspired Veg/Vegan Café in Munich. Send your tastebuds on '
#  'holiday here!')
# {}
#
# ('Recommendations and resources that will assist you with your dream of Living '
#  'in Munich. ')
# {}
#
# ('As a newcomer in Munich, one administration office you’ll quickly encounter '
#  'is the KVR Munich:die München KVR (kreisverwaltungsreferat = Regional '
#  'Administrative Office). This article was updated to reflect the most recent '
#  'KVR Munich information including updates to their contacts, processes, and '
#  'administrative practices in May 2022 KVR Munich: What is It? The KVR Munich '
#  'is …')
# {'coref_clusters_1': [the KVR Munich:, KVR Munich information, KVR Munich:, It?, The KVR Munich is]}
#
# '  KVR: Appointment and Registration in Munich Read More »'
# {}
#
# ('Keen to visit the highest mountain in Germany, the ZUGSPITZE? Here we '
#  'explain why you should do exactly that!')
# {'coref_clusters_1': [visit the, that!]}
#
# ('Being pregnant in Munich provides challenges for sure, but fear not, we’ve '
#  'got you covered!')
# {}
#
# ('The Munich Viktualienmarkt is where Munich’s heart beats. A popular '
#  'inner-city meeting place filled with food and festivities!')
# {}
#
# 'Copyright © | 2022 | Absolute Munich'
# {}
#
# 'Munich - Bavaria - Germany\nEmail: hello@absolutemunich.com'
# {}

# %% [markdown]
# ## #3. Utils (optional)

# %% [markdown]
# ### Simple coreference resolution example

# %%
doc = nlp("Berlin is the Capital of Germany. It's one of the most popular city in germany.")
print(doc.spans)
# Out:
# {'coref_clusters_1': [Berlin is, It's]}

# %% [markdown]
# ### Analize the pipeline

# %%
# see pipeline components
print(nlp.pipe_names)

# analize pipeline
pprint(nlp.analyze_pipes(pretty=True))
# Out:
# ['sentencizer', 'transformer', 'coref', 'span_resolver', 'span_cleaner']
#
# ============================= Pipeline Overview =============================
#
# #   Component       Assigns               Requires    Scores          Retokenizes
# -   -------------   -------------------   ---------   -------------   -----------
# 0   sentencizer     token.is_sent_start               sents_f         False
#                     doc.sents                         sents_p
#                                                       sents_r
#
# 1   transformer     doc._.trf_data                                    False
#
# 2   coref           doc.spans             doc.spans   coref_f         False
#                                                       coref_p
#                                                       coref_r
#
# 3   span_resolver   doc.spans             doc.spans   span_accuracy   False
#
# 4   span_cleaner    doc.spans                                         False
#
#
# ================================ Problems (1) ================================
# ⚠ 'coref' requirements not met: doc.spans
# {'attrs': {'doc._.trf_data': {'assigns': ['transformer'], 'requires': []},
#            'doc.sents': {'assigns': ['sentencizer'], 'requires': []},
#            'doc.spans': {'assigns': ['coref', 'span_resolver', 'span_cleaner'],
#                          'requires': ['coref', 'span_resolver']},
#            'token.is_sent_start': {'assigns': ['sentencizer'], 'requires': []}},
#  'problems': {'coref': ['doc.spans'],
#               'sentencizer': [],
#               'span_cleaner': [],
#               'span_resolver': [],
#               'transformer': []},
#  'summary': {'coref': {'assigns': ['doc.spans'],
#                        'requires': ['doc.spans'],
#                        'retokenizes': False,
#                        'scores': ['coref_f', 'coref_p', 'coref_r']},
#              'sentencizer': {'assigns': ['token.is_sent_start', 'doc.sents'],
#                              'requires': [],
#                              'retokenizes': False,
#                              'scores': ['sents_f', 'sents_p', 'sents_r']},
#              'span_cleaner': {'assigns': ['doc.spans'],
#                               'requires': [],
#                               'retokenizes': False,
#                               'scores': []},
#              'span_resolver': {'assigns': ['doc.spans'],
#                                'requires': ['doc.spans'],
#                                'retokenizes': False,
#                                'scores': ['span_accuracy']},
#              'transformer': {'assigns': ['doc._.trf_data'],
#                              'requires': [],
#                              'retokenizes': False,
#                              'scores': []}}}

# %% [markdown]
# # Entity linking with Wikidata (NERD/EL)

# %% [markdown]
# ## #1. Setup development environment

# %% [markdown]
# ### Update & import Python modules

# %%
# input files
ents_file = DRIVE_PATH + "/IE/ie_course_2022_team03/assets/entities.json"
annot_text_file = DRIVE_PATH + "/IE/ie_course_2022_team03/assets/annotated_text.json"

# output files
kb_dir = DRIVE_PATH + "/IE/ie_course_2022_team03/output/ml_el/kb"
nlp_dir = DRIVE_PATH + "/IE/ie_course_2022_team03/output/ml_el/my_nlp"
train_corpus = DRIVE_PATH + "/IE/ie_course_2022_team03/output/ml_el/train_corpus"
test_corpus = DRIVE_PATH + "/IE/ie_course_2022_team03/output/ml_el/test_corpus"
nlp_el_dir = DRIVE_PATH + "/IE/ie_course_2022_team03/output/ml_el/my_el_nlp"

# %%
def load_entities():
  names = dict()
  descriptions = dict()
  # read and iterate entities and split it into two dicts
  with open(ents_file, newline="") as f:
    entities = json.load(f)
    # print(f"Retrieved entities")
    for row in entities:
      qid = row['qid']
      name = row['name']
      desc = row['description']
      names[qid] = name
      descriptions[qid] = desc
  # return "names" {id,names} and "descriptions" {id,descriptions}
  return names, descriptions

name_dict, desc_dict = load_entities()

# %%
""" Step 1: create the Knowledge Base in NLP pipeline and write it to file """

# Helper function to read in the pre-defined entities we want to disambiguate to
def load_entities():
  names = dict()
  descriptions = dict()
  # read and iterate entities and split it into two dicts
  with open(ents_file, newline="") as f:
    entities = json.load(f)
    # print(f"Retrieved entities")
    for row in entities:
      if row['qid'] not in ["Q183", "Q1726", "Q64"]:
        continue
      qid = row['qid']
      name = row['name']
      desc = row['description']
      names[qid] = name
      descriptions[qid] = desc
  # return "names" {id,names} and "descriptions" {id,descriptions}
  return names, descriptions

# First: create a simple model with an NER component
# To ensure we get the correct entities for this demo, add a simple entity_ruler as well.
nlp = spacy.load("en_core_web_lg", exclude="parser, tagger, lemmatizer")
ruler = nlp.add_pipe("entity_ruler", after="ner")
patterns = [{"label": "CITY", "pattern": [{"LOWER": "berlin"}]}]
ruler.add_patterns(patterns)
nlp.add_pipe("sentencizer", first=True)

name_dict, desc_dict = load_entities()

# %%
kb = KnowledgeBase(vocab=nlp.vocab, entity_vector_length=300)

for qid, desc in desc_dict.items():
  desc_doc = nlp(desc)
  desc_enc = desc_doc.vector
  # Set arbitrary value for frequency
  kb.add_entity(entity=qid, entity_vector=desc_enc, freq=342)

for qid, name in name_dict.items():
  # set 100% prior probability P(entity|alias) for each unique name
  kb.add_alias(alias=name, entities=[qid], probabilities=[1])

qids = name_dict.keys()
probs = [0.3 for qid in qids]
# ensure that sum([probs]) <= 1 when setting aliases
kb.add_alias(alias="Berlin", entities=qids, probabilities=probs)  #

print(f"Entities in the KB: {kb.get_entity_strings()}")
print(f"Aliases in the KB: {kb.get_alias_strings()}")
print()

# store knowledgebase and NLP pipeline
kb.to_disk(kb_dir)
print(f"Saved KB in: {kb_dir}")
nlp.to_disk(nlp_dir)
print(f"Saved NLP pipeline in: {nlp_dir}")
# Out:
# <ipython-input-16-e8093ac239de>:16: UserWarning: [W017] Alias 'Berlin' already exists in the Knowledge Base.
#   kb.add_alias(alias="Berlin", entities=qids, probabilities=probs)  #
# Entities in the KB: ['Q64', 'Q1726', 'Q183']
# Aliases in the KB: ['Berlin', 'Germany', 'Munich']
#
# Saved KB in: /content/drive/My Drive/IE/ie_course_2022_team03/output/ml_el/kb
# Saved NLP pipeline in: /content/drive/My Drive/IE/ie_course_2022_team03/output/ml_el/my_nlp

# %%
nlp = spacy.load(nlp_dir, exclude="parser, tagger")

# %%
""" Step 2: Once we have done the manual annotations, create corpora in spaCy format. """

##############################################################
# TODO: create annotated dataset for training before this step
##############################################################
docs = []
gold_ids = []
COUNT = 0

with open(annot_text_file, newline="") as f:
  example = json.load(f)
  anotated_text = example['annotations']
  for line in anotated_text:
    sentence = line[0]

    QID = line[1]["entities"][0][2]
    doc = nlp.make_doc(sentence)
    gold_ids.append(QID)
    # we assume only 1 annotated span per sentence, and only 1 KB ID per span
    if QID in ['Q64', 'Q1726']:
      lable = "CITY"
    else:
      lable = "COUNTRY"
    entity = doc.char_span(
      line[1]["entities"][0][0],
      line[1]["entities"][0][1],
      label=lable,
      kb_id=QID,
    )
    doc.ents = [entity]
    for i, t in enumerate(doc):
      doc[i].is_sent_start = i == 0
    docs.append(doc)

print("Statistics of manually annotated data:")
print(Counter(gold_ids))
print()

train_docs = DocBin()
test_docs = DocBin()
for QID in ['Q64', 'Q1726', 'Q183']:
  indices = [i for i, j in enumerate(gold_ids) if j == QID]
  # first 8 in training
  for index in indices[0:8]:
    train_docs.add(docs[index])
  # last 2 in test
  for index in indices[8:10]:
    test_docs.add(docs[index])

train_docs.to_disk(train_corpus)
print(f"Saved train corpus in: {train_corpus}")
test_docs.to_disk(test_corpus)
print(f"Saved test corpus in: {test_corpus}")
# Out:
# Statistics of manually annotated data:
# Counter({'Q64': 29, 'Q183': 9, 'Q1726': 1})
#
# Saved train corpus in: /content/drive/My Drive/IE/ie_course_2022_team03/output/ml_el/train_corpus
# Saved test corpus in: /content/drive/My Drive/IE/ie_course_2022_team03/output/ml_el/test_corpus

# %%
""" Step 3: Train entity linking model. """

nlp = spacy.load(nlp_dir)

TRAIN_EXAMPLES = []

with open(train_corpus, "rb") as f:
  doc_bin = DocBin().from_disk(train_corpus)
  docs = doc_bin.get_docs(nlp.vocab)
  for doc in docs:
    TRAIN_EXAMPLES.append(Example(nlp(doc.text), doc))

entity_linker = nlp.add_pipe("entity_linker", config={"incl_prior": False}, last=True)
entity_linker.initialize(lambda: TRAIN_EXAMPLES, nlp=nlp, kb_loader=load_kb(kb_dir))

with nlp.select_pipes(enable=["entity_linker"]):  # train only the entity_linker
  optimizer = nlp.resume_training()
  for itn in range(500):  # 500 iterations takes about a minute to train
    random.shuffle(TRAIN_EXAMPLES)
    batches = minibatch(TRAIN_EXAMPLES, size=compounding(4.0, 32.0, 1.001))  # increasing batch sizes
    losses = {}
    for batch in batches:
      nlp.update(
        batch,
        drop=0.2,  # prevent overfitting
        losses=losses,
        sgd=optimizer,
      )
    if itn % 50 == 0:
      print(itn, "Losses", losses)  # print the training loss
print(itn, "Losses", losses)

nlp.to_disk(nlp_el_dir)
print()
print(f"Saved NLP pipeline in: {nlp_el_dir}")
# Out:
# 0 Losses {'entity_linker': 4.067399084568024}
# 50 Losses {'entity_linker': 0.0764659841855367}
# 100 Losses {'entity_linker': 0.14850497245788574}
# 150 Losses {'entity_linker': 0.040450205405553184}
# 200 Losses {'entity_linker': 0.022833208243052162}
# 250 Losses {'entity_linker': 0.0724490781625112}
# 300 Losses {'entity_linker': 0.01742533346017202}
# 350 Losses {'entity_linker': 0.03389229873816173}
# 400 Losses {'entity_linker': 0.1404922902584076}
# 450 Losses {'entity_linker': 0.028791427612304688}
# 499 Losses {'entity_linker': 0.053205281496047974}
#
# Saved NLP pipeline in: /content/drive/My Drive/IE/ie_course_2022_team03/output/ml_el/my_el_nlp

# %%
""" Step 4: Evaluate the new Entity Linking component by applying it to unseen text. """

nlp = spacy.load(nlp_el_dir)

examples = []

with open(test_corpus, "rb") as f:
  doc_bin = DocBin().from_disk(test_corpus)
  docs = doc_bin.get_docs(nlp.vocab)
  for doc in docs:
    examples.append(Example(nlp(doc.text), doc))


print("RESULTS ON THE DEV SET:")
print()

for example in examples:
  print(example.text)
  print(f"Gold annotation: {example.reference.ents[0].kb_id_}")
  print(f"Predicted annotation: {example.predicted.ents[0].kb_id_}")
  print()

print()
print("RUNNING THE PIPELINE ON UNSEEN TEXT:")
text = "Berlin and Munich are both centers of innovation and progress, with numerous startups, tech companies, and research institutions driving forward Germany's economy"
doc = nlp(text)
print(text)
for ent in doc.ents:
  print(ent.text, ent.label_, ent.kb_id_)
print()
# Out:
# RESULTS ON THE DEV SET:
#
# Berlin and Munich are both home to several world-class universities and research institutions, making them important centers of higher education.
# Gold annotation: Q64
# Predicted annotation: Q64
#
# Berlin and Munich are both green cities, with numerous parks, gardens, and nature reserves within the city limits.
# Gold annotation: Q64
# Predicted annotation: Q64
#
# Germany is a country with a rich and complex history, and Berlin and Munich offer a glimpse into its past, present, and future.
# Gold annotation: Q183
# Predicted annotation: Q183
#
#
# RUNNING THE PIPELINE ON UNSEEN TEXT:
# Berlin and Munich are both centers of innovation and progress, with numerous startups, tech companies, and research institutions driving forward Germany's economy
# Berlin GPE Q64
# Munich GPE Q1726
# Germany GPE Q183
